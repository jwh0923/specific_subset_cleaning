# %%
import os
from pyspark.sql import Row, SparkSession
from typing import Dict, Any
import json
import uuid
from functools import partial
from typing import Iterable, Dict, Any
# create spark session
from pyspark.sql import Row, DataFrame
from loguru import logger
from xinghe.spark import *
from app.common.json_util import *

from xinghe.s3 import *


import uuid
import traceback
from datetime import datetime
from llm_web_kit.input.datajson import DataJson
from func_timeout import FunctionTimedOut, func_timeout
config = {
    "spark_conf_name": "spark_4",
    "skip_success_check": True,
    # 根据个人路径进行替换1
    "spark.executorEnv.LLM_WEB_KIT_CFG_PATH": "/share/jiangwenhao/.llm-web-kit.jsonc",
    "spark.dynamicAllocation.maxExecutors": "400",
    "spark.yarn.queue": "root.clean_exp"
}
spark = new_spark_session("llm_kit_cc", config)
spark

# %%
input_path = ["s3://llm-users-phdd2/jiangwenhao/article/blog_sina_com_cn/v001/"]
# input_path = ["s3://llm-users-phdd2/jiangwenhao/article/zh-web-tencent/2019/v017/part-67c9306eee8b-000002.jsonl"]

# %%
input_df = read_any_path(spark, ",".join(input_path), config)

# %%
input_rdd = input_df.rdd.map(lambda x :json.loads(x.value))

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import BooleanType
import re



# 定义判断是否为纯文本
def is_plain_text(row):
    html = row.get("html","")
    return not re.search(r'<[^>]+>', html)
    
# 定义判断content_list是否为空
def is_empty_content_list(row):
    content_list = row.get("content_list","")
    tag =False
    for i in content_list:
        if len(i) == 0:
            tag = True
    return tag


    

# filter_json_rdd =filter_json_rdd.filter(is_empty_content_list)
# 筛选不含HTML标签的行

# %% [markdown]
# ## 筛选异常框架处理异常数据集

# %%
# HTML是json 文本的数据集

filter_json_rdd = input_rdd.filter(is_plain_text)

# %%
# 是HTML但是content_list为空的数据集

filter_html_empty_rdd = input_rdd.filter(lambda x : is_empty_content_list(x) and not is_plain_text(x))
# filter_html_empty_rdd.count()

# %%
## 是HTML但是content_list不为空的数据集==》正常输出数据集
filter_html_rdd = input_rdd.filter(lambda x : not is_empty_content_list(x) and not is_plain_text(x))
# filter_html_rdd.count()

# %%
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, MapType, StringType
import re


def parse_text_paragraphs(row):
    # 按换行符分割段落，过滤空行
    html_content = row.get("html", "")
    paragraphs = []
    tmp_dict = {}
    for para in html_content.split('\n'):
        if para.strip():
            paragraphs.append({"c": para.strip(), "t": "text"})
        
    tmp_dict = {
            "type": "paragraph",
            "bbox": None,
            "raw_content": None,
            "content": paragraphs
  
        }      
    # 添加/更新content_list字段
    row["content_list"] = [[tmp_dict]]
    
    # 重建Row对象保留所有原始字段
    return row
   
    
from pyspark.sql import functions as F

filter_json_add_content_list_rdd = filter_json_rdd.map(lambda x : parse_text_paragraphs(x))

filter_html_add_content_list_rdd = filter_html_empty_rdd.map(parse_text_paragraphs)

# %% [markdown]
# ## 分开之后第一次合并，进行下一步清洗

# %%
union_rdd = filter_html_rdd.union(filter_html_add_content_list_rdd).union(filter_json_add_content_list_rdd).cache()

# %% [markdown]
# ## 检验content_list异常值

# %%
import re,regex
from typing import List, Dict

def is_empty_content(text: str) -> bool:
    """检查文本是否为空或仅包含空白字符"""
    
    return not (text or "").strip()

def has_excessive_whitespace(text: str) -> bool:
    """检测过多空格或换行"""
    # 换行符占比超过25%
    total_chars = len(text)
    if total_chars == 0:
        return True
    newline_ratio = text.count('\n') / total_chars
    if newline_ratio > 0.25:
        return True
    
    # 连续空格超过500个或连续换行超过8个
    if ' ' * 500 in text or '\n' * 8 in text:
        return True
    
    return False

line_breaks_re = r"[\n\v\f\r\x85\u2028\u2029]"
visible_spaces_re = r"[\x20\xa0\u2000-\u200a\u202f\u205f\u3000]"
invisible_spaces_re = r"[\u200b-\u200d\u2060\ufeff]"
invisible_chars_re = r"[\xad\ufffc\u2061-\u2063]"
other_controls_re = r"[\x00-\x08\x0e-\x1f\x7f-\x84\x86-\x9f]"
direction_controls_re = r"[\u061c\u200e\u200f\u202a-\u202e\u2066-\u2069]"
head_view_invisible_spaces_re = r"^[\x20\xa0\u2000-\u200a\u202f\u205f\u3000 ]"
private_use_area_pattern = (
    r"[\uE000-\uF8FF]"  # BMP 私有使用区
    r"|[\U000F0000-\U000FFFFD]"  # 辅助平面 A 私有使用区
    r"|[\U00100000-\U0010FFFD]"  # 辅助平面 B 私有使用区
)
ar_invisible_spaces_re = r"[\u2060\ufeff]"
ar_direction_controls_re = r"[\u061c\u202c\u2066-\u2069]"
others = r"[\u2063\x00-\x1F\x7F-\x9F�\u200B-\u200D\uFEFF\u206a\u206e\u206f\u00AD\u200c\xa0\u3000\u2003\u2002\u200e\u00A0\u200e\u25A1\xa0]|&nbsp|\\? :|xa0|&ldquo;|&rdquo;|&rdquo|�|□|&amp|&lt|&gt"

def clean_special_whitespace(s):
    if s is None:
        return True
    s = str(s)
    s = re.sub(line_breaks_re, "\n", s)
    s = re.sub(visible_spaces_re, " ", s)
    s = re.sub(head_view_invisible_spaces_re, "", s)
    s = re.sub(invisible_spaces_re, "", s)
    s = re.sub(direction_controls_re, "", s)
    s = re.sub(invisible_chars_re, "", s)
    s = re.sub(other_controls_re, "", s)
    s = re.sub(private_use_area_pattern, "", s)
    s = re.sub(others,"",s,flags=re.UNICODE)
    s = regex.sub(r'\p{Z}+', ' ', s, flags=regex.UNICODE)
    # 匹配任意数量的指定空白字符（包括常规空格、\u2005、\u200c等）
    return s


def clean_html_tag(s):
    """处理 QUALITY_BAD_EFFECTIVENESS 类型数据质量问题"""
    # 模式选择：清理内容 或 严格过滤
    PROCESS_MODE = "clean"  # 可配置为 "filter" 进行严格过滤
    
    
    # 检测到 HTML 标签时才处理
    if bool(re.search(r'<[^>]+>', s)):
        if PROCESS_MODE == "clean":
            """清理 HTML 标签，保留文本内容"""
            s = re.sub(r'<\/?[a-z][^>]*>', '', s, flags=re.IGNORECASE)

    return  s



    
def is_url(text: str) -> bool:
    """判断文本是否为URL"""
    url_pattern = re.compile(
        r'^(?:http|ftp)s?://'  # 匹配http/https/ftp
        r'(?:\S+(?::\S*)?@)?'  # 用户名密码
        r'(?:\d{1,3}\.){3}\d{1,3}'  # IPv4地址
        r'|'                     # 或域名
        r'(?:[A-Z0-9](?:[A-Z0-9-]{0,61}[A-Z0-9])?\.)+[A-Z]{2,6}'  # 域名
        r'(?::\d+)?'            # 端口
        r'(?:/?|[/?]\S+)$', re.IGNORECASE)
    return bool(re.match(url_pattern, text))


def is_only_url(text: str) -> bool:
    """判断字符串是否仅包含一个完整URL且无其他内容"""
    # 优化后的正则表达式，支持常见URL格式
    url_pattern = re.compile(
        r'^'                            # 字符串开始
        r'(https?|ftp)://'              # 协议头
        r'(?:\S+(?::\S*)?@)?'           # 用户名密码（可选）
        r'([a-z0-9\-]+\.)+[a-z]{2,}'    # 域名部分
        r'(?::\d+)?'                    # 端口号（可选）
        r'(?:/[^\s?#]*)?'               # 路径（可选）
        r'(?:\?[^\s#]*)?'               # 查询参数（可选）
        r'(?:#[^\s]*)?'                 # 锚点（可选）
        r'$',                           # 字符串结束
        re.IGNORECASE
    )
    return url_pattern.fullmatch(text.strip()) is not None

def is_too_short(text: str) -> bool:
    """判断文本长度是否过短"""
    return len(text) <= 21

def has_abnormal_chars(text: str) -> bool:
    """检测异常字符（如不可见字符、�）"""
    abnormal_pattern = re.compile(r'[\x00-\x1F\x7F-\x9F�\u200B-\u200d\uFEFF\u00AD\u200c\xa0\u3000\u2003\u2002\u200e]')
    return bool(abnormal_pattern.search(text))

    


def clean_repeat_chars(text, max_repeat=3):
    """
    清理无意义重复字符
    :param text: 原始文本
    :param max_repeat: 允许的最大连续重复次数(中文建议3-5)
    :return: 清洗后文本
    """
    # 匹配超过阈值的连续重复字符（支持全角/半角）
    pattern = rf"([\w\W])\1{{{max_repeat},}}"
    
    def replace_func(match):
        char = match.group(1)
        # 保留不超过允许的重复次数
        return char * max_repeat
    
    return re.sub(pattern, replace_func, text)

# %% [markdown]
# ## URL数据判断

# %%
import re
from typing import List, Dict
def is_single_url(text: str) -> bool:
    """严格判断是否为单个URL（修复括号平衡）"""
    cleaned_text = text.strip().strip("'\">")
    url_pattern = re.compile(r"http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", re.IGNORECASE)
    return url_pattern.fullmatch(cleaned_text) is not None
  
def is_url_only_content(content: str) -> bool:
    """判断内容是否全部由URL构成（改进分割逻辑）"""
    if not content.strip():
        return False
    
    # 分割策略：仅按空白符（空格、换行等）分割，保留URL内部字符
    segments = re.split(r"""\n+|[\s\'">]+|'""", content.strip())
    return all(
        is_single_url(segment)
        for segment in segments
        if segment.strip()  # 过滤空段落
    )

# %%
import re
from typing import Dict, List

import traceback
def is_valid_content_element(processed: Dict) -> Dict:
    """综合校验单个content元素的有效性"""
    # 基础校验：字段完整性
    # 优先取 'c'，若不存在则取 'title_content'，最后默认空字符串
   
    content_key = 'c' if 'c' in processed else 'title_content' if 'title_content' in processed else 'c'

    raw_content = processed.get(content_key, '')
    elem_type = processed.get('t', 'text') 
    

    
    # 规则1: 空内容或纯空格
    if is_empty_content(raw_content):
        processed[content_key] = ''
        processed['t'] = 'text'  # 强制类型为text
        return processed
    
    
    # 规则2: 过多空白（根据不同类型调整阈值）
    if has_excessive_whitespace(raw_content):
        processed[content_key] = ''
        processed['t'] = 'text'  # 强制类型为text
        return processed

    
    # 规则3: URL内容（仅允许特定类型的元素包含URL）
    #url_pattern = re.compile(r'^https?://\S+$')
    #if elem_type != 'hyperlink' and url_pattern.match(content):
    #    return False
 
    # 类型相关校验
    #if elem_type == 'text':
        # 文本长度校验
    #    if len(content) < 3:  # 最小3个字符
    #        return False
    #elif elem_type == 'equation-inline':
    #    # 公式格式校验
    #    if not re.match(r'^[A-Za-z0-9=+\-*/^()]+$', content):
    #        return False

    # --- 清理逻辑 ---
    cleaned = clean_html_tag(clean_repeat_chars(clean_special_whitespace(raw_content)))
  
    processed[content_key] = cleaned  # 更新原始内容键
    processed['t'] = elem_type  # 保留原始类型或默认值
       
    return processed

# %%
from typing import List, Dict

def filter_content(content: List[Dict]) -> List[Dict]:
    """过滤content列表，保留有效内容元素"""
    filtered = []
    for elem in content:
        # 步骤1: 校验并处理单个元素
        processed = is_valid_content_element(elem)
        
        # 步骤2: 动态判断内容键（优先'c'，其次是'title_content'）
        content_key = 'c' if 'c' in processed else 'title_content' if 'title_content' in processed else None
        if not content_key:
            continue  # 无内容键，直接跳过
        
        # 步骤3: 检查内容是否有效（非空且非纯空格）
        content_value = processed.get(content_key, '')
        if content_value.strip() != '':
            filtered.append(processed)
            
    return filtered

def update_value(data, target_key, condition = lambda x :True, new_value =clean_special_whitespace):
    """
    递归地遍历任意维的字典列表堆叠结构数据，并根据条件更新特定键的值。

    :param data: 数据结构（字典或列表）
    :param target_key: 要更新的目标键
    :param condition: 更新条件函数
    :param new_value: 新的值（可以是具体值或函数）
    """
    if isinstance(data, dict):
        for key, value in data.items():
            if key == target_key and condition(value):
                if callable(new_value):
                    data[key] = new_value(value)
                else:
                    data[key] = new_value
            else:
                update_value(value, target_key, condition, new_value)
    elif isinstance(data, list):
        for item in data:
            update_value(item, target_key, condition, new_value)
   
        
def filter_content_list(row):
    """优化点：分离标题/段落处理，防御性类型检查，保留原始数据结构"""
    try:
        # 防御性获取内容列表
        for page in row.get("content_list", []):
            valid_elements = []
            for elem in page:
                # 非字典或非目标类型直接保留
                if not isinstance(elem, dict) or elem.get('type') not in ('title', 'paragraph','list'):
                    valid_elements.append(elem)
                    continue

                # 类型分流处理
                elem_type = elem['type']

                content_data = elem.get('content')

                # --- 标题类型处理 ---
                if elem_type == 'title':
                    # 标题内容必须是字典且包含 title_content
                    if isinstance(content_data, dict) and 'title_content' in content_data:
                        filtered = filter_content([content_data])  # 包装成列表
                        # 校验返回结果有效性
                        if filtered and isinstance(filtered, list) and len(filtered) > 0:
                            new_content = filtered[0]
                            # 确保标题内容非空
                            if new_content.get('title_content', '').strip():
                                elem['content'] = new_content
                                valid_elements.append(elem)
                    # 无效标题内容直接过滤
                    continue

                # --- 段落类型处理 ---
                if elem_type == 'paragraph':
                    # 段落内容必须是列表
                    if isinstance(content_data, list):
                        filtered = filter_content(content_data)
                        # 保留非空内容
                        if filtered and len(filtered) > 0:
                            elem['content'] = filtered
                            valid_elements.append(elem)
                    # 无效段落内容直接过滤
                    continue
                if elem_type == 'list':
                    update_value(content_data,'c')
                  
                    elem['content'] = content_data
                   
                    valid_elements.append(elem)
                    


            # 原地更新页面内容
            page[:] = valid_elements
        return row
    except Exception as e:
        row['__error'] = {
            'code': -1,
            'msg': f"Content filtering failed: {str(e)}",
            'trace': traceback.format_exc()
        }
        return row

# %%
para_cleaning_rdd = union_rdd.map(filter_content_list).cache()

# %%
# input_rdd.filter(lambda x : x['track_id'] == 'cd30d78d-9ab1-4577-af00-92e3dfb65fd8').take(1)[0]

# %%
 # union_rdd.filter(lambda x :x['track_id'] == '09e0dcee-0768-4609-9d0a-9850c860a6b6').take(1)[0]
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.140.84.27:35149">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>llm_kit_cc</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
para_cleaning_rdd.filter(lambda x : x['track_id'] == '6a3e406a-0aa2-433b-ae75-9873d2436788').map(lambda x : make_content_md(x)).take(1)[0]
# Out:
# {'track_id': '3cb02028-fe33-4073-8333-9397227bf565',
#  'url': 'https://new.qq.com/rain/a/20200309A0EEAK00',
#  'html': "<p>\n <!--IMG_0--></p>\n<p>http://v.xinhua-news.com/bro-view-xgg/store_attachment/xcbattachfile/dspdata/2020/03/09/XxjxzxC007003_20200309_CBPFN0A002.jpg'&gt;</p>",
#  'page_layout_type': 'article',
#  'domain': 'new.qq.com',
#  'dataset_name': 'tencent',
#  'data_source_category': 'HTML',
#  'meta_info': {'filename': 's3://private-crawl-data/zh-web-tencent/20241218_p1/2020/1733726270019.json.gz',
#   'posttime': '2020-03-09 13:59:17',
#   'm_identity': '10859191',
#   'n_origin': '',
#   'n_headimg_url': '',
#   'f_domain_sec': 'new.qq.com',
#   'title': '新华网评·“疫”中人',
#   'uuid': '779d51af3aa65342fc6ea41b476b2a11',
#   'n_contain_img': 0,
#   'n_img_urls': [],
#   'n_is_origin': '0',
#   'n_video_urls': [],
#   'footplate': 'web',
#   'n_origin_author_name': '新华社新闻',
#   'n_contain_video': 0,
#   'n_origin_url': '',
#   'n_origin_author_uid': '10859191',
#   'm_name': '新华社新闻',
#   'c_name': '企鹅号',
#   'n_origin_posttime': '',
#   'statics': {'paragraph': 1, 'paragraph.text': 1}},
#  'content_list': [[{'type': 'paragraph',
#     'raw_content': "<div><div><p>http://v.xinhua-news.com/bro-view-xgg/store_attachment/xcbattachfile/dspdata/2020/03/09/XxjxzxC007003_20200309_CBPFN0A002.jpg'&gt;</p></div></div>",
#     'content': [{'c': "http://v.xinhua-news.com/bro-view-xgg/store_attachment/xcbattachfile/dspdata/2020/03/09/XxjxzxC007003_20200309_CBPFN0A002.jpg'>",
#       't': 'text'}]}]],
#  'main_html': "<div><div><p>\n </p>\n<p>http://v.xinhua-news.com/bro-view-xgg/store_attachment/xcbattachfile/dspdata/2020/03/09/XxjxzxC007003_20200309_CBPFN0A002.jpg'&gt;</p></div></div>",
#  'content_qa': "http://v.xinhua-news.com/bro-view-xgg/store_attachment/xcbattachfile/dspdata/2020/03/09/XxjxzxC007003_20200309_CBPFN0A002.jpg'>\n"}

# %%
result_rdd.filter(lambda x : x['track_id'] == '7a4055b5-2f5f-4cf1-9786-c002f7ea9b88').take(1)[0]
# Out:
# 25/03/11 15:08:56 WARN TaskSetManager: Lost task 1761.0 in stage 55.0 (TID 7903) (host-10-140-93-52 executor 37): TaskKilled (Stage cancelled)
# 25/03/11 15:08:56 WARN TaskSetManager: Lost task 1875.0 in stage 55.0 (TID 8017) (host-10-140-93-52 executor 53): TaskKilled (Stage cancelled)
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.140.84.27:44569">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>llm_kit_cc</code></dd>
#             </dl>
#         </div>
#
#             </div>
# [Stage 55:>                                                     (6 + 10) / 6000]

# %% [markdown]
# ## Markdown处理

# %%
from llm_web_kit.input.datajson import DataJson

def make_content_md(row):
    try:
        row['content_qa'] = DataJson(row).get_content_list().to_nlp_md()

        return row
    except Exception as e2:
        err = {"code":-1, f"{row}msg": traceback.format_exc()}
        row['content_qa'] = ''
        row['__error'] = err
        return row

def del_content_qa(row):
    del row['content_qa']
    return row

from llm_web_kit.input.datajson import DataJson, StructureMapper
def clist_filter_factory(self, field_you_want = ('paragraph')):
    """把content_list转化为md格式，只接受 Node 类型为 ['a', 'b'].
    Returns:
        str: md格式的文本内容
    """
    md_blocks = []  # 每个是个DocElementType规定的元素块之一转换成的文本
    content_lst = self._get_data()
    for page in content_lst:
        for content_lst_node in page:
            if content_lst_node['type'] in field_you_want:
                txt_content = self._StructureMapper__content_lst_node_2_md(content_lst_node)
                if txt_content and len(txt_content) > 0:
                    md_blocks.append(txt_content)
    md = self._StructureMapper__md_para_splitter.join(md_blocks)
    md = md.strip() + self._StructureMapper__text_end  # 加上结尾换行符
    return md
def clist_to_c(d_iter):
    StructureMapper.clist_filter = clist_filter_factory
    for d in d_iter:
        try:
            prompt = ''
            data_id = d['track_id']
            content  = DataJson(d).get_content_list().clist_filter()
            new_d = {
                'track_id': data_id,
                'prompt': prompt,
                'content_qa': content,
            }
            yield new_d
        except Exception as e:
            raise e
# para_cleaning_rdd.filter( lambda x : not is_empty_content_list(x)).map(make_content_md).filter(lambda x: not  is_too_short(x['content_qa'])).take(1)[0]

# %%
def testing(row):
    d= {'track_id': row['track_id'],'content_qa': DataJson(row).get_content_list().to_nlp_md()}
    return d

# %%
result_rdd = para_cleaning_rdd. \
filter( lambda x : not is_empty_content_list(x)).map(make_content_md).map(lambda x:testing(x)). \
filter(lambda x: not  is_too_short(x['content_qa'])). \
filter(lambda x : not has_excessive_whitespace(x['content_qa'])). \
filter(lambda x : not is_url_only_content(x['content_qa'])) 
result_rdd.take(1)[0]
# union_rdd.filter(lambda x : x['track_id'] == 'ea0eb1bd-9cd2-441c-a231-12d754eb1f23').take(1)[0]
# Out:
# {'track_id': 'f67c4f9c-1687-4d32-b009-a9575a9b8817',
#  'content_qa': '部分埃及媒体报道称，埃及同数个阿拉伯国家正试图邀请俄罗斯和乌克兰代表团前来进行下一轮和谈。据悉，这些国家已就通过政治途径解决俄乌冲突提出了若干建议，其中包括一份关于俄乌实现停火的倡议。（央视新闻）\n'}
# [Stage 1:=========>                                          (1627 + 50) / 9000]

# %%
result_df = result_rdd.map(lambda x: Row(value=json_dumps(x))).toDF()
# Out:
# [Stage 1:=========>                                          (1627 + 50) / 9000]

# %%
#交付数据集

final_rdd = para_cleaning_rdd.filter( lambda x : not is_empty_content_list(x)).map(make_content_md).filter(lambda x: not  is_too_short(x['content_qa'])). \
filter(lambda x : not has_excessive_whitespace(x['content_qa'])).filter(lambda x : not is_url_only_content(x['content_qa'])).map(del_content_qa)
final_df = final_rdd.map(lambda x: Row(value=json_dumps(x))).toDF()

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.140.84.27:35149">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>llm_kit_cc</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# 机器质检数据
write_any_path(result_df, "s3://llm-users-phdd2/jiangwenhao/article/zh-web-tencent/v005/")
# Out:
# 25/03/17 20:58:04 WARN TaskSetManager: Lost task 1346.0 in stage 1.0 (TID 1347) (host-10-140-93-52 executor 153): TaskKilled (Stage cancelled)
# [Stage 1:==>         (1627 + 49) / 9000][Stage 8:==========>(8272 + 728) / 9000]

# %%
# 验收数据
#腾讯
write_any_path(final_df, "s3://zhuanxiang-hw60p/article/tencent/final/v003/")
#souhu
#write_any_path(final_df, "s3://zhuanxiang-hw60p/article/souhu/final/v002/")
#sina
#write_any_path(final_df, "s3://zhuanxiang-hw60p/article/sina/v008/")
#sina——blog
#write_any_path(final_df, "s3://zhuanxiang-hw60p/article/blog_sina_com_cn/final/v001/")
# Out:
# {'rows': 174705947,
#  'bytes': {'sum': 1700901954349,
#   'min': 525,
#   'max': 14546397,
#   'cnt': 174705947,
#   'avg': 9735.799},
#  'files': 17382,
#  'sub_paths': {}}

# %%
# result_rdd.filter(lambda x: "__error" in x).count()
get_s3_config("s3://zhuanxiang-hw60p/article/tencent/v001/")
#write_any_path(result_df, "s3://llm-users-phdd2/jiangwenhao/article/zh-web-souhu/v001/")
# Out:
# {'endpoint': 'http://10.140.104.7',
#  'ak': 'C90B0C502692A2818ABF',
#  'sk': 'P4TpEHbboExJds+tmV88wELd61kAAAGVJpKiim0v'}

# %%
para_cleaning_rdd.filter( lambda x : not is_empty_content_list(x)).map(make_content_md).filter(lambda x: "__error" in x).take(1)[0]
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.140.84.27:41903">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>llm_kit_cc</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %% [markdown]
# ## 数据集预处理

# %%
import os
from pyspark.sql import Row, SparkSession
from typing import Dict, Any
import json
import uuid
from functools import partial
from typing import Iterable, Dict, Any
# create spark session
from pyspark.sql import Row, DataFrame
from loguru import logger
from xinghe.spark import *
from app.common.json_util import *

from xinghe.s3 import *


import uuid
import traceback
from datetime import datetime
from llm_web_kit.input.datajson import DataJson
from func_timeout import FunctionTimedOut, func_timeout

#| track_id                  | uuid                           | 全局唯一的ID                                                                                                        | 是              |
#| dataset_name              | str                            | 数据集的名字（全局唯一），这个名字是管理员输入的，然后做索引的时候带到index里来                                     | 是              |
#| data_source_category      | str                            | 这一行数据代表的是HTML，PDF，EBOOK,CC,labCC类型                                                                     | 是，此处是 HTML |
#| html                      | 字符串                         | 以UTF-8为编码的HTML文件全文                                                                                         | 是              |
#| url                       | 字符串                         | 这个文件的来源网址                                                                                                  | 是              |
#| file_bytes                | 整数                           | 文件的size, 单位是byte                                                                                              | 是              |
#| meta_info                 | 字典                           | 存放关于文件的元信息:如果能从文件里获取到作者，制作日期等信息。或者数据本身就带有一些其他的信息都放入到这个字段里。 | 是              |
#| meta_info->input_datetime | 其格式为 `yyyy-mm-dd HH:MM:SS` | 生成这个json索引文件这一条数据的时间，可以不用那么精确                                                              | 是              |


def process_platform_data(spark: SparkSession, config,platform: str, input_paths: list, version: str = "001"):
    """接收 spark 作为参数而不是持有它"""
    platform_config = platform_configs.get(platform)
    if not platform_config:
        raise ValueError(f"Unsupported platform: {platform}")

    # Driver 端操作
    input_df = read_any_path(spark, ",".join(input_paths), config)
    print(f"读取数据结束")
    # 准备 Worker 端配置
    worker_config = {
        "field_mappings": platform_config.get("field_mappings"),
        "extractor_config": platform_config.get("extractor_config")
    }
    # 分别广播不同配置
    broadcast_field_mappings = spark.sparkContext.broadcast(worker_config["field_mappings"])
    broadcast_extractor_config_path = spark.sparkContext.broadcast(worker_config["extractor_config"])  # 广播路径

    print("原始数据json结构")
    input_rdd = input_df.rdd.map(lambda x: Row(**{**json.loads(x.value), "filename": x.filename})).cache()
  #  pandas_df = input_rdd.toDF().toPandas()
  #  print(pandas_df)
    print(input_rdd.take(1)[0].asDict().keys())
    # 数据转换（仅用字段映射）
    transformed_rdd = input_rdd.map(
        lambda row: transform_row(row, broadcast_field_mappings.value)
    )
   
    print("formatter数据结束")
    # 数据抽取（仅用抽取器配置路径）
    processed_rdd = transformed_rdd.mapPartitions(
         lambda x:extract_data(
            x,broadcast_extractor_config_path = broadcast_extractor_config_path.value
        )
    )
    print("extractor数据结束")
    print("写入数据中")
   
    # 输出结果Row(value=json.dumps(x.asDict()))).toDF()
    write_any_path(processed_rdd.map(lambda x: Row(value=json.dumps(x.asDict()))).toDF(), platform_config["output_template"],config)
    print("写入数据结束")

    # 清理广播变量
    broadcast_field_mappings.unpersist()
    broadcast_extractor_config_path.unpersist()



def transform_row(row, config: dict) -> Row:
    """根据平台配置转换行数据"""
    mappings = config

    return Row(
        track_id=getattr(row, mappings["track_id"],str(uuid.uuid4())),
        url=getattr(row, mappings["url"], ''),
        html=getattr(row, mappings["html"], ''),
        page_layout_type=mappings.get("page_layout_type_map").get(
            getattr(row, mappings["layout_field"], ''),
            "article"
        ),
        domain=extract_domain_info(getattr(row, mappings["url"], ''))['domain'],
        dataset_name=mappings["dataset_name"],
        data_source_category=mappings["data_source_category"],
        meta_info={"filename":row.filename}
    )




def extract_data(partition, broadcast_extractor_config_path):
    from loguru import logger
    extractor_chain = ExtractSimpleFactory.create('/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc')
    timeout_seconds = 10
    # 为每个分区创建唯一的错误日志文件
    # partition_id = str(uuid.uuid4())
    # current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
    # error_log_path = f"s3://xyz-llm-users/xyz-users/yujia/CC-MAIN-2024-33/output/v002/error_logs/{current_time}_{partition_id}.json"
    # s3_doc_writer = S3DocWriter(path=error_log_path)
    try:
        for row in partition:
            d = row.asDict()
           
            input_data = DataJson(d)
            data_e: DataJson = func_timeout(timeout_seconds, extractor_chain.extract, args=(input_data,))
            #data_e: DataJson = extractor_chain.extract(input_data)
            yield Row(**data_e.to_dict())
    except FunctionTimedOut as e1:
            d['__error'] = {
                "error_type":"TIMEOUT",
                "error_message": "extract function timeout",
                "traceback":"TIMEOUT"
            }
            yield Row(**d)
    except Exception as e:
            # 记录更详细的错误信息
            error_info = {
                "error_type": type(e).__name__,
                "error_message": str(e),
                "traceback": traceback.format_exc(),
            }
            logger.error(error_info)
            # s3_doc_writer.write(error_info)
            d['__error'] = error_info
            yield Row(**d)
           


def _safe_extract(data: Dict, extractor, timeout: int = 10) -> Dict:
  
    """直接返回字典，避免生成器"""
    try:
        timeout_seconds = 10
        input_data = DataJson(data.asDict())
        print(input_data)
        data_e: DataJson = func_timeout(timeout_seconds, extractor.extract, \
                                                args=(input_data,))

        print(Row(**data_e.to_dict()))
        return data_e.to_dict() 
    except Exception as e:
        # 记录更详细的错误信息
        error_info = {
            "error_type": type(e).__name__,
            "error_message": str(e),
            "traceback": traceback.format_exc(),
        }
        logger.error(error_info)
        # s3_doc_writer.write(error_info)
        data['__error'] = error_info
        yield Row(**d)


from urllib.parse import urlparse

def extract_domain_info(url: str) -> dict:
    """从 URL 中提取完整的域名信息"""
    parsed = urlparse(url)
    netloc = parsed.netloc
    domain_parts = netloc.split(":")
    domain = domain_parts[0]  # 去除端口号
    root_domain = ".".join(domain.split(".")[-2:]) if len(domain.split(".")) >= 2 else domain

    return {
        "full_url": url,
        "netloc": netloc,
        "domain": domain,
        "root_domain": root_domain
    }
        
def handle_error(row: Dict, error: Exception) -> Dict:
    """统一错误处理"""
    row_dict = row.asDict()
    return {
     ** row,
    "__error": {
        "type": type(error).__name__,
        "message": str(error),
        "traceback": traceback.format_exc()
    }
    }

    
def extract_platform_from_s3_path(s3_path: str) -> str:
    """
    从 S3 路径中提取平台名称（存储桶后的第一个目录）
    
    示例输入: 
    - "s3://private-cooperate-data/zh-web-baijiahao/20241218_p1/"
    输出: "zh-web-baijiahao"
    
    - "s3://private-cooperate-data/DouBan/"
    输出: "DouBan"
    """
    # 分割路径并过滤空字符串
    parts = [p for p in s3_path.split("/") if p.strip() != ""]
    
    # 验证路径格式
    if len(parts) < 3:
        raise ValueError(f"无效的 S3 路径格式: {s3_path}")
    
    # 平台名称是存储桶后的第一个目录
    return parts[2]
import os
from pyspark.sql import Row, SparkSession
from typing import Dict, Any
import json
import uuid
from functools import partial
from typing import Iterable, Dict, Any
# create spark session
from pyspark.sql import Row, DataFrame
from loguru import logger
from xinghe.spark import *
from app.common.json_util import *

from xinghe.s3 import *


import uuid
import traceback
from datetime import datetime
from llm_web_kit.input.datajson import DataJson
from func_timeout import FunctionTimedOut, func_timeout
version="001"
sub_dir = "202401"
input_paths =[f's3://crawl-data/blog_sina_com_cn/gz_file/1729501052/']
platform = extract_platform_from_s3_path(input_paths[0])
platform_configs = {

    "zh-web-baijiahao": {

        "field_mappings": {
            "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video"
                            },
        "dataset_name": "baijiahao",
        "url":"url",
        "html":"content",
        "layout_field": "channel",
        "data_source_category":"JSON"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/{sub_dir}/v{version}/"

    },
    "zh-web-netease": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video"
                            },
        "dataset_name": "net-ease",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
    "zh-web-tencent": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "腾讯网":"article"
                            },
        "dataset_name": "tencent",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
     "zh-web-sohu": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article"
                            },
        "dataset_name": "souhu",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
    "zh-web-sina": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article",
                                "黑猫投诉":"forum",
                                "新浪网":"article"
                            },
        "dataset_name": "sina",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },

    "blog_sina_com_cn": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article",
                                "黑猫投诉":"forum",
                                
                            },
        "dataset_name": "sina_blog",
        "url":"url",
        "html":"html",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
    "DouBan": {
       
        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article",
                                "黑猫投诉":"forum",
                                "豆瓣网":""
                            },
        "dataset_name": "sina",
        "url":"url",
        "html":"html",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
}
platform_config = platform_configs.get(platform)
platform_config
# Out:
# {'field_mappings': {'track_id': 'track_id',
#   'page_layout_type_map': {'': 'article',
#    '文章': 'article',
#    '网易': 'article',
#    '视频': 'video',
#    '搜狐网': 'article',
#    '黑猫投诉': 'forum'},
#   'dataset_name': 'sina_blog',
#   'url': 'url',
#   'html': 'html',
#   'layout_field': 'f_name',
#   'data_source_category': 'HTML'},
#  'extractor_config': '/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc',
#  'output_template': 's3://llm-users-phdd2/jiangwenhao/article/blog_sina_com_cn/v001/'}

# %%
#安全解析函数（包含异常捕获）
def safe_json_loads(s):
    try:
        json.loads(s)
        return True
    except:
        return False


        
def transform_row(row, config: dict) -> Row:

    """根据平台配置转换行数据"""
    mappings = config
    from loguru import logger
    try:
        d = Row(
                track_id=getattr(row, mappings["track_id"],str(uuid.uuid4())),
                url=getattr(row, mappings["url"], ''),
                html=getattr(row, mappings["html"], ''),
                page_layout_type=mappings.get("page_layout_type_map").get(
                    getattr(row, mappings["layout_field"], ''),
                    "article"
                ),
                domain=extract_domain_info(getattr(row, mappings["url"], ''))['domain'],
                dataset_name=mappings["dataset_name"],
                data_source_category=mappings["data_source_category"],
                meta_info={"filename":row.filename}
            )
        return d 
    except Exception as e:
        # 记录更详细的错误信息
        error_info = {
            "error_data":Row(**d),
            "error_type": type(e).__name__,
            "error_message": str(e),
            "traceback": traceback.format_exc(),
        }
        # s3_doc_writer.write(error_info)
        d['__error'] = error_info
        logger.error(error_info)
        return Row(**d)
   
    

def extract_data(partition, broadcast_extractor_config_path):
    from llm_web_kit.extractor.extractor_chain import ExtractSimpleFactory
    from loguru import logger

    extractor_chain = ExtractSimpleFactory.create('/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc')
    timeout_seconds = 10
    # 为每个分区创建唯一的错误日志文件
    # partition_id = str(uuid.uuid4())
    # current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
    # error_log_path = f"s3://xyz-llm-users/xyz-users/yujia/CC-MAIN-2024-33/output/v002/error_logs/{current_time}_{partition_id}.json"
    # s3_doc_writer = S3DocWriter(path=error_log_path)
    for row in partition:
        try:

            d = row.asDict()
            input_data = DataJson(d)
            data_e: DataJson = func_timeout(timeout_seconds, extractor_chain.extract, args=(input_data,))
            #data_e: DataJson = extractor_chain.extract(input_data)
            
    
            yield Row(**data_e.to_dict())
        except FunctionTimedOut as e1:
                d['__error'] = {
                    "error_type":"TIMEOUT",
                    "error_message": "extract function timeout",
                    "traceback":"TIMEOUT"
                }

                yield Row(**d)
        except Exception as e:
                # 记录更详细的错误信息
                error_info = {
                    "error_data":Row(**d),
                    "error_type": type(e).__name__,
                    "error_message": str(e),
                    "traceback": traceback.format_exc(),
                }
                logger.error(error_info)
                # s3_doc_writer.write(error_info)
                d['__error'] = error_info

                yield Row(**d)
from pyspark.sql.functions import col
from pyspark.sql.functions import udf
from pyspark.sql.types import BooleanType         


spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.140.84.27:33802">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>llm_kit_cc</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import udf
from pyspark.sql.types import BooleanType
version="001"
sub_dir = "202401"

platform = extract_platform_from_s3_path(input_paths[0])

platform_config = platform_configs.get(platform)
platform_config

#config = {
#    "spark_conf_name": "spark_4",
#    "skip_success_check": True,
#    # 根据个人路径进行替换1
#    "spark.executorEnv.LLM_WEB_KIT_CFG_PATH": "/share/jiangwenhao/.llm-web-kit.jsonc",
#    "spark.dynamicAllocation.maxExecutors": "400",
#    "spark.executor.cores": "20"
#}
#spark = new_spark_session("llm_kit_cc", config)


print(f"路径: {input_paths[0]} → 平台: {platform}")


"""接收 spark 作为参数而不是持有它"""
platform_config = platform_configs.get(platform)
if not platform_config:
    raise ValueError(f"Unsupported platform: {platform}")

# Driver 端操作
input_df = read_any_path(spark, ",".join(input_paths), config)
print(f"读取数据结束")


broadcast_field_mappings = platform_config.get("field_mappings")
broadcast_extractor_config_path = platform_config.get("extractor_config") 




input_rdd = df_filtered.rdd.map(lambda x: Row(**{**json.loads(x.value), "filename": x.filename}))


transformed_rdd = input_rdd.map(
    lambda row: transform_row(row, broadcast_field_mappings)
).repartition(6000)


print(transformed_rdd.getNumPartitions())
## 数据抽取（仅用抽取器配置路径）
processed_rdd = transformed_rdd.mapPartitions(
     lambda x:extract_data(
        x,broadcast_extractor_config_path = broadcast_extractor_config_path
    )
)


processed_rdd.count()
# processed_rdd_filter.count()
# Out:
# 路径: s3://crawl-data/blog_sina_com_cn/gz_file/1729501052/ → 平台: blog_sina_com_cn
# 读取数据结束
# 6000
# 28174242

# %%
processed_rdd_filter = processed_rdd.filter(lambda x:"__error" not in x).persist()
result_df = processed_rdd_filter.map(lambda x: Row(value=json_dumps(x.asDict()))).toDF()

# %%
write_any_path(result_df, platform_config["output_template"])
# Out:
# {'rows': 28174230,
#  'bytes': {'sum': 1509192879853,
#   'min': 471,
#   'max': 4047415,
#   'cnt': 28174230,
#   'avg': 53566.429},
#  'files': 6000,
#  'sub_paths': {}}

# %%
platform_config["output_template"]= 's3://llm-users-phdd2/jiangwenhao/article/zh-web-tencent/v001/'

# %%
result_df.take(1)[0].asDict()
# Out:
# {'value': '{"track_id":"45ded449-03b8-43e2-83aa-6ce108ea3d13","url":"https://new.qq.com/omn/20240103/20240103A020Q400","html":"<body> \\n <p>2023年12月28日，广东省学前教育领域2个国家级实验区和5个省级实验区正式启动，广东省各地学前教育工作者齐聚广州越秀，共同论道和擘画学前教育的高质量发展蓝图。期间，越秀区11所公办园邀请全省幼教从业者“浸润式”现场观摩，探索如何“敞开大门”办好园。</p> \\n <p><img src=\\"https://inews.gtimg.com/om_bt/OGlavVXX5r8gSaQKhkofOnszR8QRrMOF0NsHkN_6iU-FcAA/641\\"></p> \\n <p>“浸润式”观摩遇见教育美好</p> \\n <p>在日前举行的学前教育高质量发展交流研讨会中，越秀区11所公办幼儿园敞开大门，开启分论坛活动和“浸润式”现场观摩，邀请全省其他地市的教研员、幼教从业者零距离走进孩子们的一日生活，感受越秀区幼儿园的实力。</p> \\n <p><img src=\\"https://inews.gtimg.com/om_bt/OhXfil4P3yZMVYPqe-EJ-cBd4aZAM37XtuIzKv-6mpaj0AA/641\\"></p> \\n <p>从2011年起，经过实施三期“学前教育行动计划”，越秀学前教育实现了从“幼有所育”到“幼有优育”的跨越式发展。近三年，越秀区几乎以一年一个实验区的争创速度，继先后获得“广东省学前教育改革发展实验区”“广东省学前教育高质量发展实验区”后，2022年，越秀区又成功创建国家级“幼儿园保育教育质量提升实验区”，高素质保教队伍数量逐年提高，“名师”“名园长”不断涌现，已初步建成了广覆盖、保基本、有质量、布局合理、公益普惠的学前教育公共服务体系。</p> \\n <p>越秀区幼儿园到底好在哪里？越秀区打开大门供人参观的底气何在？羊城晚报记者走进各大幼儿园——</p> \\n <p>上月29日上午，在广州市越秀区东方红幼儿园内，近百位幼教观摩者用一个小时时间感受了这所名园的方方面面。在园内水池边，几个孩子专注地用塑料瓶子组建“火箭”和“小船”，利用水力推动其前行；几十米开外的创作区，孩子们在用枯叶、花朵和松果装饰着一顶“帐篷”；还有在纸板上肆意艺术创作的孩子、玩泥巴“玩得很野”的孩子，戏水池里打水仗很开心的孩子……每位参观人员都有一种感受：走进东方红幼儿园，第一眼看到的都是孩子，而几乎注意不到老师的存在。</p> \\n <p><img src=\\"https://inews.gtimg.com/om_bt/Ow6lxuXOu1RqgLUW5Mi1P_JtlYR2hpFNHlH2N0tj-rD_QAA/641\\"></p> \\n <p>对此，越秀区东方红幼儿园园长林举卿说：“大家可能会觉得东方红幼儿园的老师好像都不存在，但是你仔细去追寻，你又发现她们确确实实在跟孩子们在一起——这种感觉说起来容易，但做起来难——我们花了好多年的时间。”</p> \\n <p>惠州市惠东县教师发展中心林慧婷是参观者之一，她在观摩完后感慨，无论是老师的教育行为，还是孩子的自主表现，抑或是环境的丰富、游戏材料的支持，都能感受到这家幼儿园对孩子放手、给孩子自主学习和环境的新理念。此外，在当天上午的交流研讨活动中，她也有感于越秀区幼儿园扎实、深度的教研水平和教研氛围。“‘孩子在前，老师在后’的放手的理念值得我们学习，另外，我们自主游戏的材料可以更加丰富、多元。”她说。</p> \\n <p>同样敞开大门的，还有广东育才幼儿院一院。大草坪、大操场、趣味活动空间……孩子们在其中自由玩耍，绘画、手工、搭积木、运动，每一个孩子都能在这一场域内找到发挥自己兴趣的合适空间。</p> \\n <p>深圳市福田区第四幼儿园园长郄超在参观完后感叹：“有足够空间支持的时候，能够看到孩子的整个游戏现场呈现出来是非常丰富和高水平的，这是空间所赋予孩子的发展。”</p> \\n <p>作为广东省学前教育科研基地幼儿园、广东省新课程项目领衔园、广东省融合教育教研基地，广东省育才幼儿院一院院长陈莹表示，这里一直在努力发挥专业引领作用，以课题研究、专题讲座、跟岗研修、项目实践等途径，带领省市区幼儿园开展教育创新改革。</p> \\n <p>广东省育才幼儿院二院院长蔡晓冰则表示：“我们幼儿园梳理出了螺旋递进式幼儿自主游戏的教育方式，想利用这次开发交流的机会，将经验分享给各位同行，通过专家老师的支持和点评，来促进更多教师对幼儿的理解和支持，做一个有力量的老师。”</p> \\n <p>在越秀区中六幼儿园，“偶文化”是其特色名片。中六将木偶戏这一传统民俗艺术作为抓手，从20世纪50年代到如今不断更新发展，逐渐形成了偶剧特色园本发展体系。</p> \\n <p>园长陈欣生表示，作为国家级幼儿园保育教育质量提升实验区中的一分子，中六将继续基于园所木偶文化的传承与发展，通过支教、结对帮扶、成果展示、著作出版等形式向省内外的幼教同行进行辐射推广，分享自身的特色发展探索之路。</p> \\n <p>珠海市鹤洲新区中心教研组成员郑美琪在参观完园所后表示：“越秀区有许多历史悠久的幼儿园，浓重的文化积淀是非常令人羡慕的优势，中六的木偶戏特色名片对于新办的幼儿园来说也是一种启发，说明我们在办园过程中就应该注意去摸索并发现自己的亮点，然后再慢慢传承下去，发扬光大。”</p> \\n <p>交流、探讨、共享……越秀区学前教育以开放心态，展现着自身的多样和独特。广东省公安厅幼儿院院长史力玲告诉记者，教育原本就应有开放的心态，打开大门就是用更开放的态度聆听不同的声音和建议，实现“美人之美”“各美其美”。</p> \\n <p>广西师范大学教授、博士生导师，中国学前教育研究会理事长侯莉敏指出，衡量幼儿园教育质量好坏的维度不能仅仅局限于孩子未来的发展如何，更要关注到幼儿园所提供的师幼互动关系、教育活动质量以及环境资源规划等各方面要素，来综合考量幼儿园教育质量的体验与评价，只有将各种参考指标相互联系起来，幼儿园保教质量的衡量标准才能逐步健全和完善。</p> \\n <p>广东启动七个国家级和省级学前教育实验区探索</p> \\n <p>作为广东学前教育的“高地”，越秀区此次成为国家级幼儿园保育教育质量提升实验区；同为“国字头”的，还有成为国家级完善普惠性学前教育保障机制实验区的广州市番禺区——前者重点考察科学的保教观念，聚焦保教过程，提升学前教育的发展质量，后者重点关注政府主体责任落实、财政投入保障、师资配备与待遇保障等。</p> \\n <p>为扩大实践探索辐射范围，广东省教育厅同步立项深圳市盐田区和惠州市龙门县2个省级完善普惠性学前教育保障机制实验区，深圳市福田区、汕头市金平区和佛山市禅城区3个省级幼儿园保育教育质量提升实验区，建设周期为三年。</p> \\n <p>广东省教育厅党组成员、副厅长李璧亮介绍，围绕党和国家关于学前教育的重要战略决策，广东省实施了四期学前教育发展提升计划，2020-2023年省政府连续将学前教育列入省十件民生实事，大力实施学前教育“5080”攻坚工程和科学保教示范工程。全省幼儿园有21566所，在园幼儿有498万人，学前三年毛入园率达100%，2019年以来全省增加公办幼儿园学位120余万个，公办园和普惠性民办园在园幼儿占比达87%，“入园难、入园贵”问题得到了有效缓解。</p> \\n <p>各地推进学前教育普及普惠安全优质有哪些经验？学前教育改革实验区的启动后，将做些什么？越秀区委常委、常务副区长郭环介绍，越秀区将继续完善人才培养体系，严格按照国家、省、市有关规定，核准教职工配备学历资质和工资待遇。幼儿园园长、教师定期培训和全员轮训之路，实施未来园长教师储备与培养计划，全面提升幼儿园园长、教师素质。强化师德师风建设，提高教师职业素养，培养热爱幼教、热爱幼儿的职业情怀。接下来，越秀区将以推进国家级“幼儿园保育教育质量提升实验区”为契机，扩优提质，探索形成区域教育高质量发展的经验范式。</p> \\n <p>番禺区教育局党组书记、局长曾敏表示，未来，番禺区将重点围绕健全学前教育财政投入制度；加强幼儿园收费监管和提高幼儿园教师工资待遇，落实幼儿园教师社会保障政策三个主要试点任务开展建设。聚焦普及普惠、保障支持、健康安全、人才兴教等六方面，推动普惠性资源扩容增效；推行集团化城乡一体化改革，扩大发展区内10个幼教集团优质资源覆盖面；推广学区化治理模式等。以试点建设带动学前教育普惠优质发展，全力推进普惠共享、协调均衡、创新高效的高质量学前教育发展，打造粤港澳大湾区“番禺幼教”品牌，全力打造全国一流学前教育强区。</p> \\n <p>侯莉敏认为，可在实验区内开展一系列具体研究内容，包括：如何有效观察理解幼儿、如何在游戏当中支持幼儿解决问题、深度学习、理解游戏的价值，反思和改进幼儿园的自我评估，激发幼儿园教师内驱力来实施教研的改革，以及与家长合作等等。</p> \\n <p>文/记者&nbsp;崔文灿 李可欣 实习生 刘婧汐 杨林培</p> \\n</body>","page_layout_type":"article","domain":"new.qq.com","dataset_name":"tencent","data_source_category":"HTML","meta_i ...
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2643 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15920 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3472 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_157 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5943 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3686 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12327 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5847 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3861 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1993 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3804 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10489 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1429 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2639 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_14975 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2996 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_4181 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2635 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3741 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13091 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3686 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10511 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10582 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2636 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15613 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10529 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12740 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1381 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3834 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3493 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10539 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10426 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_17665 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13074 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_4332 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10426 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3888 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3826 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1122 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2963 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3756 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_242 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3789 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_14451 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_17714 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13091 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2641 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2644 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10507 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2690 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_508 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3741 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_463 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_14975 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2384 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12802 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2639 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10401 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13246 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10582 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13074 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15826 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2635 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_17714 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15920 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13054 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15780 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1687 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_3097 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15848 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_2605 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2641 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10364 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3820 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13207 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3861 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3891 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_16262 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1466 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12740 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10511 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13664 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2636 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12327 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10494 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10364 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1736 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15615 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15701 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3789 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_16262 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2642 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2638 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10494 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3826 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2350 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_4752 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2638 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3756 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2642 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2638 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_548 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2642 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1075 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2657 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13246 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2639 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13124 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13207 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2043 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2637 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13054 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15826 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_201 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2640 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_815 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_854 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_14451 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5899 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3804 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3891 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12802 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15848 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2643 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3713 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13124 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2637 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2641 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_2299 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1772 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_769 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15615 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1160 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2644 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3511 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2635 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10401 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_17665 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5888 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2644 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15780 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2637 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3500 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2078 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5762 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10507 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15613 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10529 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2640 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13664 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10539 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2643 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3820 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10489 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2636 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2640 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15701 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3506 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3834 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_888 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5841 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5759 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2655 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2660 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3723 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10436 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2656 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10501 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2658 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10394 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1195 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3540 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3723 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_16618 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_16618 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3814 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10597 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3476 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10501 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3505 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_274 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3439 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2655 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1711 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3968 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10438 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3998 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_14586 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3814 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_17689 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_2629 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2664 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3447 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_4199 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10394 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12717 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2658 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10482 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3842 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10383 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3833 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15287 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2663 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2659 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_181 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12963 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3671 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3838 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1099 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3968 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12934 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1204 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15992 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_16871 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2658 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2655 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2662 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3701 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12963 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2122 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3795 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5947 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2656 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10383 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15438 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15652 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_581 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2660 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15185 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2423 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3780 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15479 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12872 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13069 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3838 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2664 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3780 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_16871 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15511 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2428 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2657 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3036 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_793 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_4199 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12927 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_14586 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3984 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15511 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10768 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10544 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_592 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3701 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15479 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12927 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_2017 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_2323 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15753 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2661 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10768 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12644 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2661 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15992 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2662 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10597 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2663 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12934 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2661 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3525 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_487 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2660 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2659 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13190 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2657 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2116 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15287 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13908 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12872 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15185 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12717 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5938 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_286 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2734 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3842 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_17689 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10484 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2664 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1809 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1816 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5807 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15753 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10436 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2663 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2657 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2656 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_3040 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13908 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5877 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1405 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10438 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_898 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13069 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10484 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1502 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10482 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3795 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15438 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3501 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15652 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13190 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1510 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2730 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5828 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3833 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2662 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12644 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2659 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10544 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3984 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10606 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_17505 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2647 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3990 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2645 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3751 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10592 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_16097 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_587 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_17050 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10559 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3844 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_2117 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10585 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3497 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1024 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5895 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_106 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3798 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3470 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3449 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_412 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2645 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2557 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2649 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_408 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2250 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15463 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13719 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_2423 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5853 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2653 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_101 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2647 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5793 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_14639 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_16488 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2650 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1505 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_3376 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10514 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2248 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15871 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10766 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2646 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_16488 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10622 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2650 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10665 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3913 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15639 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15688 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3990 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2647 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15639 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1330 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2648 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3856 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3851 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10510 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2864 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2654 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2654 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10592 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15871 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1636 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_16097 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3798 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2652 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3913 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2646 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_17034 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2648 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10445 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5867 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13012 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13192 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3681 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2651 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_14639 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3866 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3844 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13012 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13591 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5823 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12995 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3866 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10514 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10585 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2554 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_893 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_4057 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2651 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13206 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15733 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3996 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5810 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10766 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13591 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13719 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15463 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12995 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1636 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3486 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3463 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13621 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_14775 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_718 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_4057 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13621 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10606 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2654 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10510 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1329 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10559 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2652 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1942 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2648 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2645 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3751 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13192 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1943 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15733 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5948 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2649 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1199 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_14775 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1022 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10665 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_17034 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3856 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2646 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_281 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3474 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13206 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_715 !
# 25/03/12 20:09:00 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10622 !
# ...
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5876 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10464 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_17705 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2393 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_3181 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2699 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2678 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10614 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13827 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_16638 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10594 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2829 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3933 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10522 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15388 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2682 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3480 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2681 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10435 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2683 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2684 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2683 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12851 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12851 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12873 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_14018 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1601 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2681 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15858 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10469 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3432 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3468 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_17444 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3790 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2678 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2219 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2684 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10444 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13020 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_2741 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1607 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10442 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_16274 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_680 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3930 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5805 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15943 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15388 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3853 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1294 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15467 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5820 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15553 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10418 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3444 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10444 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12979 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1517 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2680 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12873 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2681 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10522 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13019 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_995 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2677 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_1908 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2679 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13019 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2675 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_2129 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3777 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15298 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15553 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10418 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5880 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2676 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1823 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3878 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2675 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2683 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3758 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15063 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15298 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10614 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_599 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5826 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3518 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3933 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3483 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_3309 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10442 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3930 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3829 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3730 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12979 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2684 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1913 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15467 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3755 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2525 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15063 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2215 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2676 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2678 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3829 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_2831 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_12822 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_77 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_15858 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13827 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_16274 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13020 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_689 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5812 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5907 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10498 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10594 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3529 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10469 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_987 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3755 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_16472 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2680 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3743 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_905 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3853 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10639 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13272 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_3939 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_4305 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_293 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3758 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_5806 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2675 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2682 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_1301 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2677 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2679 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2679 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13674 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2676 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_2682 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_12822 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10639 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_16638 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_10435 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_16472 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_373 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_66 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_150_2522 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_3790 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_36_2680 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_2435 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_15943 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_121_1211 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3730 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_13674 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_13272 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_17444 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3878 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_52_10498 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_14018 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_3777 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_53_2677 !
# 25/03/12 20:09:01 WARN BlockManagerMasterEndpoint: No more replicas available for rdd_144_383 !
