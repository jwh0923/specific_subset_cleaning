# %%
import os
from pyspark.sql import Row, SparkSession
from typing import Dict, Any
import json
import uuid
from functools import partial
from typing import Iterable, Dict, Any
# create spark session
from pyspark.sql import Row, DataFrame
from loguru import logger
from xinghe.spark import *
from app.common.json_util import *

from xinghe.s3 import *


import uuid
import traceback
from datetime import datetime
from llm_web_kit.input.datajson import DataJson
from func_timeout import FunctionTimedOut, func_timeout

#| track_id                  | uuid                           | 全局唯一的ID                                                                                                        | 是              |
#| dataset_name              | str                            | 数据集的名字（全局唯一），这个名字是管理员输入的，然后做索引的时候带到index里来                                     | 是              |
#| data_source_category      | str                            | 这一行数据代表的是HTML，PDF，EBOOK,CC,labCC类型                                                                     | 是，此处是 HTML |
#| html                      | 字符串                         | 以UTF-8为编码的HTML文件全文                                                                                         | 是              |
#| url                       | 字符串                         | 这个文件的来源网址                                                                                                  | 是              |
#| file_bytes                | 整数                           | 文件的size, 单位是byte                                                                                              | 是              |
#| meta_info                 | 字典                           | 存放关于文件的元信息:如果能从文件里获取到作者，制作日期等信息。或者数据本身就带有一些其他的信息都放入到这个字段里。 | 是              |
#| meta_info->input_datetime | 其格式为 `yyyy-mm-dd HH:MM:SS` | 生成这个json索引文件这一条数据的时间，可以不用那么精确                                                              | 是              |


def process_platform_data(spark: SparkSession, config,platform: str, input_paths: list, version: str = "001"):
    """接收 spark 作为参数而不是持有它"""
    platform_config = platform_configs.get(platform)
    if not platform_config:
        raise ValueError(f"Unsupported platform: {platform}")

    # Driver 端操作
    input_df = read_any_path(spark, ",".join(input_paths), config)
    print(f"读取数据结束")
    # 准备 Worker 端配置
    worker_config = {
        "field_mappings": platform_config.get("field_mappings"),
        "extractor_config": platform_config.get("extractor_config")
    }
    # 分别广播不同配置
    broadcast_field_mappings = spark.sparkContext.broadcast(worker_config["field_mappings"])
    broadcast_extractor_config_path = spark.sparkContext.broadcast(worker_config["extractor_config"])  # 广播路径

    print("原始数据json结构")
    input_rdd = input_df.rdd.map(lambda x: Row(**{**json.loads(x.value), "filename": x.filename})).cache()
  #  pandas_df = input_rdd.toDF().toPandas()
  #  print(pandas_df)
    print(input_rdd.take(1)[0].asDict().keys())
    # 数据转换（仅用字段映射）
    transformed_rdd = input_rdd.map(
        lambda row: transform_row(row, broadcast_field_mappings.value)
    )
   
    print("formatter数据结束")
    # 数据抽取（仅用抽取器配置路径）
    processed_rdd = transformed_rdd.mapPartitions(
         lambda x:extract_data(
            x,broadcast_extractor_config_path = broadcast_extractor_config_path.value
        )
    )
    print("extractor数据结束")
    print("写入数据中")
   
    # 输出结果Row(value=json.dumps(x.asDict()))).toDF()
    write_any_path(processed_rdd.map(lambda x: Row(value=json.dumps(x.asDict()))).toDF(), platform_config["output_template"],config)
    print("写入数据结束")

    # 清理广播变量
    broadcast_field_mappings.unpersist()
    broadcast_extractor_config_path.unpersist()



def transform_row(row, config: dict) -> Row:
    """根据平台配置转换行数据"""
    mappings = config

    return Row(
        track_id=getattr(row, mappings["track_id"],str(uuid.uuid4())),
        url=getattr(row, mappings["url"], ''),
        html=getattr(row, mappings["html"], ''),
        page_layout_type=mappings.get("page_layout_type_map").get(
            getattr(row, mappings["layout_field"], ''),
            "article"
        ),
        domain=extract_domain_info(getattr(row, mappings["url"], ''))['domain'],
        dataset_name=mappings["dataset_name"],
        data_source_category=mappings["data_source_category"],
        meta_info={"filename":row.filename}
    )




def extract_data(partition, broadcast_extractor_config_path):
    from loguru import logger
    extractor_chain = ExtractSimpleFactory.create('/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc')
    timeout_seconds = 10
    # 为每个分区创建唯一的错误日志文件
    # partition_id = str(uuid.uuid4())
    # current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
    # error_log_path = f"s3://xyz-llm-users/xyz-users/yujia/CC-MAIN-2024-33/output/v002/error_logs/{current_time}_{partition_id}.json"
    # s3_doc_writer = S3DocWriter(path=error_log_path)
    try:
        for row in partition:
            d = row.asDict()
           
            input_data = DataJson(d)
            data_e: DataJson = func_timeout(timeout_seconds, extractor_chain.extract, args=(input_data,))
            #data_e: DataJson = extractor_chain.extract(input_data)
            yield Row(**data_e.to_dict())
    except FunctionTimedOut as e1:
            d['__error'] = {
                "error_type":"TIMEOUT",
                "error_message": "extract function timeout",
                "traceback":"TIMEOUT"
            }
            yield Row(**d)
    except Exception as e:
            # 记录更详细的错误信息
            error_info = {
                "error_type": type(e).__name__,
                "error_message": str(e),
                "traceback": traceback.format_exc(),
            }
            logger.error(error_info)
            # s3_doc_writer.write(error_info)
            d['__error'] = error_info
            yield Row(**d)
           


def _safe_extract(data: Dict, extractor, timeout: int = 10) -> Dict:
  
    """直接返回字典，避免生成器"""
    try:
        timeout_seconds = 10
        input_data = DataJson(data.asDict())
        print(input_data)
        data_e: DataJson = func_timeout(timeout_seconds, extractor.extract, \
                                                args=(input_data,))

        print(Row(**data_e.to_dict()))
        return data_e.to_dict() 
    except Exception as e:
        # 记录更详细的错误信息
        error_info = {
            "error_type": type(e).__name__,
            "error_message": str(e),
            "traceback": traceback.format_exc(),
        }
        logger.error(error_info)
        # s3_doc_writer.write(error_info)
        data['__error'] = error_info
        yield Row(**d)


from urllib.parse import urlparse

def extract_domain_info(url: str) -> dict:
    """从 URL 中提取完整的域名信息"""
    parsed = urlparse(url)
    netloc = parsed.netloc
    domain_parts = netloc.split(":")
    domain = domain_parts[0]  # 去除端口号
    root_domain = ".".join(domain.split(".")[-2:]) if len(domain.split(".")) >= 2 else domain

    return {
        "full_url": url,
        "netloc": netloc,
        "domain": domain,
        "root_domain": root_domain
    }
        
def handle_error(row: Dict, error: Exception) -> Dict:
    """统一错误处理"""
    row_dict = row.asDict()
    return {
     ** row,
    "__error": {
        "type": type(error).__name__,
        "message": str(error),
        "traceback": traceback.format_exc()
    }
    }

    
def extract_platform_from_s3_path(s3_path: str) -> str:
    """
    从 S3 路径中提取平台名称（存储桶后的第一个目录）
    
    示例输入: 
    - "s3://private-cooperate-data/zh-web-baijiahao/20241218_p1/"
    输出: "zh-web-baijiahao"
    
    - "s3://private-cooperate-data/DouBan/"
    输出: "DouBan"
    """
    # 分割路径并过滤空字符串
    parts = [p for p in s3_path.split("/") if p.strip() != ""]
    
    # 验证路径格式
    if len(parts) < 3:
        raise ValueError(f"无效的 S3 路径格式: {s3_path}")
    
    # 平台名称是存储桶后的第一个目录
    return parts[2]

#
#
# config = {
#     "spark_conf_name": "spark_4",
#     "skip_success_check": True,
#     "spark.executor.memory":"8g",
#     # 根据个人路径进行替换1
#     "spark.executorEnv.LLM_WEB_KIT_CFG_PATH": "/share/jiangwenhao/.llm-web-kit.jsonc",
#     "spark.dynamicAllocation.maxExecutors": "400"
# }
# paths = [
# #"s3://private-cooperate-data/zh-web-baijiahao/",
# #"s3://private-crawl-data/zh-web-netease/20241218_p1/",
#    "s3://private-crawl-data/zh-web-tencent/20241218_p1/",
#     "s3://private-crawl-data/zh-web-sohu/20241218_p1/",
#  #   "s3://private-crawl-data/zh-web-sina/20241218_p1/",
#    # "s3://crawl-data/blog_sina_com_cn/gz_file/1729501052/",
#    # "s3://private-cooperate-data/DouBan/"
#
#
# ]


# spark = new_spark_session("llm_kit_cc", config)
# version="008"
# for path in paths:
#     platform = extract_platform_from_s3_path(path)
#     print(f"路径: {path} → 平台: {platform}")
#     platform_configs = {
#
#     "zh-web-baijiahao": {
#
#         "field_mappings": {
#             "track_id":"track_id",
#             "page_layout_type_map" :{
#                                 "":"article",
#                                 "文章":"article",
#                                 "网易":'article',
#                                 "视频":"video"
#                             },
#         "dataset_name": "baijiahao",
#         "url":"url",
#         "html":"content",
#         "layout_field": "channel",
#         "data_source_category":"JSON"
#         },
#         "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
#         "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
#
#     },
#     "zh-web-netease": {
#
#         "field_mappings": {
#              "track_id":"track_id",
#             "page_layout_type_map" :{
#                                 "":"article",
#                                 "文章":"article",
#                                 "网易":'article',
#                                 "视频":"video"
#                             },
#         "dataset_name": "net-ease",
#         "url":"url",
#         "html":"content",
#         "layout_field": "f_name",
#         "data_source_category":"HTML"
#         },
#         "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
#         "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
#     },
#     "zh-web-tencent": {
#
#         "field_mappings": {
#              "track_id":"track_id",
#             "page_layout_type_map" :{
#                                 "":"article",
#                                 "文章":"article",
#                                 "网易":'article',
#                                 "视频":"video",
#                                 "腾讯网":"article"
#                             },
#         "dataset_name": "tencent",
#         "url":"url",
#         "html":"content",
#         "layout_field": "f_name",
#         "data_source_category":"HTML"
#         },
#         "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
#         "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
#     },
#      "zh-web-sohu": {
#
#         "field_mappings": {
#              "track_id":"track_id",
#             "page_layout_type_map" :{
#                                 "":"article",
#                                 "文章":"article",
#                                 "网易":'article',
#                                 "视频":"video",
#                                 "搜狐网":"article"
#                             },
#         "dataset_name": "souhu",
#         "url":"url",
#         "html":"content",
#         "layout_field": "f_name",
#         "data_source_category":"HTML"
#         },
#         "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
#         "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
#     },
#     "zh-web-sina": {
#
#         "field_mappings": {
#              "track_id":"track_id",
#             "page_layout_type_map" :{
#                                 "":"article",
#                                 "文章":"article",
#                                 "网易":'article',
#                                 "视频":"video",
#                                 "搜狐网":"article",
#                                 "黑猫投诉":"forum"
#                             },
#         "dataset_name": "sina",
#         "url":"url",
#         "html":"content",
#         "layout_field": "f_name",
#         "data_source_category":"HTML"
#         },
#         "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
#         "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
#     },
#
#     "blog_sina_com_cn": {
#
#         "field_mappings": {
#              "track_id":"track_id",
#             "page_layout_type_map" :{
#                                 "":"article",
#                                 "文章":"article",
#                                 "网易":'article',
#                                 "视频":"video",
#                                 "搜狐网":"article",
#                                 "黑猫投诉":"forum"
#                             },
#         "dataset_name": "sina",
#         "url":"url",
#         "html":"html",
#         "layout_field": "f_name",
#         "data_source_category":"HTML"
#         },
#         "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
#         "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
#     },
#     "DouBan": {
#
#         "field_mappings": {
#              "track_id":"track_id",
#             "page_layout_type_map" :{
#                                 "":"article",
#                                 "文章":"article",
#                                 "网易":'article',
#                                 "视频":"video",
#                                 "搜狐网":"article",
#                                 "黑猫投诉":"forum",
#                                 "豆瓣网":""
#                             },
#         "dataset_name": "sina",
#         "url":"url",
#         "html":"html",
#         "layout_field": "f_name",
#         "data_source_category":"HTML"
#         },
#         "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
#         "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
#     },
#}
    # 处理正式数据
 #  process_platform_data(
 #      spark=spark,
 #      config=config,
 #      platform=platform,
 #      input_paths=[path],
 #      version=version
 # )


    # 处理其他平台数据
    # processor.process_platform_data("other_platform", [...])

# %%
import os
from pyspark.sql import Row, SparkSession
from typing import Dict, Any
import json
import uuid
from functools import partial
from typing import Iterable, Dict, Any
# create spark session
from pyspark.sql import Row, DataFrame
from loguru import logger
from xinghe.spark import *
from app.common.json_util import *

from xinghe.s3 import *


import uuid
import traceback
from datetime import datetime
from llm_web_kit.input.datajson import DataJson
from func_timeout import FunctionTimedOut, func_timeout

# %%
version="001"
sub_dir = "202401"
input_paths =[f's3://crawl-data/blog_sina_com_cn/gz_file/1729501052/']
platform = extract_platform_from_s3_path(input_paths[0])
platform_configs = {

    "zh-web-baijiahao": {

        "field_mappings": {
            "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video"
                            },
        "dataset_name": "baijiahao",
        "url":"url",
        "html":"content",
        "layout_field": "channel",
        "data_source_category":"JSON"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/{sub_dir}/v{version}/"

    },
    "zh-web-netease": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video"
                            },
        "dataset_name": "net-ease",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
    "zh-web-tencent": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "腾讯网":"article"
                            },
        "dataset_name": "tencent",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
     "zh-web-sohu": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article"
                            },
        "dataset_name": "souhu",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
    "zh-web-sina": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article",
                                "黑猫投诉":"forum",
                                "新浪网":"article"
                            },
        "dataset_name": "sina",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },

    "blog_sina_com_cn": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article",
                                "黑猫投诉":"forum"
                            },
        "dataset_name": "sina",
        "url":"url",
        "html":"html",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
    "DouBan": {
       
        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article",
                                "黑猫投诉":"forum",
                                "豆瓣网":""
                            },
        "dataset_name": "sina",
        "url":"url",
        "html":"html",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
}
platform_config = platform_configs.get(platform)
platform_config
# Out:
# {'field_mappings': {'track_id': 'track_id',
#   'page_layout_type_map': {'': 'article',
#    '文章': 'article',
#    '网易': 'article',
#    '视频': 'video',
#    '搜狐网': 'article',
#    '黑猫投诉': 'forum'},
#   'dataset_name': 'sina',
#   'url': 'url',
#   'html': 'html',
#   'layout_field': 'f_name',
#   'data_source_category': 'HTML'},
#  'extractor_config': '/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc',
#  'output_template': 's3://llm-users-phdd2/jiangwenhao/article/blog_sina_com_cn/v001/'}

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.140.84.27:44077">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>llm_kit_cc</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
# input_paths =[f's3://zhuanxiang-hw60p/article/sina/v006/']





# Driver 端操作
# input_df = read_any_path(spark, ",".join(input_paths), config)

# %%
#def is_error__(row):
#    if "__error__" in row:  # 先检查键是否存在
#        return True
#    else:
#        return False
#
#def del_error__(row):
#    row.pop("__error__", None)  # 若键不存在，返回 None 且不报错
#    return row
#final_df = input_df.rdd.map(lambda x: json.loads(x.value)).filter(is_error__)
#final_df.take(1)[0]
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[9], line 11
#       9     return row
#      10 final_df = input_df.rdd.map(lambda x: json.loads(x.value)).filter(is_error__)
# ---> 11 final_df.take(1)[0]
#
# IndexError: list index out of range

# %%
write_any_path(final_df, "s3://zhuanxiang-hw60p/article/sina/v006/")
# Out:
# {'rows': 180601564,
#  'bytes': {'sum': 1711075727829,
#   'min': 516,
#   'max': 14546436,
#   'cnt': 180601564,
#   'avg': 9474.313},
#  'files': 2228,
#  'sub_paths': {}}

# %%
config = {
    "spark_conf_name": "spark_4",
    "skip_success_check": True,
    # 根据个人路径进行替换1
    "spark.executorEnv.LLM_WEB_KIT_CFG_PATH": "/share/jiangwenhao/.llm-web-kit.jsonc",
    "spark.dynamicAllocation.maxExecutors": "400",
    "spark.executor.cores": "20"
}
spark = new_spark_session("llm_kit_cc", config)


print(f"路径: {input_paths[0]} → 平台: {platform}")


"""接收 spark 作为参数而不是持有它"""
platform_config = platform_configs.get(platform)
if not platform_config:
    raise ValueError(f"Unsupported platform: {platform}")

# Driver 端操作
input_df = read_any_path(spark, ",".join(input_paths), config)
print(f"读取数据结束")
# 准备 Worker 端配置
worker_config = {
    "field_mappings": platform_config.get("field_mappings"),
    "extractor_config": platform_config.get("extractor_config")
}
# 分别广播不同配置
broadcast_field_mappings = worker_config["field_mappings"]
broadcast_extractor_config_path = worker_config["extractor_config"] # 广播路径
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# 路径: s3://crawl-data/blog_sina_com_cn/gz_file/1729501052/ → 平台: blog_sina_com_cn
# 读取数据结束

# %%
get_s3_config("s3://web-parse-hw60p/xuchao/zx-html-error/")
# Out:
# {'endpoint': 'http://10.140.104.11',
#  'ak': 'C68F0C5011E8E9C10F64',
#  'sk': '5HaI9RymQ3poL/BIC8g2ifksOwYAAAGVEejpySCi'}

# %%
# Out:
# {'value': '{"track_id":"3edfc1c9-c87b-480f-a26e-b90a7d54c24a","url":"https://blog.sina.com.cn/s/article_archive_1884248122_201206_1.html","status":200,"html":"<!DOCTYPE html PUBLIC \\"-//W3C//DTD XHTML 1.0 Transitional//EN\\" \\"//www.w3.org/TR/xhtml1/DTD/xhtml1-transitional.dtd\\"><html xmlns=\\"//www.w3.org/1999/xhtml\\"><head><script id=\\"sinaads-ck-script\\" charset=\\"utf-8\\" src=\\"//d4.sina.com.cn/litong/zhitou/sinaads/src/spec/sinaads_ck.js\\"></script><script src=\\"https://d8.sina.com.cn/litong/zhitou/wenjing28/js/postMan.js\\"></script>\\n<meta http-equiv=\\"Content-Type\\" content=\\"text/html; charset=utf-8\\">\\n<title>归档_安徽文学_新浪博客</title>\\n<meta http-equiv=\\"X-UA-Compatible\\" content=\\"IE=EmulateIE8,chrome=1\\">\\n<meta name=\\"renderer\\" content=\\"webkit\\">\\n<meta name=\\"keywords\\" content=\\"\\">\\n<meta name=\\"description\\" content=\\"\\">\\n<meta content=\\"always\\" name=\\"referrer\\">\\n<!--–[if lte IE 6]-->\\n<script type=\\"text/javascript\\">\\ntry{\\ndocument.execCommand(\\"BackgroundImageCache\\", false, true);\\n}catch(e){}\\n</script>\\n<!--[endif]–-->\\n<script type=\\"text/javascript\\">\\n    \\nwindow.staticTime=new Date().getTime();\\n;(function () {\\n    if(/\\\\/{2,}/.test(location.pathname)){\\n        location.href = \'//blog.sina.com.cn\' + location.pathname.replace(/\\\\/+/g,\'/\') + location.search;\\n    }\\n})();\\n</script>\\n<link rel=\\"pingback\\" href=\\"//upload.move.blog.sina.com.cn/blog_rebuild/blog/xmlrpc.php\\">\\n<link rel=\\"EditURI\\" type=\\"application/rsd+xml\\" title=\\"RSD\\" href=\\"//upload.move.blog.sina.com.cn/blog_rebuild/blog/xmlrpc.php?rsd\\">\\n<link href=\\"//blog.sina.com.cn/blog_rebuild/blog/wlwmanifest.xml\\" type=\\"application/wlwmanifest+xml\\" rel=\\"wlwmanifest\\">\\n<link rel=\\"alternate\\" type=\\"application/rss+xml\\" href=\\"//blog.sina.com.cn/rss/1884248122.xml\\" title=\\"RSS\\">\\n<link href=\\"//simg.sinajs.cn/blog7style/css/conf/blog/articlelist.css\\" type=\\"text/css\\" rel=\\"stylesheet\\"><style id=\\"tplstyle\\" type=\\"text/css\\">@charset \\"utf-8\\";@import url(\\"//simg.sinajs.cn/blog7newtpl/css/30/30_1/t.css\\");\\n</style>\\n<style id=\\"positionstyle\\" type=\\"text/css\\">\\n</style>\\n<style id=\\"bgtyle\\" type=\\"text/css\\">\\n</style>\\n<style id=\\"headtyle\\" type=\\"text/css\\">\\n</style>\\n<style id=\\"navtyle\\" type=\\"text/css\\">\\n</style>\\n\\n    <link href=\\"//mjs.sinaimg.cn//wap/project/blog_upload/1.0.6/index_v3/static/css/index_v3.min.css\\" type=\\"text/css\\" rel=\\"stylesheet\\">\\n    <script type=\\"text/javascript\\" src=\\"//mjs.sinaimg.cn//wap/project/blog_upload/1.0.7/index_v3/static/js/index_v3.min.js\\"></script>\\n    <style>\\n    .popup_blogUpdata{\\n      z-index:1200\\n    }\\n    .fl_bg{\\n      z-index:1100;\\n    }\\n    .articleCell .atc_main{\\n      width:340px!important;\\n    }\\n    </style>\\n<script src=\\"//i.sso.sina.com.cn/js/ssologin.js\\" charset=\\"utf-8\\" async=\\"\\"></script><script src=\\"//sjs.sinajs.cn/blog7/articlelist.js?737.js\\" charset=\\"utf-8\\"></script><script src=\\"//d5.sina.com.cn/litong/zhitou/sinaads/release/sinaads.js\\" charset=\\"utf-8\\"></script><script src=\\"//www.sinaimg.cn/unipro/pub/suda_s_v851c.js\\" charset=\\"utf-8\\"></script><iframe src=\\"https://sbeacon.sina.com.cn/data.html?1730559205404\\" id=\\"sudaDataFrame\\" scrolling=\\"no\\" style=\\"height: 0px; width: 1px; overflow: hidden;\\"></iframe><script src=\\"https://sbeacon.sina.com.cn/h.js\\"></script><iframe src=\\"https://sbeacon.sina.com.cn/ckctl.html\\" id=\\"ckctlFrame\\" scrolling=\\"no\\" style=\\"height: 0px; width: 1px; overflow: hidden;\\"></iframe></head>\\n<body><div id=\\"sinaadToolkitBox0\\" class=\\"sinaad-toolkit-box\\" style=\\"position: fixed; width: 120px; height: 288px; z-index: 99999; display: block; left: 0px; top: 120px;\\"><div style=\\"width: 120px; height: 18px; position: absolute; right: 0px; top: 270px; z-index: 10000; background: url(&quot ...
#  'filename': 's3://crawl-data/blog_sina_com_cn/gz_file/1729501052/fdc31261-148d-4715-8b37-ca549727a5e3.jsonl.gz'}

# %%
# input_df = read_any_path(spark, ",".join(['s3a://private-crawl-data/zh-web-tencent/20241218_p1/2020/1733715370691.json.gz']), config)
# input_df.show()
input_df.take(1)[0]
# Out:
# 25/03/14 11:28:27 WARN YarnScheduler: Initial job has not accepted any resources; check your cluster UI to ensure that workers are registered and have sufficient resources
# 28174242

# %%
from pyspark.sql.functions import col
from pyspark.sql.functions import udf
from pyspark.sql.types import BooleanType
#安全解析函数（包含异常捕获）
def safe_json_loads(s):
    try:
        json.loads(s)
        return True
    except:
        return False
# 将Python函数注册为Spark UDF
safe_json_udf = udf(safe_json_loads, BooleanType())

# 在filter中使用UDF生成的Column表达式
df_filtered = input_df.filter(safe_json_udf(col("value")))

broadcast_field_mappings
# Out:
# {'track_id': 'track_id',
#  'page_layout_type_map': {'': 'article',
#   '文章': 'article',
#   '网易': 'article',
#   '视频': 'video',
#   '搜狐网': 'article',
#   '黑猫投诉': 'forum'},
#  'dataset_name': 'sina',
#  'url': 'url',
#  'html': 'html',
#  'layout_field': 'f_name',
#  'data_source_category': 'HTML'}

# %%
df_filtered.count()
# Out:
# ERROR:root:KeyboardInterrupt while sending command.            (49 + 188) / 237]
# Traceback (most recent call last):
#   File "/share/jiangwenhao/envs/code_clean_venv/lib/python3.10/site-packages/py4j/java_gateway.py", line 1038, in send_command
#     response = connection.send_command(command)
#   File "/share/jiangwenhao/envs/code_clean_venv/lib/python3.10/site-packages/py4j/clientserver.py", line 511, in send_command
#     answer = smart_decode(self.stream.readline()[:-1])
#   File "/share/python/3.10.9/lib/python3.10/socket.py", line 705, in readinto
#     return self._sock.recv_into(b)
# KeyboardInterrupt
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 1
# ----> 1 df_filtered.count()
#
# File ~/envs/code_clean_venv/lib/python3.10/site-packages/pyspark/sql/dataframe.py:1193, in DataFrame.count(self)
#    1170 def count(self) -> int:
#    1171     """Returns the number of rows in this :class:`DataFrame`.
#    1172
#    1173     .. versionadded:: 1.3.0
#    (...)
#    1191     3
#    1192     """
# -> 1193     return int(self._jdf.count())
#
# File ~/envs/code_clean_venv/lib/python3.10/site-packages/py4j/java_gateway.py:1321, in JavaMember.__call__(self, *args)
#    1314 args_command, temp_args = self._build_args(*args)
#    1316 command = proto.CALL_COMMAND_NAME +\
#    1317     self.command_header +\
#    1318     args_command +\
#    1319     proto.END_COMMAND_PART
# -> 1321 answer = self.gateway_client.send_command(command)
#    1322 return_value = get_return_value(
#    1323     answer, self.gateway_client, self.target_id, self.name)
#    1325 for temp_arg in temp_args:
#
# File ~/envs/code_clean_venv/lib/python3.10/site-packages/py4j/java_gateway.py:1038, in GatewayClient.send_command(self, command, retry, binary)
#    1036 connection = self._get_connection()
#    1037 try:
# -> 1038     response = connection.send_command(command)
#    1039     if binary:
#    1040         return response, self._create_connection_guard(connection)
#
# File ~/envs/code_clean_venv/lib/python3.10/site-packages/py4j/clientserver.py:511, in ClientServerConnection.send_command(self, command)
#     509 try:
#     510     while True:
# --> 511         answer = smart_decode(self.stream.readline()[:-1])
#     512         logger.debug("Answer received: {0}".format(answer))
#     513         # Happens when a the other end is dead. There might be an empty
#     514         # answer before the socket raises an error.
#
# File /share/python/3.10.9/lib/python3.10/socket.py:705, in SocketIO.readinto(self, b)
#     703 while True:
#     704     try:
# --> 705         return self._sock.recv_into(b)
#     706     except timeout:
#     707         self._timeout_occurred = True
#
# KeyboardInterrupt:

# %%
input_rdd = df_filtered.rdd.map(lambda x: Row(**{**json.loads(x.value), "filename": x.filename}))

# %%
def transform_row(row, config: dict) -> Row:

    """根据平台配置转换行数据"""
    mappings = config
    from loguru import logger
    try:
        d = Row(
                track_id=getattr(row, mappings["track_id"],str(uuid.uuid4())),
                url=getattr(row, mappings["url"], ''),
                html=getattr(row, mappings["html"], ''),
                page_layout_type=mappings.get("page_layout_type_map").get(
                    getattr(row, mappings["layout_field"], ''),
                    "article"
                ),
                domain=extract_domain_info(getattr(row, mappings["url"], ''))['domain'],
                dataset_name=mappings["dataset_name"],
                data_source_category=mappings["data_source_category"],
                meta_info={"filename":row.filename}
            )
        return d 
    except Exception as e:
        # 记录更详细的错误信息
        error_info = {
            "error_data":Row(**d),
            "error_type": type(e).__name__,
            "error_message": str(e),
            "traceback": traceback.format_exc(),
        }
        # s3_doc_writer.write(error_info)
        d['__error'] = error_info
        logger.error(error_info)
        return Row(**d)
   
    
 
#  pandas_df = input_rdd.toDF().toPandas()
#  print(pandas_df)

# 数据转换（仅用字段映射）
transformed_rdd = input_rdd.map(
    lambda row: transform_row(row, broadcast_field_mappings)
).repartition(6000)

# %%
transformed_rdd.count()

# %%
transformed_not_error_rdd = transformed_rdd.filter(lambda x:"__error" not in x)
transformed_not_error_rdd.count()

# %%
transformed_not_empty_rdd = transformed_not_error_rdd.filter(lambda x :x.html !='').cache()
transformed_not_empty_rdd.count()

# %% [markdown]
# ## 测试 To_Main_HTML

# %%
#timeout_seconds = 10
#extractor_chain = ExtractSimpleFactory.create('/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc')
#data_e: DataJson = func_timeout(timeout_seconds, extractor_chain.extract, args=(input_data,))
#d = json.loads(data_e.to_json())
#d['to_main_html'] = data_e.get_content_list().to_main_html()
#d

# %%
# transformed_rdd_1 = transformed_rdd.filter(lambda x: "<!--VIDEO_0-->"  not in x.html)
# transformed_rdd_2 = transformed_rdd_1.filter(lambda x: "<!--MUSIC_0-->" not in x.html)
# transformed_rdd_2 = transformed_rdd_2.cache()
transformed_not_empty_rdd.cache()
# 18660
# 62
# 50000-(18660+62)=31278
# Out:
# MapPartitionsRDD[54] at coalesce at NativeMethodAccessorImpl.java:0

# %% [markdown]
# ## Extractor

# %%
def extract_data(partition, broadcast_extractor_config_path):
    from llm_web_kit.extractor.extractor_chain import ExtractSimpleFactory
    from loguru import logger

    extractor_chain = ExtractSimpleFactory.create('/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc')
    timeout_seconds = 10
    # 为每个分区创建唯一的错误日志文件
    # partition_id = str(uuid.uuid4())
    # current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
    # error_log_path = f"s3://xyz-llm-users/xyz-users/yujia/CC-MAIN-2024-33/output/v002/error_logs/{current_time}_{partition_id}.json"
    # s3_doc_writer = S3DocWriter(path=error_log_path)
    for row in partition:
        try:

            d = row.asDict()
            input_data = DataJson(d)
            data_e: DataJson = func_timeout(timeout_seconds, extractor_chain.extract, args=(input_data,))
            #data_e: DataJson = extractor_chain.extract(input_data)
            
    
            yield Row(**data_e.to_dict())
        except FunctionTimedOut as e1:
                d['__error'] = {
                    "error_type":"TIMEOUT",
                    "error_message": "extract function timeout",
                    "traceback":"TIMEOUT"
                }

                yield Row(**d)
        except Exception as e:
                # 记录更详细的错误信息
                error_info = {
                    "error_data":Row(**d),
                    "error_type": type(e).__name__,
                    "error_message": str(e),
                    "traceback": traceback.format_exc(),
                }
                logger.error(error_info)
                # s3_doc_writer.write(error_info)
                d['__error'] = error_info

                yield Row(**d)
           


# 数据抽取（仅用抽取器配置路径）
processed_rdd = transformed_not_empty_rdd.mapPartitions(
     lambda x:extract_data(
        x,broadcast_extractor_config_path = broadcast_extractor_config_path
    )
)

# %%
spark
processed_rdd.take(1)[0]
# Out:
# DEBUG:Command to send: c
# o511
# partitions
# e
#
# DEBUG:Answer received: !ylo703
# DEBUG:Command to send: c
# o703
# size
# e
#
# DEBUG:Answer received: !yi6000
# DEBUG:Command to send: r
# u
# PythonRDD
# rj
# e
#
# DEBUG:Answer received: !ycorg.apache.spark.api.python.PythonRDD
# DEBUG:Command to send: r
# m
# org.apache.spark.api.python.PythonRDD
# runJob
# e
#
# DEBUG:Answer received: !ym
# DEBUG:Command to send: c
# o421
# sc
# e
#
# DEBUG:Answer received: !yro704
# DEBUG:Command to send: r
# u
# PythonUtils
# rj
# e
#
# DEBUG:Answer received: !ycorg.apache.spark.api.python.PythonUtils
# DEBUG:Command to send: r
# m
# org.apache.spark.api.python.PythonUtils
# getBroadcastThreshold
# e
#
# DEBUG:Answer received: !ym
# DEBUG:Command to send: c
# z:org.apache.spark.api.python.PythonUtils
# getBroadcastThreshold
# ro421
# e
#
# DEBUG:Answer received: !yL1048576
# DEBUG:Command to send: r
# u
# SimplePythonFunction
# rj
# e
#
# DEBUG:Answer received: !ycorg.apache.spark.api.python.SimplePythonFunction
# DEBUG:Command to send: i
# java.util.HashMap
# e
#
# DEBUG:Answer received: !yao705
# DEBUG:Command to send: c
# o705
# put
# sJAVA_HOME
# s/share/spark/jdk1.8.0_181-cloudera
# e
#
# DEBUG:Answer received: !yn
# DEBUG:Command to send: c
# o705
# put
# sBASE_DIR
# s/share/dataproc/code-clean
# e
#
# DEBUG:Answer received: !yn
# DEBUG:Command to send: c
# o705
# put
# sMKL_NUM_THREADS
# s1
# e
#
# DEBUG:Answer received: !yn
# DEBUG:Command to send: c
# o705
# put
# sOPENBLAS_NUM_THREADS
# s1
# e
#
# DEBUG:Answer received: !yn
# DEBUG:Command to send: c
# o705
# put
# sPYTHONPATH
# s/share/dataproc/code-clean:.
# e
#
# DEBUG:Answer received: !yn
# DEBUG:Command to send: c
# o705
# put
# sPYSPARK_EXECUTOR_MEMORY_MB
# s4096
# e
#
# DEBUG:Answer received: !yn
# DEBUG:Command to send: c
# o705
# put
# sLLM_WEB_KIT_CFG_PATH
# s/share/jiangwenhao/.llm-web-kit.jsonc
# e
#
# DEBUG:Answer received: !yn
# DEBUG:Command to send: c
# o705
# put
# sPYTHONHASHSEED
# s0
# e
#
# DEBUG:Answer received: !yn
# DEBUG:Command to send: i
# java.util.ArrayList
# e
#
# DEBUG:Answer received: !ylo706
# DEBUG:Command to send: i
# java.util.ArrayList
# e
#
# DEBUG:Answer received: !ylo707
# DEBUG:Command to send: i
# org.apache.spark.api.python.SimplePythonFunction
# ...
# ro705
# ro706
# s/share/jiangwenhao/envs/code_clean_venv/bin/python
# s3.10
# ro707
# ro424
# e
#
# DEBUG:Answer received: !yro708
# DEBUG:Command to send: r
# u
# PythonRDD
# rj
# e
#
# DEBUG:Answer received: !ycorg.apache.spark.api.python.PythonRDD
# DEBUG:Command to send: c
# o511
# rdd
# e
#
# DEBUG:Answer received: !yro709
# DEBUG:Command to send: i
# org.apache.spark.api.python.PythonRDD
# ro709
# ro708
# bFalse
# bFalse
# e
#
# DEBUG:Answer received: !yro710
# DEBUG:Command to send: c
# o710
# asJavaRDD
# e
#
# DEBUG:Answer received: !yro711
# DEBUG:Command to send: i
# java.util.ArrayList
# e
#
# DEBUG:Answer received: !ylo712
# DEBUG:Command to send: c
# o712
# add
# i0
# e
#
# DEBUG:Answer received: !ybtrue
# DEBUG:Command to send: c
# z:org.apache.spark.api.python.PythonRDD
# runJob
# ro704
# ro711
# ro712
# e
#
# DEBUG:Command to send: m                                            (0 + 1) / 1]
# d
# o705
# e
#
# DEBUG:Answer received: !yv
# DEBUG:Command to send: m
# d
# o706
# e
#
# DEBUG:Answer received: !yv
# DEBUG:Command to send: m
# d
# o707
# e
#
# DEBUG:Answer received: !yv
# DEBUG:Answer received: !yto713
# DEBUG:Command to send: a
# e
# o713
# e
#
# DEBUG:Answer received: !yi3
# DEBUG:Command to send: a
# g
# o713
# i0
# e
#
# DEBUG:Answer received: !yi38877
# DEBUG:Command to send: a
# e
# o713
# e
#
# DEBUG:Answer received: !yi3
# DEBUG:Command to send: a
# g
# o713
# i1
# e
#
# DEBUG:Answer received: !ys87c93982d3653823c77e6bcfe6b6f9cec80593d45074386c6e97d07fb2d56e55
# Row(track_id='c5825dc9-dd61-4ef3-9517-89bab95dfdae', url='https://tousu.sina.com.cn/complaint/view/17358758620#gsdata_cmd5=60d4284ce0d5ebbf73a11d28c5d298db', html='<div class="ts-d-item"> \n <!-- 底部处理流程头像部分 --> \n <div class="ts-d-user clearfix"> \n  <img src="" alt="" class="avatar"> \n  <span class="u-name">黑猫消费者服务平台</span> \n  <span class="u-status">商家处理中</span> \n </div> \n <div class="ts-d-cont"> \n  <p>已分配商家 京东客服</p> \n  <br> \n  <p></p> \n </div> \n</div>', page_layout_type='forum', domain='tousu.sina.com.cn', dataset_name='sina', data_source_category='HTML', meta_info={'filename': 's3://private-crawl-data/zh-web-sina/20241218_p1/2022/1732884424577.json.gz', 'statics': {'paragraph': 3, 'paragraph.text': 3}}, content_list=[[{'type': 'paragraph', 'raw_content': '<div class="ts-d-item"><div class="ts-d-user clearfix"><span class="u-name">黑猫消费者服务平台</span></div></div>', 'content': [{'c': '黑猫消费者服务平台', 't': 'text'}]}, {'type': 'paragraph', 'raw_content': '<div class="ts-d-item"><div class="ts-d-user clearfix"><span class="u-status">商家处理中</span></div></div>', 'content': [{'c': '商家处理中', 't': 'text'}]}, {'type': 'paragraph', 'raw_content': '<div class="ts-d-item"><div class="ts-d-cont"><p>已分配商家 京东客服</p></div></div>', 'content': [{'c': '已分配商家 京东客服', 't': 'text'}]}]])
# DEBUG:Command to send: m
# d
# o712
# e
#
# DEBUG:Answer received: !yv
# DEBUG:Command to send: m
# d
# o713
# e
#
# DEBUG:Answer received: !yv

# %% [markdown]
# ## 排除error 数据

# %%
processed_rdd_filter = processed_rdd.filter(lambda x:"__error" not in x).persist()

# %%
processed_rdd_filter.count()
# Out:
# [Stage 8:===========>                                          (50 + 187) / 237]

# %%
processed_rdd_error_filter = processed_rdd.filter(lambda x:"__error"  in x)
write_any_path(processed_rdd_error_filter.map(lambda x: Row(value=json_dumps(x.asDict()))).toDF(),"s3://web-parse-hw60p/xuchao/zx-html-error/sina_blog/v001")
# Out:
# 25/03/13 18:34:53 WARN TaskSetManager: Lost task 1628.0 in stage 23.0 (TID 46535) (host-10-140-92-226 executor 218): TaskKilled (Stage cancelled)
# 25/03/13 18:35:01 WARN TaskSetManager: Lost task 5177.0 in stage 23.0 (TID 46045) (host-10-140-92-136 executor 183): TaskKilled (Stage cancelled)
# 25/03/13 18:35:03 WARN TaskSetManager: Lost task 2117.0 in stage 23.0 (TID 44120) (host-10-140-92-90 executor 140): TaskKilled (Stage cancelled)
# 25/03/13 18:35:10 WARN TaskSetManager: Lost task 1091.0 in stage 23.0 (TID 43811) (host-10-140-92-228 executor 193): TaskKilled (Stage cancelled)
# {'rows': 167733,
#  'bytes': {'sum': 5138783050,
#   'min': 1816,
#   'max': 2334641,
#   'cnt': 167733,
#   'avg': 30636.685},
#  'files': 6000,
#  'sub_paths': {}}

# %%
platform_config["output_template"]
# Out:
# 's3://llm-users-phdd2/jiangwenhao/article/zh-web-sina/v001/'

# %%
result_df = processed_rdd_filter.map(lambda x: Row(value=json_dumps(x.asDict()))).toDF()

# 输出结果Row(value=json.dumps(x.asDict()))).toDF()
#write_any_path(processed_rdd.map(lambda x: Row(value=json.dumps(x.asDict()))).toDF(), platform_config["output_template"],config)

platform_config
# Out:
# {'field_mappings': {'track_id': 'track_id',
#   'page_layout_type_map': {'': 'article',
#    '文章': 'article',
#    '网易': 'article',
#    '视频': 'video',
#    '搜狐网': 'article',
#    '黑猫投诉': 'forum',
#    '新浪网': 'article'},
#   'dataset_name': 'sina',
#   'url': 'url',
#   'html': 'content',
#   'layout_field': 'f_name',
#   'data_source_category': 'HTML'},
#  'extractor_config': '/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc',
#  'output_template': 's3://llm-users-phdd2/jiangwenhao/article/zh-web-sina/v001/'}

# %%
platform_config["output_template"]
# Out:
# 's3://llm-users-phdd2/jiangwenhao/article/zh-web-sina/v002/'
# 25/03/13 17:29:13 WARN TaskSetManager: Lost task 211.0 in stage 17.0 (TID 30427) (host-10-140-93-45 executor 241): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4973.0 in stage 17.0 (TID 34145) (host-10-140-93-29 executor 116): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4052.0 in stage 17.0 (TID 34681) (host-10-140-92-123 executor 34): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1117.0 in stage 17.0 (TID 35156) (host-10-140-93-63 executor 87): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 522.0 in stage 17.0 (TID 30992) (host-10-140-92-28 executor 250): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 521.0 in stage 17.0 (TID 30742) (host-10-140-92-28 executor 250): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 649.0 in stage 17.0 (TID 32503) (host-10-140-92-28 executor 249): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 669.0 in stage 17.0 (TID 33503) (host-10-140-92-28 executor 249): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3095.0 in stage 17.0 (TID 34218) (host-10-140-92-90 executor 137): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3066.0 in stage 17.0 (TID 31968) (host-10-140-92-90 executor 137): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1040.0 in stage 17.0 (TID 31906) (host-10-140-93-63 executor 87): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1020.0 in stage 17.0 (TID 31156) (host-10-140-93-63 executor 87): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1046.0 in stage 17.0 (TID 32656) (host-10-140-93-63 executor 87): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5031.0 in stage 17.0 (TID 30680) (host-10-140-93-29 executor 117): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5105.0 in stage 17.0 (TID 32680) (host-10-140-93-29 executor 117): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5135.0 in stage 17.0 (TID 33930) (host-10-140-93-29 executor 117): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 921.0 in stage 17.0 (TID 31150) (host-10-140-92-190 executor 164): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5073.0 in stage 17.0 (TID 34715) (host-10-140-92-113 executor 209): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5095.0 in stage 17.0 (TID 34965) (host-10-140-92-113 executor 209): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5683.0 in stage 17.0 (TID 33325) (host-10-140-92-222 executor 84): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5692.0 in stage 17.0 (TID 35075) (host-10-140-92-222 executor 84): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5035.0 in stage 17.0 (TID 33465) (host-10-140-92-113 executor 209): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4990.0 in stage 17.0 (TID 31965) (host-10-140-92-113 executor 209): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5694.0 in stage 17.0 (TID 35325) (host-10-140-92-222 executor 84): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5679.0 in stage 17.0 (TID 32825) (host-10-140-92-222 executor 84): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5678.0 in stage 17.0 (TID 32575) (host-10-140-92-222 executor 84): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5686.0 in stage 17.0 (TID 33825) (host-10-140-92-222 executor 84): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4993.0 in stage 17.0 (TID 32215) (host-10-140-92-113 executor 209): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 500.0 in stage 17.0 (TID 33779) (host-10-140-93-63 executor 85): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 505.0 in stage 17.0 (TID 34279) (host-10-140-93-63 executor 85): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 498.0 in stage 17.0 (TID 33279) (host-10-140-93-63 executor 85): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3045.0 in stage 17.0 (TID 30718) (host-10-140-92-90 executor 137): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 16.0 in stage 17.0 (TID 30480) (host-10-140-92-31 executor 254): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2674.0 in stage 17.0 (TID 34170) (host-10-140-92-152 executor 203): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2594.0 in stage 17.0 (TID 32420) (host-10-140-92-152 executor 203): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2616.0 in stage 17.0 (TID 32920) (host-10-140-92-152 executor 203): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1972.0 in stage 17.0 (TID 33763) (host-10-140-92-152 executor 205): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1041.0 in stage 17.0 (TID 32156) (host-10-140-93-63 executor 87): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3297.0 in stage 17.0 (TID 33848) (host-10-140-93-69 executor 155): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4716.0 in stage 17.0 (TID 35383) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4705.0 in stage 17.0 (TID 33883) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4350.0 in stage 17.0 (TID 31133) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4431.0 in stage 17.0 (TID 32383) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4698.0 in stage 17.0 (TID 32883) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4347.0 in stage 17.0 (TID 30883) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4702.0 in stage 17.0 (TID 33383) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4330.0 in stage 17.0 (TID 30632) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4407.0 in stage 17.0 (TID 31883) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4710.0 in stage 17.0 (TID 34383) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4714.0 in stage 17.0 (TID 34883) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5311.0 in stage 17.0 (TID 35357) (host-10-140-92-172 executor 52): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5309.0 in stage 17.0 (TID 34857) (host-10-140-92-172 executor 52): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5297.0 in stage 17.0 (TID 32357) (host-10-140-92-172 executor 52): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5282.0 in stage 17.0 (TID 30857) (host-10-140-92-172 executor 52): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2529.0 in stage 17.0 (TID 34418) (host-10-140-92-86 executor 110): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5292.0 in stage 17.0 (TID 31857) (host-10-140-92-172 executor 52): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2517.0 in stage 17.0 (TID 33668) (host-10-140-92-86 executor 110): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5981.0 in stage 17.0 (TID 32889) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2658.0 in stage 17.0 (TID 33074) (host-10-140-92-86 executor 114): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2661.0 in stage 17.0 (TID 33574) (host-10-140-92-86 executor 114): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2683.0 in stage 17.0 (TID 35074) (host-10-140-92-86 executor 114): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2671.0 in stage 17.0 (TID 34574) (host-10-140-92-86 executor 114): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2665.0 in stage 17.0 (TID 34074) (host-10-140-92-86 executor 114): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5551.0 in stage 17.0 (TID 33337) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5663.0 in stage 17.0 (TID 34837) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5444.0 in stage 17.0 (TID 31587) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5402.0 in stage 17.0 (TID 30586) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5420.0 in stage 17.0 (TID 31337) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5649.0 in stage 17.0 (TID 34587) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5455.0 in stage 17.0 (TID 32087) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5684.0 in stage 17.0 (TID 35087) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1477.0 in stage 17.0 (TID 33100) (host-10-140-92-194 executor 91): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1504.0 in stage 17.0 (TID 35100) (host-10-140-92-194 executor 91): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1514.0 in stage 17.0 (TID 35350) (host-10-140-92-194 executor 91): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1484.0 in stage 17.0 (TID 33850) (host-10-140-92-194 executor 91): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1002.0 in stage 17.0 (TID 32950) (host-10-140-92-190 executor 74): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1083.0 in stage 17.0 (TID 33200) (host-10-140-92-190 executor 74): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5999.0 in stage 17.0 (TID 35200) (host-10-140-92-190 executor 74): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1370.0 in stage 17.0 (TID 34200) (host-10-140-92-190 executor 74): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 862.0 in stage 17.0 (TID 32450) (host-10-140-92-190 executor 74): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 278.0 in stage 17.0 (TID 30700) (host-10-140-92-190 executor 74): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5997.0 in stage 17.0 (TID 34700) (host-10-140-92-190 executor 74): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5995.0 in stage 17.0 (TID 34450) (host-10-140-92-190 executor 74): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 715.0 in stage 17.0 (TID 31950) (host-10-140-92-190 executor 74): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5453.0 in stage 17.0 (TID 31837) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5858.0 in stage 17.0 (TID 32911) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5846.0 in stage 17.0 (TID 30660) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5870.0 in stage 17.0 (TID 35161) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5867.0 in stage 17.0 (TID 34411) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5851.0 in stage 17.0 (TID 31911) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5863.0 in stage 17.0 (TID 33911) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5859.0 in stage 17.0 (TID 33161) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5847.0 in stage 17.0 (TID 30911) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5862.0 in stage 17.0 (TID 33661) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5845.0 in stage 17.0 (TID 30408) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5856.0 in stage 17.0 (TID 32411) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5869.0 in stage 17.0 (TID 34911) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5857.0 in stage 17.0 (TID 32661) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5860.0 in stage 17.0 (TID 33411) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5865.0 in stage 17.0 (TID 34161) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5852.0 in stage 17.0 (TID 32161) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 694.0 in stage 17.0 (TID 34753) (host-10-140-92-28 executor 249): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1061.0 in stage 17.0 (TID 33241) (host-10-140-93-63 executor 61): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2982.0 in stage 17.0 (TID 32285) (host-10-140-92-90 executor 135): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2970.0 in stage 17.0 (TID 31535) (host-10-140-92-90 executor 135): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5300.0 in stage 17.0 (TID 32857) (host-10-140-92-172 executor 52): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 426.0 in stage 17.0 (TID 30550) (host-10-140-93-43 executor 103): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1166.0 in stage 17.0 (TID 30562) (host-10-140-93-34 executor 144): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1188.0 in stage 17.0 (TID 32063) (host-10-140-93-34 executor 144): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1185.0 in stage 17.0 (TID 31813) (host-10-140-93-34 executor 144): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1223.0 in stage 17.0 (TID 35063) (host-10-140-93-34 executor 144): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1171.0 in stage 17.0 (TID 30813) (host-10-140-93-34 executor 144): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2293.0 in stage 17.0 (TID 33819) (host-10-140-92-79 executor 166): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2456.0 in stage 17.0 (TID 32399) (host-10-140-93-69 executor 101): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2503.0 in stage 17.0 (TID 34649) (host-10-140-93-69 executor 101): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2426.0 in stage 17.0 (TID 31649) (host-10-140-93-69 executor 101): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1980.0 in stage 17.0 (TID 34654) (host-10-140-92-90 executor 171): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1933.0 in stage 17.0 (TID 32654) (host-10-140-92-90 executor 171): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1203.0 in stage 17.0 (TID 33813) (host-10-140-93-34 executor 144): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3485.0 in stage 17.0 (TID 34343) (host-10-140-92-90 executor 142): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3146.0 in stage 17.0 (TID 32630) (host-10-140-93-69 executor 156): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3162.0 in stage 17.0 (TID 32880) (host-10-140-93-69 executor 156): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3614.0 in stage 17.0 (TID 33997) (host-10-140-92-136 executor 187): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3541.0 in stage 17.0 (TID 31997) (host-10-140-92-136 executor 187): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2941.0 in stage 17.0 (TID 30495) (host-10-140-92-136 executor 187): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3531.0 in stage 17.0 (TID 31247) (host-10-140-92-136 executor 187): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3537.0 in stage 17.0 (TID 31747) (host-10-140-92-136 executor 187): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2653.0 in stage 17.0 (TID 32324) (host-10-140-92-86 executor 114): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5281.0 in stage 17.0 (TID 31446) (host-10-140-93-34 executor 181): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5411.0 in stage 17.0 (TID 34446) (host-10-140-93-34 executor 181): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5401.0 in stage 17.0 (TID 33946) (host-10-140-93-34 executor 181): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5279.0 in stage 17.0 (TID 31196) (host-10-140-93-34 executor 181): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5405.0 in stage 17.0 (TID 34196) (host-10-140-93-34 executor 181): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5325.0 in stage 17.0 (TID 31946) (host-10-140-93-34 executor 181): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1159.0 in stage 17.0 (TID 35150) (host-10-140-92-190 executor 164): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1071.0 in stage 17.0 (TID 33650) (host-10-140-92-190 executor 164): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1153.0 in stage 17.0 (TID 34846) (host-10-140-93-34 executor 143): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1151.0 in stage 17.0 (TID 34596) (host-10-140-93-34 executor 143): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1103.0 in stage 17.0 (TID 31346) (host-10-140-93-34 executor 143): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1125.0 in stage 17.0 (TID 32846) (host-10-140-93-34 executor 143): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1094.0 in stage 17.0 (TID 30595) (host-10-140-93-34 executor 143): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1112.0 in stage 17.0 (TID 32096) (host-10-140-93-34 executor 143): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1128.0 in stage 17.0 (TID 33346) (host-10-140-93-34 executor 143): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1052.0 in stage 17.0 (TID 33150) (host-10-140-92-190 executor 164): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1149.0 in stage 17.0 (TID 34400) (host-10-140-92-190 executor 164): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3413.0 in stage 17.0 (TID 34635) (host-10-140-92-172 executor 26): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3419.0 in stage 17.0 (TID 35135) (host-10-140-92-172 executor 26): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3404.0 in stage 17.0 (TID 34135) (host-10-140-92-172 executor 26): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1923.0 in stage 17.0 (TID 31904) (host-10-140-92-90 executor 171): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3105.0 in stage 17.0 (TID 32380) (host-10-140-93-69 executor 156): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3407.0 in stage 17.0 (TID 34385) (host-10-140-92-172 executor 26): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3375.0 in stage 17.0 (TID 32385) (host-10-140-92-172 executor 26): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3382.0 in stage 17.0 (TID 32635) (host-10-140-92-172 executor 26): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3591.0 in stage 17.0 (TID 32997) (host-10-140-92-136 executor 187): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3547.0 in stage 17.0 (TID 32247) (host-10-140-92-136 executor 187): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3630.0 in stage 17.0 (TID 34497) (host-10-140-92-136 executor 187): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2619.0 in stage 17.0 (TID 30573) (host-10-140-92-86 executor 114): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3414.0 in stage 17.0 (TID 34885) (host-10-140-92-172 executor 26): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3383.0 in stage 17.0 (TID 32885) (host-10-140-92-172 executor 26): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3421.0 in stage 17.0 (TID 35385) (host-10-140-92-172 executor 26): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3403.0 in stage 17.0 (TID 33885) (host-10-140-92-172 executor 26): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1734.0 in stage 17.0 (TID 34738) (host-10-140-92-70 executor 118): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1584.0 in stage 17.0 (TID 33604) (host-10-140-92-123 executor 109): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5753.0 in stage 17.0 (TID 35044) (host-10-140-93-63 executor 86): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 440.0 in stage 17.0 (TID 32044) (host-10-140-93-63 executor 86): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 325.0 in stage 17.0 (TID 30543) (host-10-140-93-63 executor 86): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5969.0 in stage 17.0 (TID 31139) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4590.0 in stage 17.0 (TID 33506) (host-10-140-92-190 executor 127): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4619.0 in stage 17.0 (TID 35256) (host-10-140-92-190 executor 127): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4606.0 in stage 17.0 (TID 34756) (host-10-140-92-190 executor 127): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4476.0 in stage 17.0 (TID 31006) (host-10-140-92-190 executor 127): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4604.0 in stage 17.0 (TID 34256) (host-10-140-92-190 executor 127): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4563.0 in stage 17.0 (TID 33006) (host-10-140-92-190 executor 127): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4459.0 in stage 17.0 (TID 30505) (host-10-140-92-190 executor 127): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2949.0 in stage 17.0 (TID 33984) (host-10-140-92-79 executor 167): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2914.0 in stage 17.0 (TID 33234) (host-10-140-92-79 executor 167): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5985.0 in stage 17.0 (TID 33639) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5979.0 in stage 17.0 (TID 32389) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 349.0 in stage 17.0 (TID 30726) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 564.0 in stage 17.0 (TID 31476) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1109.0 in stage 17.0 (TID 33226) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1490.0 in stage 17.0 (TID 34476) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3003.0 in stage 17.0 (TID 35234) (host-10-140-92-79 executor 167): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1045.0 in stage 17.0 (TID 32976) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1615.0 in stage 17.0 (TID 34976) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2276.0 in stage 17.0 (TID 32032) (host-10-140-92-90 executor 168): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2349.0 in stage 17.0 (TID 34032) (host-10-140-92-90 executor 168): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2358.0 in stage 17.0 (TID 34782) (host-10-140-92-90 executor 168): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1552.0 in stage 17.0 (TID 34726) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2269.0 in stage 17.0 (TID 31532) (host-10-140-92-90 executor 168): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1334.0 in stage 17.0 (TID 33976) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2307.0 in stage 17.0 (TID 32282) (host-10-140-92-90 executor 168): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2370.0 in stage 17.0 (TID 35282) (host-10-140-92-90 executor 168): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2268.0 in stage 17.0 (TID 31282) (host-10-140-92-90 executor 168): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5610.0 in stage 17.0 (TID 33615) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5641.0 in stage 17.0 (TID 34115) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5640.0 in stage 17.0 (TID 33865) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5557.0 in stage 17.0 (TID 32365) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5543.0 in stage 17.0 (TID 31365) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5507.0 in stage 17.0 (TID 31115) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5682.0 in stage 17.0 (TID 35115) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5466.0 in stage 17.0 (TID 30614) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5554.0 in stage 17.0 (TID 31865) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5591.0 in stage 17.0 (TID 32865) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5547.0 in stage 17.0 (TID 31615) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5496.0 in stage 17.0 (TID 30865) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5590.0 in stage 17.0 (TID 32615) (host-10-140-92-222 executor 150): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5848.0 in stage 17.0 (TID 31161) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5849.0 in stage 17.0 (TID 31411) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 961.0 in stage 17.0 (TID 32726) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1197.0 in stage 17.0 (TID 33476) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 820.0 in stage 17.0 (TID 32226) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2176.0 in stage 17.0 (TID 30860) (host-10-140-92-90 executor 170): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2181.0 in stage 17.0 (TID 31360) (host-10-140-92-90 executor 170): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4192.0 in stage 17.0 (TID 34568) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5868.0 in stage 17.0 (TID 34661) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4212.0 in stage 17.0 (TID 35318) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 888.0 in stage 17.0 (TID 32476) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4149.0 in stage 17.0 (TID 31068) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4171.0 in stage 17.0 (TID 33068) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4143.0 in stage 17.0 (TID 30567) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4206.0 in stage 17.0 (TID 35068) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4147.0 in stage 17.0 (TID 30818) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4165.0 in stage 17.0 (TID 32568) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4179.0 in stage 17.0 (TID 33818) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5808.0 in stage 17.0 (TID 33697) (host-10-140-92-70 executor 55): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4164.0 in stage 17.0 (TID 32318) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4168.0 in stage 17.0 (TID 32818) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4189.0 in stage 17.0 (TID 34068) (host-10-140-92-123 executor 37): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5816.0 in stage 17.0 (TID 34947) (host-10-140-92-70 executor 55): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5785.0 in stage 17.0 (TID 30445) (host-10-140-92-70 executor 55): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5793.0 in stage 17.0 (TID 32197) (host-10-140-92-70 executor 55): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5807.0 in stage 17.0 (TID 33447) (host-10-140-92-70 executor 55): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5792.0 in stage 17.0 (TID 31947) (host-10-140-92-70 executor 55): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5786.0 in stage 17.0 (TID 30697) (host-10-140-92-70 executor 55): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5811.0 in stage 17.0 (TID 34197) (host-10-140-92-70 executor 55): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5812.0 in stage 17.0 (TID 34447) (host-10-140-92-70 executor 55): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3821.0 in stage 17.0 (TID 30431) (host-10-140-93-33 executor 246): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3912.0 in stage 17.0 (TID 32183) (host-10-140-93-33 executor 246): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4107.0 in stage 17.0 (TID 35183) (host-10-140-93-33 executor 246): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3832.0 in stage 17.0 (TID 30683) (host-10-140-93-33 executor 246): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3987.0 in stage 17.0 (TID 33433) (host-10-140-93-33 executor 246): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3884.0 in stage 17.0 (TID 31933) (host-10-140-93-33 executor 246): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3323.0 in stage 17.0 (TID 33969) (host-10-140-92-172 executor 28): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3950.0 in stage 17.0 (TID 32933) (host-10-140-93-33 executor 246): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3252.0 in stage 17.0 (TID 32219) (host-10-140-92-172 executor 28): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3914.0 in stage 17.0 (TID 32433) (host-10-140-93-33 executor 246): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3232.0 in stage 17.0 (TID 30969) (host-10-140-92-172 executor 28): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3992.0 in stage 17.0 (TID 33683) (host-10-140-93-33 executor 246): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3250.0 in stage 17.0 (TID 31969) (host-10-140-92-172 executor 28): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3848.0 in stage 17.0 (TID 31183) (host-10-140-93-33 executor 246): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3325.0 in stage 17.0 (TID 34219) (host-10-140-92-172 executor 28): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3334.0 in stage 17.0 (TID 34469) (host-10-140-92-172 executor 28): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 378.0 in stage 17.0 (TID 30976) (host-10-140-92-190 executor 71): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1631.0 in stage 17.0 (TID 35442) (host-10-140-93-45 executor 241): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4982.0 in stage 17.0 (TID 34953) (host-10-140-92-172 executor 51): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5980.0 in stage 17.0 (TID 32639) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5976.0 in stage 17.0 (TID 32139) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5989.0 in stage 17.0 (TID 34389) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5984.0 in stage 17.0 (TID 33389) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5972.0 in stage 17.0 (TID 31639) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5991.0 in stage 17.0 (TID 34889) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5988.0 in stage 17.0 (TID 34139) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5970.0 in stage 17.0 (TID 31389) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5986.0 in stage 17.0 (TID 33889) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5983.0 in stage 17.0 (TID 33139) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5990.0 in stage 17.0 (TID 34639) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5794.0 in stage 17.0 (TID 31677) (host-10-140-92-174 executor 232): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2117.0 in stage 17.0 (TID 34299) (host-10-140-92-136 executor 186): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2036.0 in stage 17.0 (TID 31549) (host-10-140-92-136 executor 186): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2098.0 in stage 17.0 (TID 33299) (host-10-140-92-136 executor 186): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1760.0 in stage 17.0 (TID 31152) (host-10-140-92-70 executor 120): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2109.0 in stage 17.0 (TID 33799) (host-10-140-92-136 executor 186): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2104.0 in stage 17.0 (TID 33549) (host-10-140-92-136 executor 186): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2118.0 in stage 17.0 (TID 34549) (host-10-140-92-136 executor 186): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1786.0 in stage 17.0 (TID 32652) (host-10-140-92-70 executor 120): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1802.0 in stage 17.0 (TID 34652) (host-10-140-92-70 executor 120): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1789.0 in stage 17.0 (TID 33152) (host-10-140-92-70 executor 120): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2045.0 in stage 17.0 (TID 32049) (host-10-140-92-136 executor 186): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 2043.0 in stage 17.0 (TID 31799) (host-10-140-92-136 executor 186): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4983.0 in stage 17.0 (TID 35203) (host-10-140-92-172 executor 51): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4979.0 in stage 17.0 (TID 34453) (host-10-140-92-172 executor 51): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 589.0 in stage 17.0 (TID 31831) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 606.0 in stage 17.0 (TID 32581) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 595.0 in stage 17.0 (TID 32081) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 608.0 in stage 17.0 (TID 32831) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 544.0 in stage 17.0 (TID 30580) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 588.0 in stage 17.0 (TID 31581) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 654.0 in stage 17.0 (TID 33831) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5512.0 in stage 17.0 (TID 32948) (host-10-140-92-79 executor 82): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5515.0 in stage 17.0 (TID 33198) (host-10-140-92-79 executor 82): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 707.0 in stage 17.0 (TID 35081) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5509.0 in stage 17.0 (TID 32698) (host-10-140-92-79 executor 82): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1260.0 in stage 17.0 (TID 31264) (host-10-140-92-152 executor 204): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1234.0 in stage 17.0 (TID 31014) (host-10-140-92-152 executor 204): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1433.0 in stage 17.0 (TID 34264) (host-10-140-92-152 executor 204): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1474.0 in stage 17.0 (TID 35264) (host-10-140-92-152 executor 204): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4037.0 in stage 17.0 (TID 34183) (host-10-140-93-33 executor 246): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5094.0 in stage 17.0 (TID 32908) (host-10-140-92-172 executor 49): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5080.0 in stage 17.0 (TID 30908) (host-10-140-92-172 executor 49): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5078.0 in stage 17.0 (TID 30657) (host-10-140-92-172 executor 49): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5145.0 in stage 17.0 (TID 34408) (host-10-140-92-172 executor 49): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5085.0 in stage 17.0 (TID 31408) (host-10-140-92-172 executor 49): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5089.0 in stage 17.0 (TID 32158) (host-10-140-92-172 executor 49): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5157.0 in stage 17.0 (TID 35158) (host-10-140-92-172 executor 49): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 260.0 in stage 17.0 (TID 30672) (host-10-140-92-190 executor 75): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5967.0 in stage 17.0 (TID 30889) (host-10-140-92-190 executor 72): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5503.0 in stage 17.0 (TID 32198) (host-10-140-92-79 executor 82): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5494.0 in stage 17.0 (TID 30698) (host-10-140-92-79 executor 82): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5527.0 in stage 17.0 (TID 34448) (host-10-140-92-79 executor 82): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 817.0 in stage 17.0 (TID 34442) (host-10-140-92-115 executor 124): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 813.0 in stage 17.0 (TID 34192) (host-10-140-92-115 executor 124): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5519.0 in stage 17.0 (TID 33698) (host-10-140-92-79 executor 82): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4016.0 in stage 17.0 (TID 32431) (host-10-140-92-123 executor 34): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 790.0 in stage 17.0 (TID 33192) (host-10-140-92-115 executor 124): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 830.0 in stage 17.0 (TID 35192) (host-10-140-92-115 executor 124): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 824.0 in stage 17.0 (TID 34692) (host-10-140-92-115 executor 124): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5535.0 in stage 17.0 (TID 34948) (host-10-140-92-79 executor 82): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5537.0 in stage 17.0 (TID 35198) (host-10-140-92-79 executor 82): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 5508.0 in stage 17.0 (TID 32448) (host-10-140-92-79 executor 82): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4019.0 in stage 17.0 (TID 32681) (host-10-140-92-123 executor 34): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 1745.0 in stage 17.0 (TID 35447) (host-10-140-93-45 executor 239): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 3997.0 in stage 17.0 (TID 31181) (host-10-140-92-123 executor 34): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4543.0 in stage 17.0 (TID 32022) (host-10-140-93-43 executor 152): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4545.0 in stage 17.0 (TID 32272) (host-10-140-93-43 executor 152): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4634.0 in stage 17.0 (TID 34272) (host-10-140-93-43 executor 152): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4937.0 in stage 17.0 (TID 33145) (host-10-140-93-29 executor 116): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4671.0 in stage 17.0 (TID 35272) (host-10-140-93-43 executor 152): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4659.0 in stage 17.0 (TID 35022) (host-10-140-93-43 executor 152): TaskKilled (Stage cancelled)
# 25/03/13 17:29:14 WARN TaskSetManager: Lost task 4538.0 in stage 17.0 (TID 31772) (host-10-140-93-43 executor 152): TaskKilled (Stage cancelled)
# ...
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2776.0 in stage 17.0 (TID 33839) (host-10-140-92-105 executor 17): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2775.0 in stage 17.0 (TID 33589) (host-10-140-92-105 executor 17): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2763.0 in stage 17.0 (TID 30588) (host-10-140-92-105 executor 17): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2777.0 in stage 17.0 (TID 34089) (host-10-140-92-105 executor 17): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2774.0 in stage 17.0 (TID 33339) (host-10-140-92-105 executor 17): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2782.0 in stage 17.0 (TID 35339) (host-10-140-92-105 executor 17): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2780.0 in stage 17.0 (TID 34839) (host-10-140-92-105 executor 17): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2769.0 in stage 17.0 (TID 32089) (host-10-140-92-105 executor 17): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2770.0 in stage 17.0 (TID 32339) (host-10-140-92-105 executor 17): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5041.0 in stage 17.0 (TID 33629) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2808.0 in stage 17.0 (TID 32452) (host-10-140-92-136 executor 185): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2387.0 in stage 17.0 (TID 33689) (host-10-140-92-222 executor 94): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5072.0 in stage 17.0 (TID 34629) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4782.0 in stage 17.0 (TID 31879) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2306.0 in stage 17.0 (TID 34069) (host-10-140-92-79 executor 166): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3511.0 in stage 17.0 (TID 35093) (host-10-140-92-90 executor 142): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 1467.0 in stage 17.0 (TID 32600) (host-10-140-92-194 executor 91): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3406.0 in stage 17.0 (TID 31843) (host-10-140-92-90 executor 142): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 1495.0 in stage 17.0 (TID 34600) (host-10-140-92-194 executor 91): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5977.0 in stage 17.0 (TID 34677) (host-10-140-92-174 executor 232): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2223.0 in stage 17.0 (TID 32319) (host-10-140-92-79 executor 166): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2372.0 in stage 17.0 (TID 35319) (host-10-140-92-79 executor 166): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5065.0 in stage 17.0 (TID 34379) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4791.0 in stage 17.0 (TID 32129) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5810.0 in stage 17.0 (TID 32427) (host-10-140-92-174 executor 232): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2317.0 in stage 17.0 (TID 34319) (host-10-140-92-79 executor 166): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4764.0 in stage 17.0 (TID 31129) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5059.0 in stage 17.0 (TID 34129) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4723.0 in stage 17.0 (TID 30879) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5056.0 in stage 17.0 (TID 33879) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2028.0 in stage 17.0 (TID 30568) (host-10-140-92-79 executor 166): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4793.0 in stage 17.0 (TID 32379) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5084.0 in stage 17.0 (TID 35129) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5964.0 in stage 17.0 (TID 35137) (host-10-140-92-190 executor 76): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4777.0 in stage 17.0 (TID 31629) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4820.0 in stage 17.0 (TID 33129) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5074.0 in stage 17.0 (TID 34879) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 721.0 in stage 17.0 (TID 35331) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 381.0 in stage 17.0 (TID 31241) (host-10-140-93-63 executor 61): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4811.0 in stage 17.0 (TID 32629) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4835.0 in stage 17.0 (TID 33379) (host-10-140-92-222 executor 149): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 580.0 in stage 17.0 (TID 31331) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 549.0 in stage 17.0 (TID 30831) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 693.0 in stage 17.0 (TID 31991) (host-10-140-93-63 executor 61): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 611.0 in stage 17.0 (TID 33081) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 704.0 in stage 17.0 (TID 34831) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 555.0 in stage 17.0 (TID 31081) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2281.0 in stage 17.0 (TID 33319) (host-10-140-92-79 executor 166): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 634.0 in stage 17.0 (TID 33581) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4156.0 in stage 17.0 (TID 33370) (host-10-140-92-79 executor 133): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 601.0 in stage 17.0 (TID 32331) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 660.0 in stage 17.0 (TID 34331) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4127.0 in stage 17.0 (TID 32620) (host-10-140-92-79 executor 133): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4323.0 in stage 17.0 (TID 33499) (host-10-140-93-33 executor 244): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 1626.0 in stage 17.0 (TID 35241) (host-10-140-93-63 executor 61): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 970.0 in stage 17.0 (TID 32991) (host-10-140-93-63 executor 61): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4028.0 in stage 17.0 (TID 33431) (host-10-140-92-123 executor 34): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4195.0 in stage 17.0 (TID 31499) (host-10-140-93-33 executor 244): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4096.0 in stage 17.0 (TID 32120) (host-10-140-92-79 executor 133): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4202.0 in stage 17.0 (TID 35120) (host-10-140-92-79 executor 133): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2058.0 in stage 17.0 (TID 31069) (host-10-140-92-79 executor 166): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 692.0 in stage 17.0 (TID 34581) (host-10-140-93-34 executor 176): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3993.0 in stage 17.0 (TID 30681) (host-10-140-92-123 executor 34): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2092.0 in stage 17.0 (TID 31569) (host-10-140-92-79 executor 166): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4024.0 in stage 17.0 (TID 32931) (host-10-140-92-123 executor 34): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2168.0 in stage 17.0 (TID 34763) (host-10-140-92-152 executor 205): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4985.0 in stage 17.0 (TID 34395) (host-10-140-93-29 executor 116): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4921.0 in stage 17.0 (TID 32645) (host-10-140-93-29 executor 116): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3102.0 in stage 17.0 (TID 34968) (host-10-140-92-90 executor 137): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3157.0 in stage 17.0 (TID 35462) (host-10-140-92-90 executor 257): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3099.0 in stage 17.0 (TID 34468) (host-10-140-92-90 executor 137): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 2174.0 in stage 17.0 (TID 32106) (host-10-140-93-43 executor 104): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 1019.0 in stage 17.0 (TID 30906) (host-10-140-93-63 executor 87): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3061.0 in stage 17.0 (TID 31718) (host-10-140-92-90 executor 137): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5668.0 in stage 17.0 (TID 30825) (host-10-140-92-222 executor 84): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4703.0 in stage 17.0 (TID 33633) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4400.0 in stage 17.0 (TID 31633) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 1503.0 in stage 17.0 (TID 34850) (host-10-140-92-194 executor 91): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4386.0 in stage 17.0 (TID 31383) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4438.0 in stage 17.0 (TID 32633) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4425.0 in stage 17.0 (TID 32133) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5850.0 in stage 17.0 (TID 31661) (host-10-140-92-70 executor 54): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4715.0 in stage 17.0 (TID 35133) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4707.0 in stage 17.0 (TID 34133) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4700.0 in stage 17.0 (TID 33133) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 4711.0 in stage 17.0 (TID 34633) (host-10-140-92-115 executor 44): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5693.0 in stage 17.0 (TID 35337) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5487.0 in stage 17.0 (TID 32337) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5616.0 in stage 17.0 (TID 34337) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3121.0 in stage 17.0 (TID 31601) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3163.0 in stage 17.0 (TID 33101) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3170.0 in stage 17.0 (TID 33351) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3179.0 in stage 17.0 (TID 33601) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3123.0 in stage 17.0 (TID 31851) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3263.0 in stage 17.0 (TID 34601) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3280.0 in stage 17.0 (TID 35101) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3097.0 in stage 17.0 (TID 31351) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3130.0 in stage 17.0 (TID 32351) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3155.0 in stage 17.0 (TID 32851) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3241.0 in stage 17.0 (TID 34351) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3299.0 in stage 17.0 (TID 35351) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3272.0 in stage 17.0 (TID 34851) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3222.0 in stage 17.0 (TID 34101) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3074.0 in stage 17.0 (TID 30600) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3094.0 in stage 17.0 (TID 31101) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3126.0 in stage 17.0 (TID 32101) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3142.0 in stage 17.0 (TID 32601) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3091.0 in stage 17.0 (TID 30851) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 3185.0 in stage 17.0 (TID 33851) (host-10-140-92-70 executor 162): TaskKilled (Stage cancelled)
# 25/03/13 17:29:16 WARN TaskSetManager: Lost task 5408.0 in stage 17.0 (TID 30837) (host-10-140-93-63 executor 165): TaskKilled (Stage cancelled)

# %%
write_any_path(result_df, platform_config["output_template"])
# Out:
# {'rows': 229402632,
#  'bytes': {'sum': 1764715225792,
#   'min': 380,
#   'max': 14546436,
#   'cnt': 229402632,
#   'avg': 7692.655},
#  'files': 6000,
#  'sub_paths': {}}

# %%
x = "s3://llm-users-phdd2/jiangwenhao/article/zh-web-tencent/"
s3 = get_s3_client(x)
_ = list(list_s3_objects(client=s3, path = x))
_

# %%
get_s3_config("s3://llm-users-phdd2/jiangwenhao/article/zh-web-tencent/2019/v017/")

# %%
# 清理广播变量
broadcast_field_mappings.unpersist()
broadcast_extractor_config_path.unpersist()

# %%
from xinghe.spark import *
from app.common.json_util import *

from xinghe.s3 import *

delete_path = "s3://llm-users-phdd2/jiangwenhao/"
client = get_s3_client(delete_path)
delete_s3_object(delete_path +'article/zh-web-baijiahao/v004', client = client, dry_run = False)

# %%
list(list_s3_objects('s3://llm-users-phdd2/jiangwenhao/article/zh-web-baijiahao/', client = client, recursive=False))

# %%
   def process_platform_data(self, platform: str, input_paths: list, version: str = "001"):
        """处理指定平台数据的主流程"""
        # 获取平台配置
        config = self.platform_configs.get(platform)
        if not config:
            raise ValueError(f"Unsupported platform: {platform}")

        # 读取原始数据
        input_df = read_any_path(self.spark, ",".join(input_paths), config)

        # 数据转换
        transformed_rdd = input_df.rdd.map(
            partial(self._transform_row, platform=platform)
        ).repartition(6000)

        # 数据抽取
        processed_rdd = transformed_rdd.mapPartitions(
            partial(self._extract_data, platform=platform)
        )

        # 写入输出
        output_path = config["output_template"].format(
            platform=platform,
            version=version.zfill(3)
        )
        write_any_path(
            processed_rdd.map(lambda x: Row(value=json.dumps(x))).toDF(),
            output_path,
            {"skip_output_check": True}
        )

# %%
from pyspark.sql import Row, SparkSession
from typing import Dict, Any
import json
import uuid
from functools import partial
from typing import Iterable, Dict, Any
# create spark session
from pyspark.sql import Row, DataFrame

from xinghe.spark import *
from app.common.json_util import *

from xinghe.s3 import *


config = {
    "spark_conf_name": "spark_4",
    "skip_success_check": True,
    # 根据个人路径进行替换1
    "spark.executorEnv.LLM_WEB_KIT_CFG_PATH": "/share/jiangwenhao/.llm-web-kit.jsonc",
    "spark.dynamicAllocation.maxExecutors": "400",
}

spark = new_spark_session("llm_kit_cc", config)

processor = WebDataProcessor(spark)
platform="netease"
input_paths=["s3://private-crawl-data/zh-web-netease/20241218_p1/"]
version="002"

# %%
# 获取平台配置
self =processor
config = processor.platform_configs.get(platform)
if not config:
    raise ValueError(f"Unsupported platform: {platform}")

# 读取原始数据
input_df = read_any_path(self.spark, ",".join(input_paths), config)

# %%
input_df.count()

# %%
sample_fraction = 0.1
if sample_fraction==1.0:
    df_sample = input_df
else:
    df_sample = input_df.sample(fraction=sample_fraction)

# %%
df_sample = df_sample.limit(1)
type(df_sample)

# %%
transformed_rdd = df_sample.rdd.map(
        partial(self._transform_row, platform=platform)
    )
transformed_rdd.count()

# %%
processor.platform_configs.get(platform)
