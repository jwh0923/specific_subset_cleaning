# %%
import os
from pyspark.sql import Row, SparkSession
from typing import Dict, Any
import json
import uuid
from functools import partial
from typing import Iterable, Dict, Any
# create spark session
from pyspark.sql import Row, DataFrame
from loguru import logger
from xinghe.spark import *
from app.common.json_util import *

from xinghe.s3 import *


import os
from pyspark.sql import Row, SparkSession
from typing import Dict, Any
import json
import uuid
from functools import partial
from typing import Iterable, Dict, Any
# create spark session
from pyspark.sql import Row, DataFrame
from loguru import logger
from xinghe.spark import *
from app.common.json_util import *

from xinghe.s3 import *


import uuid
import traceback
from datetime import datetime
from llm_web_kit.input.datajson import DataJson
from func_timeout import FunctionTimedOut, func_timeout
import os
from pyspark.sql import Row, SparkSession
from typing import Dict, Any
import json
import uuid
from functools import partial
from typing import Iterable, Dict, Any
# create spark session
from pyspark.sql import Row, DataFrame
from loguru import logger
from xinghe.spark import *
from app.common.json_util import *

from xinghe.s3 import *

from pyspark.sql.functions import udf
from pyspark.sql.types import BooleanType
import re



from urllib.parse import urlparse


import uuid
import traceback
from datetime import datetime
from llm_web_kit.input.datajson import DataJson
from func_timeout import FunctionTimedOut, func_timeout

# %%
def transform_row(row, config: dict) -> Row:

    """根据平台配置转换行数据"""
    mappings = config
    from loguru import logger
    try:

         # 获取已使用的字段名
        used_field_names = {
            mappings["track_id"],
            mappings["url"],
            mappings["html"],
            mappings["layout_field"],
            "filename"  # 显式使用的filename字段
        }

        # 获取原始行的所有字段名
        row_field_names = row.__fields__  # 适用于pyspark.sql.Row对象

        # 收集未被使用的字段
        remaining_fields = [f for f in row_field_names if f not in used_field_names]
  
        # 构建meta_info字典
        meta_info = {"filename": getattr(row, "filename", "")}
        for field in remaining_fields:
            meta_info[field] = getattr(row, field, None)

        d = Row(
                track_id=getattr(row, mappings["track_id"],str(uuid.uuid4())),
                url=getattr(row, mappings["url"], ''),
                html=getattr(row, mappings["html"], ''),
                page_layout_type=mappings.get("page_layout_type_map").get(
                    getattr(row, mappings["layout_field"], ''),
                    "article"
                ),
                domain=extract_domain_info(getattr(row, mappings["url"], ''))['domain'],
                dataset_name=mappings["dataset_name"],
                data_source_category=mappings["data_source_category"],
                meta_info=meta_info
            )
        return d 
    except Exception as e:
        # 记录更详细的错误信息
        error_info = {
            "error_data":Row(**d),
            "error_type": type(e).__name__,
            "error_message": str(e),
            "traceback": traceback.format_exc(),
        }
        # s3_doc_writer.write(error_info)
        d['__error'] = error_info
    
        return Row(**d)
   


def extract_data(partition, broadcast_extractor_config_path):
    from llm_web_kit.extractor.extractor_chain import ExtractSimpleFactory
    from loguru import logger

    extractor_chain = ExtractSimpleFactory.create('/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc')
    timeout_seconds = 10
    # 为每个分区创建唯一的错误日志文件
    # partition_id = str(uuid.uuid4())
    # current_time = datetime.now().strftime("%Y%m%d_%H%M%S")
    # error_log_path = f"s3://xyz-llm-users/xyz-users/yujia/CC-MAIN-2024-33/output/v002/error_logs/{current_time}_{partition_id}.json"
    # s3_doc_writer = S3DocWriter(path=error_log_path)
    for row in partition:
        try:

            d = row.asDict()
            input_data = DataJson(d)
            data_e: DataJson = func_timeout(timeout_seconds, extractor_chain.extract, args=(input_data,))
            #data_e: DataJson = extractor_chain.extract(input_data)
            
    
            yield Row(**data_e.to_dict())
        except FunctionTimedOut as e1:
                d['__error'] = {
                    "error_type":"TIMEOUT",
                    "error_message": "extract function timeout",
                    "traceback":"TIMEOUT"
                }

                yield Row(**d)
        except Exception as e:
                # 记录更详细的错误信息
                error_info = {
                    "error_data":Row(**d),
                    "error_type": type(e).__name__,
                    "error_message": str(e),
                    "traceback": traceback.format_exc(),
                }
         
                # s3_doc_writer.write(error_info)
                d['__error'] = error_info

                yield Row(**d)
           




def extract_domain_info(url: str) -> dict:
    """从 URL 中提取完整的域名信息"""
    parsed = urlparse(url)
    netloc = parsed.netloc
    domain_parts = netloc.split(":")
    domain = domain_parts[0]  # 去除端口号
    root_domain = ".".join(domain.split(".")[-2:]) if len(domain.split(".")) >= 2 else domain

    return {
        "full_url": url,
        "netloc": netloc,
        "domain": domain,
        "root_domain": root_domain
    }
        
def handle_error(row: Dict, error: Exception) -> Dict:
    """统一错误处理"""
    row_dict = row.asDict()
    return {
     ** row,
    "__error": {
        "type": type(error).__name__,
        "message": str(error),
        "traceback": traceback.format_exc()
    }
    }

    
def extract_platform_from_s3_path(s3_path: str) -> str:
    """
    从 S3 路径中提取平台名称（存储桶后的第一个目录）
    
    示例输入: 
    - "s3://private-cooperate-data/zh-web-baijiahao/20241218_p1/"
    输出: "zh-web-baijiahao"
    
    - "s3://private-cooperate-data/DouBan/"
    输出: "DouBan"
    """
    # 分割路径并过滤空字符串
    parts = [p for p in s3_path.split("/") if p.strip() != ""]
    
    # 验证路径格式
    if len(parts) < 3:
        raise ValueError(f"无效的 S3 路径格式: {s3_path}")
    
    # 平台名称是存储桶后的第一个目录
    
    return parts[2]
# 定义判断是否为纯文本
def is_plain_text(row):
    html = row.get("html","")
    return not re.search(r'<[^>]+>', html)
    
# 定义判断content_list是否为空
def is_empty_content_list(row):
    content_list = row.get("content_list","")
    tag =False
    for i in content_list:
        if len(i) == 0:
            tag = True
    return tag
from pyspark.sql.functions import udf
from pyspark.sql.types import ArrayType, MapType, StringType
import re


def parse_text_paragraphs(row):
    # 按换行符分割段落，过滤空行
    html_content = row.get("html", "")
    paragraphs = []
    tmp_dict = {}
    for para in html_content.split('\n'):
        if para.strip():
            paragraphs.append({"c": para.strip(), "t": "text"})
        
    tmp_dict = {
            "type": "paragraph",
            "bbox": None,
            "raw_content": None,
            "content": paragraphs
  
        }      
    # 添加/更新content_list字段
    row["content_list"] = [[tmp_dict]]
    
    # 重建Row对象保留所有原始字段
    return row
   
  
import re,regex
from typing import List, Dict

def is_empty_content(text: str) -> bool:
    """检查文本是否为空或仅包含空白字符"""
    
    return not (text or "").strip()

def has_excessive_whitespace(text: str) -> bool:
    """检测过多空格或换行"""
    # 换行符占比超过25%
    total_chars = len(text)
    if total_chars == 0:
        return True
    newline_ratio = text.count('\n') / total_chars
    if newline_ratio > 0.25:
        return True
    
    # 连续空格超过500个或连续换行超过8个
    if ' ' * 500 in text or '\n' * 8 in text:
        return True
    
    return False

line_breaks_re = r"[\n\v\f\r\x85\u2028\u2029]"
visible_spaces_re = r"[\x20\xa0\u2000-\u200a\u202f\u205f\u3000]"
invisible_spaces_re = r"[\u200b-\u200d\u2060\ufeff]"
invisible_chars_re = r"[\xad\ufffc\u2061-\u2063]"
other_controls_re = r"[\x00-\x08\x0e-\x1f\x7f-\x84\x86-\x9f]"
direction_controls_re = r"[\u061c\u200e\u200f\u202a-\u202e\u2066-\u2069]"
head_view_invisible_spaces_re = r"^[\x20\xa0\u2000-\u200a\u202f\u205f\u3000 ]"
private_use_area_pattern = (
    r"[\uE000-\uF8FF]"  # BMP 私有使用区
    r"|[\U000F0000-\U000FFFFD]"  # 辅助平面 A 私有使用区
    r"|[\U00100000-\U0010FFFD]"  # 辅助平面 B 私有使用区
)
ar_invisible_spaces_re = r"[\u2060\ufeff]"
ar_direction_controls_re = r"[\u061c\u202c\u2066-\u2069]"
others = r"[\u2063\x00-\x1F\x7F-\x9F�\u200B-\u200D\uFEFF\u206a\u206e\u206f\u00AD\u200c\xa0\u3000\u2003\u2002\u200e\u00A0\u200e\u25A1\xa0]|&nbsp|\\? :|xa0|&ldquo;|&rdquo;|&rdquo|�|□|&amp|&lt|&gt"

def clean_special_whitespace(s):
    if s is None:
        return True
    s = str(s)
    s = re.sub(line_breaks_re, "\n", s)
    s = re.sub(visible_spaces_re, " ", s)
    s = re.sub(head_view_invisible_spaces_re, "", s)
    s = re.sub(invisible_spaces_re, "", s)
    s = re.sub(direction_controls_re, "", s)
    s = re.sub(invisible_chars_re, "", s)
    s = re.sub(other_controls_re, "", s)
    s = re.sub(private_use_area_pattern, "", s)
    s = re.sub(others,"",s,flags=re.UNICODE)
    s = regex.sub(r'\p{Z}+', ' ', s, flags=regex.UNICODE)
    # 匹配任意数量的指定空白字符（包括常规空格、\u2005、\u200c等）
    return s


def clean_html_tag(s):
    """处理 QUALITY_BAD_EFFECTIVENESS 类型数据质量问题"""
    # 模式选择：清理内容 或 严格过滤
    PROCESS_MODE = "clean"  # 可配置为 "filter" 进行严格过滤
    
    
    # 检测到 HTML 标签时才处理
    if bool(re.search(r'<[^>]+>', s)):
        if PROCESS_MODE == "clean":
            """清理 HTML 标签，保留文本内容"""
            s = re.sub(r'<\/?[a-z][^>]*>', '', s, flags=re.IGNORECASE)

    return  s



    
def is_url(text: str) -> bool:
    """判断文本是否为URL"""
    url_pattern = re.compile(
        r'^(?:http|ftp)s?://'  # 匹配http/https/ftp
        r'(?:\S+(?::\S*)?@)?'  # 用户名密码
        r'(?:\d{1,3}\.){3}\d{1,3}'  # IPv4地址
        r'|'                     # 或域名
        r'(?:[A-Z0-9](?:[A-Z0-9-]{0,61}[A-Z0-9])?\.)+[A-Z]{2,6}'  # 域名
        r'(?::\d+)?'            # 端口
        r'(?:/?|[/?]\S+)$', re.IGNORECASE)
    return bool(re.match(url_pattern, text))


def is_only_url(text: str) -> bool:
    """判断字符串是否仅包含一个完整URL且无其他内容"""
    # 优化后的正则表达式，支持常见URL格式
    url_pattern = re.compile(
        r'^'                            # 字符串开始
        r'(https?|ftp)://'              # 协议头
        r'(?:\S+(?::\S*)?@)?'           # 用户名密码（可选）
        r'([a-z0-9\-]+\.)+[a-z]{2,}'    # 域名部分
        r'(?::\d+)?'                    # 端口号（可选）
        r'(?:/[^\s?#]*)?'               # 路径（可选）
        r'(?:\?[^\s#]*)?'               # 查询参数（可选）
        r'(?:#[^\s]*)?'                 # 锚点（可选）
        r'$',                           # 字符串结束
        re.IGNORECASE
    )
    return url_pattern.fullmatch(text.strip()) is not None

def is_too_short(text: str) -> bool:
    """判断文本长度是否过短"""
    return len(text) <= 21

def has_abnormal_chars(text: str) -> bool:
    """检测异常字符（如不可见字符、�）"""
    abnormal_pattern = re.compile(r'[\x00-\x1F\x7F-\x9F�\u200B-\u200d\uFEFF\u00AD\u200c\xa0\u3000\u2003\u2002\u200e]')
    return bool(abnormal_pattern.search(text))

    


def clean_repeat_chars(text, max_repeat=3):
    """
    清理无意义重复字符
    :param text: 原始文本
    :param max_repeat: 允许的最大连续重复次数(中文建议3-5)
    :return: 清洗后文本
    """
    # 匹配超过阈值的连续重复字符（支持全角/半角）
    pattern = rf"([\w\W])\1{{{max_repeat},}}"
    
    def replace_func(match):
        char = match.group(1)
        # 保留不超过允许的重复次数
        return char * max_repeat
    
    return re.sub(pattern, replace_func, text)



import re
from typing import List, Dict

def is_single_url(text: str) -> bool:
    """严格判断是否为单个URL（修复括号平衡）"""
    cleaned_text = text.strip()
    url_pattern = re.compile(r"http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", re.IGNORECASE)
    return url_pattern.fullmatch(cleaned_text) is not None

def is_single_url(text: str) -> bool:
    URL_PATTERN = re.compile(
        r'^'
        r'(?:(?:https?):\/\/)?'  # 协议头（非捕获组优化）
        r'(?:www\.)?'            # 可选www前缀（网页2非捕获组建议）
        r'(?:'                   # 主域名部分（原子组优化）
            r'(?:[a-zA-Z0-9-]{1,63}\.)+[a-zA-Z]{2,63}'  # 域名结构（网页1长度限制）
            r'|'                                        # 或IP地址
            r'(?:\d{1,3}\.){3}\d{1,3}'                 # IPv4（精确匹配）
            r'|'                                        # 或
            r'$$([a-f0-9:]+)$$'                        # IPv6（网页4特殊符号处理）
        r')'
        r'(?::\d{1,5})?'         # 端口号（限制1-5位数字）
        r'(?:\/'                 # 路径参数（网页3回溯预防）
            r'[\w$-_.+!*\'(),%;&=@~#]*'  # 安全字符集（排除回溯风险）
            r'(?:%[0-9a-fA-F]{2})*'      # 编码字符（替代宽泛匹配）
        r')*'                   # 允许多级路径
        r'$', 
        re.IGNORECASE | re.VERBOSE
    )

    """严格验证单个URL（支持IPv6/Punycode/特殊符号）"""
    cleaned = text.strip() # 清理边界符号（网页4的清理建议）
    url_pattern_2 = re.compile(r"http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", re.IGNORECASE)
    tag = URL_PATTERN.fullmatch(cleaned) is not None
    tag2 = url_pattern_2.fullmatch(cleaned) is not None
    logger.info(cleaned)
    return tag2


def is_url_only_content(content: str) -> bool:
    """判断内容是否全部由URL构成（改进分割逻辑）"""
    if not content.strip():
        return False
    
    # 分割策略：仅按空白符（空格、换行等）分割，保留URL内部字符
    segments = re.split(r"""\n+|[\s\'">]+|'""", content.strip())
    return all(
        is_single_url(segment)
        for segment in segments
        if segment.strip()  # 过滤空段落
    )

import re
from typing import Dict, List

import traceback
def is_valid_content_element(processed: Dict) -> Dict:
    """综合校验单个content元素的有效性"""
    # 基础校验：字段完整性
    # 优先取 'c'，若不存在则取 'title_content'，最后默认空字符串
   
    content_key = 'c' if 'c' in processed else 'title_content' if 'title_content' in processed else 'c'

    raw_content = processed.get(content_key, '')
    elem_type = processed.get('t', 'text') 
    

    
    # 规则1: 空内容或纯空格
    if is_empty_content(raw_content):
        processed[content_key] = ''
        processed['t'] = 'text'  # 强制类型为text
        return processed
    
    
    # 规则2: 过多空白（根据不同类型调整阈值）
    if has_excessive_whitespace(raw_content):
        processed[content_key] = ''
        processed['t'] = 'text'  # 强制类型为text
        return processed

 
    # --- 清理逻辑 ---
    cleaned = clean_html_tag(clean_repeat_chars(clean_special_whitespace(raw_content)))
  
    processed[content_key] = cleaned  # 更新原始内容键
    processed['t'] = elem_type  # 保留原始类型或默认值
       
    return processed


from typing import List, Dict

def filter_content(content: List[Dict]) -> List[Dict]:
    """过滤content列表，保留有效内容元素"""
    filtered = []
    for elem in content:
        # 步骤1: 校验并处理单个元素
        processed = is_valid_content_element(elem)
        
        # 步骤2: 动态判断内容键（优先'c'，其次是'title_content'）
        content_key = 'c' if 'c' in processed else 'title_content' if 'title_content' in processed else None
        if not content_key:
            continue  # 无内容键，直接跳过
        
        # 步骤3: 检查内容是否有效（非空且非纯空格）
        content_value = processed.get(content_key, '')
        if content_value.strip() != '':
            filtered.append(processed)
            
    return filtered

def update_value(data, target_key, condition = lambda x :True, new_value =clean_special_whitespace):
    """
    递归地遍历任意维的字典列表堆叠结构数据，并根据条件更新特定键的值。

    :param data: 数据结构（字典或列表）
    :param target_key: 要更新的目标键
    :param condition: 更新条件函数
    :param new_value: 新的值（可以是具体值或函数）
    """
    if isinstance(data, dict):
        for key, value in data.items():
            if key == target_key and condition(value):
                if callable(new_value):
                    data[key] = new_value(value)
                else:
                    data[key] = new_value
            else:
                update_value(value, target_key, condition, new_value)
    elif isinstance(data, list):
        for item in data:
            update_value(item, target_key, condition, new_value)
   
        
def filter_content_list(row):
    """优化点：分离标题/段落处理，防御性类型检查，保留原始数据结构"""
    try:
        # 防御性获取内容列表
        for page in row.get("content_list", []):
            valid_elements = []
            for elem in page:
                # 非字典或非目标类型直接保留
                if not isinstance(elem, dict) or elem.get('type') not in ('title', 'paragraph','list'):
                    valid_elements.append(elem)
                    continue

                # 类型分流处理
                elem_type = elem['type']

                content_data = elem.get('content')

                # --- 标题类型处理 ---
                if elem_type == 'title':
                    # 标题内容必须是字典且包含 title_content
                    if isinstance(content_data, dict) and 'title_content' in content_data:
                        filtered = filter_content([content_data])  # 包装成列表
                        # 校验返回结果有效性
                        if filtered and isinstance(filtered, list) and len(filtered) > 0:
                            new_content = filtered[0]
                            # 确保标题内容非空
                            if new_content.get('title_content', '').strip():
                                elem['content'] = new_content
                                valid_elements.append(elem)
                    # 无效标题内容直接过滤
                    continue

                # --- 段落类型处理 ---
                if elem_type == 'paragraph':
                    # 段落内容必须是列表
                    if isinstance(content_data, list):
                        filtered = filter_content(content_data)
                        # 保留非空内容
                        if filtered and len(filtered) > 0:
                            elem['content'] = filtered
                            valid_elements.append(elem)
                    # 无效段落内容直接过滤
                    continue
                if elem_type == 'list':
                    update_value(content_data,'c')
                  
                    elem['content'] = content_data
                   
                    valid_elements.append(elem)
                    


            # 原地更新页面内容
            page[:] = valid_elements
        return row
    except Exception as e:
        row['__error'] = {
            'code': -1,
            'msg': f"Content filtering failed: {str(e)}",
            'trace': traceback.format_exc()
        }
        return row
from llm_web_kit.input.datajson import DataJson

def make_content_md(row):
    try:
        row['content_qa'] = DataJson(row).get_content_list().to_nlp_md()

        return row
    except Exception as e2:
        err = {"code":-1, f"{row}msg": traceback.format_exc()}
        row['content_qa'] = ''
        row['__error'] = err
        return row

def del_content_qa(row):
    del row['content_qa']
    return row

from llm_web_kit.input.datajson import DataJson, StructureMapper
def clist_filter_factory(self, field_you_want = ('paragraph')):
    """把content_list转化为md格式，只接受 Node 类型为 ['a', 'b'].
    Returns:
        str: md格式的文本内容
    """
    md_blocks = []  # 每个是个DocElementType规定的元素块之一转换成的文本
    content_lst = self._get_data()
    for page in content_lst:
        for content_lst_node in page:
            if content_lst_node['type'] in field_you_want:
                txt_content = self._StructureMapper__content_lst_node_2_md(content_lst_node)
                if txt_content and len(txt_content) > 0:
                    md_blocks.append(txt_content)
    md = self._StructureMapper__md_para_splitter.join(md_blocks)
    md = md.strip() + self._StructureMapper__text_end  # 加上结尾换行符
    return md

    
from pyspark.sql.functions import col
from pyspark.sql.functions import udf
from pyspark.sql.types import BooleanType
#安全解析函数（包含异常捕获）
def safe_json_loads(s):
    try:
        json.loads(s)
        return True
    except:
        return False
# 将Python函数注册为Spark UDF
safe_json_udf = udf(safe_json_loads, BooleanType())

# %%
version="002"
sub_dir=''
input_paths =[f's3://private-crawl-data/zh-web-tencent/20241218_p1/']
platform = extract_platform_from_s3_path(input_paths[0])
platform_configs = {

    "zh-web-baijiahao": {

        "field_mappings": {
            "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video"
                            },
        "dataset_name": "baijiahao",
        "url":"url",
        "html":"content",
        "layout_field": "channel",
        "data_source_category":"JSON"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/{sub_dir}/v{version}/"

    },
    "zh-web-netease": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video"
                            },
        "dataset_name": "net-ease",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
    "zh-web-tencent": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "腾讯网":"article"
                            },
        "dataset_name": "tencent",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
     "zh-web-sohu": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article"
                            },
        "dataset_name": "souhu",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
    "zh-web-sina": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article",
                                "黑猫投诉":"forum",
                                "新浪网":"article"
                            },
        "dataset_name": "sina",
        "url":"url",
        "html":"content",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },

    "blog_sina_com_cn": {

        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article",
                                "黑猫投诉":"forum",
                                
                            },
        "dataset_name": "sina_blog",
        "url":"url",
        "html":"html",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
    "DouBan": {
       
        "field_mappings": {
             "track_id":"track_id",
            "page_layout_type_map" :{
                                "":"article",
                                "文章":"article",
                                "网易":'article',
                                "视频":"video",
                                "搜狐网":"article",
                                "黑猫投诉":"forum",
                                "豆瓣网":""
                            },
        "dataset_name": "sina",
        "url":"url",
        "html":"html",
        "layout_field": "f_name",
        "data_source_category":"HTML"
        },
        "extractor_config": "/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc",
        "output_template": f"s3://llm-users-phdd2/jiangwenhao/article/{platform}/v{version}/"
    },
}
platform_config = platform_configs.get(platform)
platform_config
# Out:
# {'field_mappings': {'track_id': 'track_id',
#   'page_layout_type_map': {'': 'article',
#    '文章': 'article',
#    '网易': 'article',
#    '视频': 'video',
#    '腾讯网': 'article'},
#   'dataset_name': 'tencent',
#   'url': 'url',
#   'html': 'content',
#   'layout_field': 'f_name',
#   'data_source_category': 'HTML'},
#  'extractor_config': '/share/jiangwenhao/notebooks/定向子集专项/subset-spliz.jsonc',
#  'output_template': 's3://llm-users-phdd2/jiangwenhao/article/zh-web-tencent/v002/'}

# %%
config = {
    "spark_conf_name": "spark_4",
    "skip_success_check": True,
    # 根据个人路径进行替换1
    "spark.executorEnv.LLM_WEB_KIT_CFG_PATH": "/share/jiangwenhao/.llm-web-kit.jsonc",
    "spark.dynamicAllocation.maxExecutors": "400",
    "spark.yarn.queue": "root.clean_exp"
}
spark = new_spark_session("llm_kit_cc", config)
spark
# Out:
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.140.84.27:39785">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>llm_kit_cc</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
print(f"路径: {input_paths[0]} → 平台: {platform}")


"""接收 spark 作为参数而不是持有它"""
platform_config = platform_configs.get(platform)
if not platform_config:
    raise ValueError(f"Unsupported platform: {platform}")

# Driver 端操作
input_df = read_any_path(spark, ",".join(input_paths), config)
print(f"读取数据结束")
# 准备 Worker 端配置
worker_config = {
    "field_mappings": platform_config.get("field_mappings"),
    "extractor_config": platform_config.get("extractor_config")
}
# 分别广播不同配置
broadcast_field_mappings = worker_config["field_mappings"]
broadcast_extractor_config_path = worker_config["extractor_config"] # 广播路径






#processed_rdd_error_filter = processed_rdd.filter(lambda x:"__error"  in x)

#write_any_path(processed_rdd_error_filter.map(lambda x: Row(value=json_dumps(x.asDict()))).toDF(),"s3://web-parse-hw60p/xuchao/zx-html-error/tencent_blog/v002")


#result_df = processed_rdd_filter.map(lambda x: Row(value=json_dumps(x.asDict()))).toDF()

# write_any_path(result_df, platform_config["output_template"])
# Out:
# 路径: s3://private-crawl-data/zh-web-tencent/20241218_p1/ → 平台: zh-web-tencent
# 读取数据结束

# %%
# 在filter中使用UDF生成的Column表达式
processed_rdd_filter = input_df.filter(safe_json_udf(col("value"))).rdd.map(lambda x: Row(**{**json.loads(x.value), "filename": x.filename})).map(
    lambda row: transform_row(row, broadcast_field_mappings)
).repartition(6000).filter(lambda x:"__error" not in x).filter(lambda x :x.html !='').mapPartitions(
     lambda x:extract_data(
        x,broadcast_extractor_config_path = broadcast_extractor_config_path
    )
).filter(lambda x:"__error" not in x).cache()
#\input_path = ["s3://llm-users-phdd2/jiangwenhao/article/zh-web-tencent/v002/"]
#input_df = read_any_path(spark, ",".join(input_path), config)
processed_rdd_filter = processed_rdd_filter.map(lambda x :x.asDict())

# %%
spark
# Out:
#             <div>
#                 <p><b>SparkSession - hive</b></p>
#
#         <div>
#             <p><b>SparkContext</b></p>
#
#             <p><a href="http://10.140.84.27:39785">Spark UI</a></p>
#
#             <dl>
#               <dt>Version</dt>
#                 <dd><code>v3.4.1</code></dd>
#               <dt>Master</dt>
#                 <dd><code>yarn</code></dd>
#               <dt>AppName</dt>
#                 <dd><code>llm_kit_cc</code></dd>
#             </dl>
#         </div>
#
#             </div>

# %%
filter_json_rdd = processed_rdd_filter.filter(is_plain_text)


filter_html_empty_rdd = processed_rdd_filter.filter(lambda x : is_empty_content_list(x) and not is_plain_text(x))

## 是HTML但是content_list不为空的数据集==》正常输出数据集
filter_html_rdd = processed_rdd_filter.filter(lambda x : not is_empty_content_list(x) and not is_plain_text(x))

filter_json_add_content_list_rdd = filter_json_rdd.map(lambda x : parse_text_paragraphs(x))

filter_html_add_content_list_rdd = filter_html_empty_rdd.map(parse_text_paragraphs)



union_rdd = filter_html_rdd.union(filter_html_add_content_list_rdd).union(filter_json_add_content_list_rdd)
final_rdd = union_rdd.map(filter_content_list).filter( lambda x : not is_empty_content_list(x)).map(make_content_md)

# %%
final_rdd_1 = final_rdd.filter(lambda x: not  is_too_short(x['content_qa']))
final_rdd_2 = final_rdd_1.filter(lambda x : not has_excessive_whitespace(x['content_qa']))
final_rdd_3 = final_rdd_2.filter(lambda x : not is_url_only_content(x['content_qa']))

# %%
#from loguru import logger
#        URL_PATTERN = re.compile(
#            r'^'
#            r'(?:(?:https?):\/\/)?'  # 协议头（非捕获组优化）
#            r'(?:www\.)?'            # 可选www前缀（网页2非捕获组建议）
#            r'(?:'                   # 主域名部分（原子组优化）
#                r'(?:[a-zA-Z0-9-]{1,63}\.)+[a-zA-Z]{2,63}'  # 域名结构（网页1长度限制）
#                r'|'                                        # 或IP地址
#                r'(?:\d{1,3}\.){3}\d{1,3}'                 # IPv4（精确匹配）
#                r'|'                                        # 或
#                r'$$([a-f0-9:]+)$$'                        # IPv6（网页4特殊符号处理）
#            r')'
#            r'(?::\d{1,5})?'         # 端口号（限制1-5位数字）
#            r'(?:\/'                 # 路径参数（网页3回溯预防）
#                r'[\w$-_.+!*\'(),%;&=@~#]*'  # 安全字符集（排除回溯风险）
#                r'(?:%[0-9a-fA-F]{2})*'      # 编码字符（替代宽泛匹配）
#            r')*'                   # 允许多级路径
#            r'$', 
#            re.IGNORECASE | re.VERBOSE
#        )
#    
#        """严格验证单个URL（支持IPv6/Punycode/特殊符号）"""
#        cleaned = text.strip() # 清理边界符号（网页4的清理建议）
#        url_pattern_2 = re.compile(r"http[s]?://(?:[a-zA-Z]|[0-9]|[$-_@.&+]|[!*\\(\\),]|(?:%[0-9a-fA-F][0-9a-fA-F]))+", re.IGNORECASE)
#        tag = URL_PATTERN.fullmatch(cleaned) is not None
def is_single_url(text: str) -> bool:
    cleaned = text.strip()
    
    # 前置条件：必须以http/https或www开头（不区分大小写）
    lower_clean = cleaned.lower()
    if not (lower_clean.startswith(('http://', 'https://', 'www.'))):
        return False
    else:
        return True
        
#  tag2 = url_pattern_2.fullmatch(cleaned) is not None
    



def is_url_only_content_2(content: str) -> bool:
    """判断内容是否全部由URL构成（改进分割逻辑）"""
    if not content.strip():
        return False
    
    # 分割策略：仅按空白符（空格、换行等）分割，保留URL内部字符
    segments = re.split(r"""\n+|[\s\'">]+|'""", content.strip())
    return all(
        is_single_url(segment)
        for segment in segments
        if segment.strip()  # 过滤空段落
    )
# Out:
# 25/03/18 19:35:48 WARN TaskSetManager: Lost task 12581.0 in stage 13.0 (TID 115046) (host-10-140-92-237 executor 50): TaskKilled (Stage cancelled)

# %%
final_rdd_3 = final_rdd_2.filter(lambda x : not is_url_only_content_2(x['content_qa']))
final_rdd_3.count()
# Out:
# 157725645

# %%
from pyspark import SparkConf

from dingo.model.model import Model
from dingo.io import InputArgs
from dingo.exec import Executor
from dingo.io import MetaData

# %%
def testing(row):
    d= {'track_id': row['track_id'],'content_qa': DataJson(row).get_content_list().to_nlp_md()}
    return d

# %%
input_rdd_format = final_rdd_3.map(lambda x : testing(x))

input_rdd_format = input_rdd_format.map(lambda x: MetaData(
    data_id= str(x['track_id']),
    prompt='',
    content=x['content_qa'],
    # image=json.loads(x.value)['image'],
    # raw_data = json.loads(x.value)
))

input_data = {
    "eval_group": "qa_standard_v1",
    'input_path': 'redpajama',
    'save_data': True,
    # 'save_raw': True
}
# input_data = {
#     "eval_group": "test",
#     "input_path": "redpajama",  # local filesystem dataset
#     "save_data": True,
#     "custom_config":
#         {
#             "rule_list": ["CommonSpecialCharacter", "CommonColonEnd"],
#             "prompt_list": ["LLMRepeat"],
#             "llm_config":
#                 {
#                     "detect_text_quality":
#                         {
#                             "key": "sk-proj-CwgXjGGBKq9vBI0Lue3jT3BlbkFJ5GnKDvQtrCmlwdHoea04",
#                             "api_url": "http://10.140.54.48:26666/v1",
#                         }
#                 }
#         }
# }
# Model.apply_config(input_data['custom_config_path'])
input_args = InputArgs(**input_data)
executor = Executor.exec_map["spark"](input_args, spark_session=spark, spark_rdd=input_rdd_format)
result = executor.execute()
result = result[0].to_dict()
print(result)
# Out:
# ============= Init pyspark =============
# ============== Init Done ===============
# [Stage 43:==============================================> (17550 + 386) / 18000]
# {'task_id': '45fbd640-03ee-11f0-83fc-e8ebd34ed3cc', 'task_name': 'dingo', 'eval_group': 'qa_standard_v1', 'input_path': '', 'output_path': '', 'create_time': '20250318_194149', 'finish_time': '20250318_194428', 'score': 100.0, 'num_good': 157724734, 'num_bad': 911, 'total': 157725645, 'type_ratio': {'QUALITY_BAD_EFFECTIVENESS': 6e-06}, 'name_ratio': {'QUALITY_BAD_EFFECTIVENESS-RuleAbnormalChar': 3e-06, 'QUALITY_BAD_EFFECTIVENESS-RuleAbnormalHtml': 2e-06, 'QUALITY_BAD_EFFECTIVENESS-RuleOnlyUrl': 0.0}}

# %%
final_df = final_rdd_3.map(lambda x: Row(value=json_dumps(x))).toDF()
# Out:
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2220.3 in stage 19.0 (TID 169868) (host-10-140-92-209 executor 167): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2843.2 in stage 19.0 (TID 169998) (host-10-140-92-174 executor 254): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2842.2 in stage 19.0 (TID 170025) (host-10-140-92-174 executor 254): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2830.1 in stage 19.0 (TID 170004) (host-10-140-92-174 executor 253): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2836.2 in stage 19.0 (TID 170006) (host-10-140-92-174 executor 253): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2845.2 in stage 19.0 (TID 170000) (host-10-140-92-174 executor 254): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 4309.2 in stage 19.0 (TID 169864) (host-10-140-93-33 executor 46): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 456.3 in stage 19.0 (TID 169871) (host-10-140-93-33 executor 46): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2125.3 in stage 19.0 (TID 169990) (host-10-140-92-209 executor 166): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2848.2 in stage 19.0 (TID 170002) (host-10-140-92-174 executor 254): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2224.3 in stage 19.0 (TID 169831) (host-10-140-92-209 executor 167): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 414.3 in stage 19.0 (TID 169838) (host-10-140-93-33 executor 44): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 410.3 in stage 19.0 (TID 169873) (host-10-140-93-33 executor 44): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2833.2 in stage 19.0 (TID 170027) (host-10-140-92-174 executor 253): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 419.2 in stage 19.0 (TID 169846) (host-10-140-93-33 executor 44): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 5385.2 in stage 19.0 (TID 169825) (host-10-140-92-209 executor 167): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 412.3 in stage 19.0 (TID 169880) (host-10-140-93-33 executor 44): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2847.2 in stage 19.0 (TID 170061) (host-10-140-92-174 executor 254): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 454.3 in stage 19.0 (TID 169876) (host-10-140-93-33 executor 46): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 1369.1 in stage 19.0 (TID 169963) (host-10-140-92-98 executor 137): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 1368.1 in stage 19.0 (TID 169938) (host-10-140-92-98 executor 137): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 5069.2 in stage 19.0 (TID 169953) (host-10-140-92-100 executor 210): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 1609.3 in stage 19.0 (TID 169936) (host-10-140-92-100 executor 210): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2227.3 in stage 19.0 (TID 169839) (host-10-140-92-209 executor 167): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2834.2 in stage 19.0 (TID 170050) (host-10-140-92-174 executor 253): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 1362.1 in stage 19.0 (TID 169959) (host-10-140-92-98 executor 137): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 427.3 in stage 19.0 (TID 170011) (host-10-140-93-33 executor 43): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2841.1 in stage 19.0 (TID 170090) (host-10-140-92-174 executor 254): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 4038.2 in stage 19.0 (TID 169860) (host-10-140-93-33 executor 44): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 857.3 in stage 19.0 (TID 169791) (host-10-140-92-110 executor 63): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2225.3 in stage 19.0 (TID 169858) (host-10-140-92-209 executor 167): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 1363.1 in stage 19.0 (TID 169949) (host-10-140-92-98 executor 137): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 455.3 in stage 19.0 (TID 169901) (host-10-140-93-33 executor 46): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2163.3 in stage 19.0 (TID 170019) (host-10-140-92-209 executor 168): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 5369.2 in stage 19.0 (TID 170062) (host-10-140-92-209 executor 166): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 3875.2 in stage 19.0 (TID 169796) (host-10-140-92-110 executor 63): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 356.2 in stage 19.0 (TID 169950) (host-10-140-93-59 executor 36): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 3456.2 in stage 19.0 (TID 170017) (host-10-140-93-59 executor 35): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 357.3 in stage 19.0 (TID 169958) (host-10-140-93-59 executor 36): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 3939.1 in stage 19.0 (TID 169999) (host-10-140-93-59 executor 35): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2162.3 in stage 19.0 (TID 170056) (host-10-140-92-209 executor 168): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 458.3 in stage 19.0 (TID 169854) (host-10-140-93-33 executor 46): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2849.2 in stage 19.0 (TID 170033) (host-10-140-92-174 executor 254): TaskKilled (Stage cancelled)
# 25/03/18 19:38:26 WARN TaskSetManager: Lost task 2532.3 in stage 19.0 (TID 169756) (host-10-140-92-189 executor 228): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 362.3 in stage 19.0 (TID 170038) (host-10-140-93-59 executor 35): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2226.3 in stage 19.0 (TID 169878) (host-10-140-92-209 executor 167): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 405.2 in stage 19.0 (TID 169895) (host-10-140-93-59 executor 40): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1971.3 in stage 19.0 (TID 169979) (host-10-140-92-100 executor 211): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2165.3 in stage 19.0 (TID 169926) (host-10-140-92-209 executor 168): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 409.3 in stage 19.0 (TID 169899) (host-10-140-93-59 executor 40): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 361.3 in stage 19.0 (TID 170044) (host-10-140-93-59 executor 35): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 354.2 in stage 19.0 (TID 169964) (host-10-140-93-59 executor 36): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 3877.2 in stage 19.0 (TID 170048) (host-10-140-92-174 executor 253): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 363.3 in stage 19.0 (TID 170030) (host-10-140-93-59 executor 35): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 403.3 in stage 19.0 (TID 170028) (host-10-140-93-59 executor 40): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 408.3 in stage 19.0 (TID 170079) (host-10-140-93-59 executor 40): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 868.3 in stage 19.0 (TID 169937) (host-10-140-92-137 executor 74): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 578.2 in stage 19.0 (TID 170051) (host-10-140-92-237 executor 49): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 3452.2 in stage 19.0 (TID 169960) (host-10-140-93-59 executor 36): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4986.2 in stage 19.0 (TID 169942) (host-10-140-92-100 executor 210): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2839.2 in stage 19.0 (TID 170065) (host-10-140-92-174 executor 253): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1963.2 in stage 19.0 (TID 169951) (host-10-140-92-246 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2168.2 in stage 19.0 (TID 169905) (host-10-140-92-209 executor 168): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2123.3 in stage 19.0 (TID 170037) (host-10-140-92-209 executor 166): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 406.3 in stage 19.0 (TID 169902) (host-10-140-93-59 executor 40): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2124.3 in stage 19.0 (TID 169994) (host-10-140-92-209 executor 166): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1423.2 in stage 19.0 (TID 169894) (host-10-140-92-218 executor 155): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1168.3 in stage 19.0 (TID 169925) (host-10-140-92-75 executor 95): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1160.3 in stage 19.0 (TID 169931) (host-10-140-92-75 executor 95): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 575.2 in stage 19.0 (TID 170052) (host-10-140-92-237 executor 49): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 627.2 in stage 19.0 (TID 170086) (host-10-140-92-237 executor 83): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 3965.1 in stage 19.0 (TID 170088) (host-10-140-92-237 executor 51): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 781.3 in stage 19.0 (TID 169844) (host-10-140-92-121 executor 86): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1582.3 in stage 19.0 (TID 170076) (host-10-140-92-100 executor 212): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 571.3 in stage 19.0 (TID 170055) (host-10-140-92-237 executor 49): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 866.3 in stage 19.0 (TID 169944) (host-10-140-92-137 executor 74): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 438.3 in stage 19.0 (TID 169913) (host-10-140-92-199 executor 41): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 3683.1 in stage 19.0 (TID 170071) (host-10-140-92-237 executor 49): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 862.3 in stage 19.0 (TID 169939) (host-10-140-92-137 executor 74): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 865.2 in stage 19.0 (TID 169930) (host-10-140-92-137 executor 74): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 786.3 in stage 19.0 (TID 169823) (host-10-140-92-121 executor 86): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1835.3 in stage 19.0 (TID 169980) (host-10-140-92-246 executor 181): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 436.3 in stage 19.0 (TID 169909) (host-10-140-92-199 executor 41): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1972.2 in stage 19.0 (TID 169982) (host-10-140-92-100 executor 211): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1608.3 in stage 19.0 (TID 169922) (host-10-140-92-100 executor 210): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 421.3 in stage 19.0 (TID 170054) (host-10-140-93-33 executor 43): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1975.3 in stage 19.0 (TID 169974) (host-10-140-92-100 executor 211): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 440.3 in stage 19.0 (TID 169851) (host-10-140-92-199 executor 42): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 437.3 in stage 19.0 (TID 170024) (host-10-140-92-199 executor 41): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1974.3 in stage 19.0 (TID 170058) (host-10-140-92-100 executor 211): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1977.3 in stage 19.0 (TID 170064) (host-10-140-92-100 executor 211): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 785.3 in stage 19.0 (TID 169852) (host-10-140-92-121 executor 86): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 5166.0 in stage 19.0 (TID 169973) (host-10-140-92-33 executor 267): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1360.1 in stage 19.0 (TID 169943) (host-10-140-92-98 executor 137): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2895.3 in stage 19.0 (TID 169911) (host-10-140-92-209 executor 286): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 432.3 in stage 19.0 (TID 169906) (host-10-140-92-199 executor 41): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2121.3 in stage 19.0 (TID 170077) (host-10-140-92-209 executor 166): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 359.3 in stage 19.0 (TID 169955) (host-10-140-93-59 executor 36): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1969.3 in stage 19.0 (TID 169966) (host-10-140-92-246 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 442.3 in stage 19.0 (TID 169859) (host-10-140-92-199 executor 42): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1830.2 in stage 19.0 (TID 169985) (host-10-140-92-246 executor 181): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1600.2 in stage 19.0 (TID 169912) (host-10-140-92-100 executor 210): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2166.3 in stage 19.0 (TID 170035) (host-10-140-92-209 executor 168): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1606.3 in stage 19.0 (TID 169948) (host-10-140-92-100 executor 210): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 783.3 in stage 19.0 (TID 169892) (host-10-140-92-121 executor 86): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1836.1 in stage 19.0 (TID 169989) (host-10-140-92-246 executor 181): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2844.2 in stage 19.0 (TID 170039) (host-10-140-92-174 executor 254): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 787.2 in stage 19.0 (TID 169865) (host-10-140-92-121 executor 86): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1366.1 in stage 19.0 (TID 169934) (host-10-140-92-98 executor 137): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2296.3 in stage 19.0 (TID 169981) (host-10-140-92-33 executor 267): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4002.0 in stage 19.0 (TID 169968) (host-10-140-92-246 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 366.2 in stage 19.0 (TID 170084) (host-10-140-93-59 executor 35): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2160.3 in stage 19.0 (TID 169910) (host-10-140-92-209 executor 168): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4121.2 in stage 19.0 (TID 169983) (host-10-140-92-246 executor 181): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 529.2 in stage 19.0 (TID 169840) (host-10-140-92-222 executor 55): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1365.1 in stage 19.0 (TID 169954) (host-10-140-92-98 executor 137): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2271.2 in stage 19.0 (TID 169800) (host-10-140-93-57 executor 231): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2416.2 in stage 19.0 (TID 169803) (host-10-140-92-94 executor 279): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4494.1 in stage 19.0 (TID 169830) (host-10-140-93-57 executor 236): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1585.3 in stage 19.0 (TID 170023) (host-10-140-92-100 executor 212): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1601.3 in stage 19.0 (TID 170047) (host-10-140-92-100 executor 210): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4497.1 in stage 19.0 (TID 169875) (host-10-140-92-121 executor 86): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 780.3 in stage 19.0 (TID 169886) (host-10-140-92-121 executor 86): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1966.3 in stage 19.0 (TID 169962) (host-10-140-92-246 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2327.2 in stage 19.0 (TID 169837) (host-10-140-93-57 executor 236): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 797.3 in stage 19.0 (TID 169857) (host-10-140-92-53 executor 90): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2890.3 in stage 19.0 (TID 170067) (host-10-140-92-209 executor 286): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4838.0 in stage 19.0 (TID 169918) (host-10-140-92-98 executor 137): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1979.3 in stage 19.0 (TID 169976) (host-10-140-92-100 executor 211): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 791.3 in stage 19.0 (TID 169874) (host-10-140-92-53 executor 90): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4661.2 in stage 19.0 (TID 169870) (host-10-140-92-53 executor 90): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 3953.2 in stage 19.0 (TID 169957) (host-10-140-92-246 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2139.2 in stage 19.0 (TID 170069) (host-10-140-93-57 executor 232): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 504.2 in stage 19.0 (TID 169967) (host-10-140-92-222 executor 57): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 3505.2 in stage 19.0 (TID 169866) (host-10-140-92-199 executor 42): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 5108.2 in stage 19.0 (TID 169975) (host-10-140-92-33 executor 267): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2252.2 in stage 19.0 (TID 169853) (host-10-140-93-57 executor 230): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4004.2 in stage 19.0 (TID 169812) (host-10-140-92-222 executor 58): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2301.2 in stage 19.0 (TID 169804) (host-10-140-93-57 executor 234): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4566.0 in stage 19.0 (TID 170005) (host-10-140-93-57 executor 232): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2329.2 in stage 19.0 (TID 169861) (host-10-140-93-57 executor 236): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 512.2 in stage 19.0 (TID 169946) (host-10-140-92-222 executor 54): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2251.2 in stage 19.0 (TID 169819) (host-10-140-93-57 executor 230): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 784.3 in stage 19.0 (TID 170082) (host-10-140-92-121 executor 86): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1833.3 in stage 19.0 (TID 170073) (host-10-140-92-246 executor 181): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 25.2 in stage 19.0 (TID 170074) (host-10-140-92-158 executor 8): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4409.1 in stage 19.0 (TID 169923) (host-10-140-93-57 executor 235): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 796.3 in stage 19.0 (TID 170026) (host-10-140-92-53 executor 90): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1965.3 in stage 19.0 (TID 170029) (host-10-140-92-246 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 533.2 in stage 19.0 (TID 169783) (host-10-140-92-222 executor 53): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2240.2 in stage 19.0 (TID 169810) (host-10-140-93-57 executor 233): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2312.2 in stage 19.0 (TID 169956) (host-10-140-93-57 executor 229): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 467.2 in stage 19.0 (TID 170015) (host-10-140-92-222 executor 56): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 471.2 in stage 19.0 (TID 169904) (host-10-140-92-222 executor 52): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 792.3 in stage 19.0 (TID 170042) (host-10-140-92-53 executor 90): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 502.2 in stage 19.0 (TID 169970) (host-10-140-92-222 executor 57): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2279.2 in stage 19.0 (TID 169794) (host-10-140-93-57 executor 231): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 900.2 in stage 19.0 (TID 169993) (host-10-140-92-103 executor 64): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2289.2 in stage 19.0 (TID 169940) (host-10-140-93-57 executor 235): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2317.2 in stage 19.0 (TID 169965) (host-10-140-93-57 executor 229): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 338.2 in stage 19.0 (TID 169947) (host-10-140-92-37 executor 37): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 332.2 in stage 19.0 (TID 170066) (host-10-140-92-37 executor 37): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2292.3 in stage 19.0 (TID 170081) (host-10-140-92-33 executor 267): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 386.2 in stage 19.0 (TID 170059) (host-10-140-92-37 executor 38): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2290.3 in stage 19.0 (TID 169978) (host-10-140-92-33 executor 267): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2949.2 in stage 19.0 (TID 170068) (host-10-140-93-43 executor 304): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2959.3 in stage 19.0 (TID 170096) (host-10-140-93-43 executor 306): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2571.2 in stage 19.0 (TID 170063) (host-10-140-92-120 executor 169): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4030.2 in stage 19.0 (TID 170078) (host-10-140-93-43 executor 306): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2321.2 in stage 19.0 (TID 170020) (host-10-140-93-57 executor 236): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 909.3 in stage 19.0 (TID 170016) (host-10-140-92-103 executor 64): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 902.3 in stage 19.0 (TID 170022) (host-10-140-92-103 executor 64): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2576.2 in stage 19.0 (TID 170043) (host-10-140-92-120 executor 169): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 337.3 in stage 19.0 (TID 170049) (host-10-140-92-37 executor 37): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2243.1 in stage 19.0 (TID 169789) (host-10-140-93-57 executor 233): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 906.3 in stage 19.0 (TID 170060) (host-10-140-92-103 executor 64): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 331.2 in stage 19.0 (TID 170041) (host-10-140-92-37 executor 37): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2573.3 in stage 19.0 (TID 170072) (host-10-140-92-120 executor 169): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 385.2 in stage 19.0 (TID 170010) (host-10-140-92-37 executor 38): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2300.2 in stage 19.0 (TID 169776) (host-10-140-93-57 executor 234): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 901.2 in stage 19.0 (TID 169941) (host-10-140-92-103 executor 64): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2287.2 in stage 19.0 (TID 169935) (host-10-140-93-57 executor 235): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 311.2 in stage 19.0 (TID 170013) (host-10-140-92-37 executor 33): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2247.2 in stage 19.0 (TID 169835) (host-10-140-93-57 executor 233): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2137.2 in stage 19.0 (TID 170070) (host-10-140-93-57 executor 232): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2250.2 in stage 19.0 (TID 169833) (host-10-140-93-57 executor 230): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 908.3 in stage 19.0 (TID 170085) (host-10-140-92-103 executor 64): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 3176.2 in stage 19.0 (TID 169952) (host-10-140-92-37 executor 37): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4556.1 in stage 19.0 (TID 169802) (host-10-140-93-57 executor 233): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2285.2 in stage 19.0 (TID 169919) (host-10-140-93-57 executor 235): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2309.2 in stage 19.0 (TID 169814) (host-10-140-93-57 executor 234): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2091.3 in stage 19.0 (TID 170045) (host-10-140-93-48 executor 201): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4524.1 in stage 19.0 (TID 169809) (host-10-140-93-57 executor 234): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1361.1 in stage 19.0 (TID 169924) (host-10-140-92-98 executor 137): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2258.2 in stage 19.0 (TID 169822) (host-10-140-93-57 executor 230): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2320.2 in stage 19.0 (TID 170080) (host-10-140-93-57 executor 236): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4517.1 in stage 19.0 (TID 170007) (host-10-140-93-57 executor 232): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4415.1 in stage 19.0 (TID 169932) (host-10-140-93-57 executor 235): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2254.2 in stage 19.0 (TID 169805) (host-10-140-93-57 executor 230): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2256.2 in stage 19.0 (TID 169843) (host-10-140-93-57 executor 230): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4421.1 in stage 19.0 (TID 170021) (host-10-140-93-57 executor 231): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2274.2 in stage 19.0 (TID 169785) (host-10-140-93-57 executor 231): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2328.2 in stage 19.0 (TID 169849) (host-10-140-93-57 executor 236): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2431.2 in stage 19.0 (TID 169775) (host-10-140-93-26 executor 193): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2278.2 in stage 19.0 (TID 169788) (host-10-140-93-57 executor 231): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2138.2 in stage 19.0 (TID 170009) (host-10-140-93-57 executor 232): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2244.2 in stage 19.0 (TID 170083) (host-10-140-93-57 executor 233): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4572.1 in stage 19.0 (TID 169961) (host-10-140-93-57 executor 229): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2277.2 in stage 19.0 (TID 170032) (host-10-140-93-57 executor 231): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2283.2 in stage 19.0 (TID 169945) (host-10-140-93-57 executor 235): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2436.2 in stage 19.0 (TID 169760) (host-10-140-93-26 executor 193): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2432.2 in stage 19.0 (TID 169757) (host-10-140-93-26 executor 193): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 3445.1 in stage 19.0 (TID 169764) (host-10-140-93-26 executor 193): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2433.2 in stage 19.0 (TID 169750) (host-10-140-93-26 executor 193): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 3233.1 in stage 19.0 (TID 168813) (host-10-140-92-32 executor 29): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2455.1 in stage 19.0 (TID 168826) (host-10-140-92-94 executor 280): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 120.2 in stage 19.0 (TID 168835) (host-10-140-92-32 executor 28): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 208.2 in stage 19.0 (TID 168850) (host-10-140-92-32 executor 29): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 5065.1 in stage 19.0 (TID 168865) (host-10-140-92-94 executor 279): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2460.2 in stage 19.0 (TID 168870) (host-10-140-92-94 executor 278): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4891.1 in stage 19.0 (TID 168875) (host-10-140-92-94 executor 278): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2454.2 in stage 19.0 (TID 168880) (host-10-140-92-94 executor 280): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2459.2 in stage 19.0 (TID 168886) (host-10-140-92-94 executor 280): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1953.1 in stage 19.0 (TID 168894) (host-10-140-92-86 executor 190): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 121.2 in stage 19.0 (TID 168898) (host-10-140-92-32 executor 29): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 5009.1 in stage 19.0 (TID 168899) (host-10-140-92-94 executor 277): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 5008.1 in stage 19.0 (TID 168905) (host-10-140-92-94 executor 280): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2453.2 in stage 19.0 (TID 168916) (host-10-140-92-94 executor 280): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1259.1 in stage 19.0 (TID 168918) (host-10-140-92-112 executor 121): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1291.1 in stage 19.0 (TID 168920) (host-10-140-92-112 executor 125): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 155.2 in stage 19.0 (TID 168925) (host-10-140-92-32 executor 25): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 237.2 in stage 19.0 (TID 168921) (host-10-140-92-32 executor 29): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1293.2 in stage 19.0 (TID 168933) (host-10-140-92-112 executor 125): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2409.2 in stage 19.0 (TID 168932) (host-10-140-92-94 executor 277): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1618.2 in stage 19.0 (TID 168936) (host-10-140-92-112 executor 205): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1884.2 in stage 19.0 (TID 168940) (host-10-140-92-86 executor 186): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1610.2 in stage 19.0 (TID 168945) (host-10-140-92-112 executor 205): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 68.2 in stage 19.0 (TID 168944) (host-10-140-92-32 executor 25): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2406.2 in stage 19.0 (TID 168949) (host-10-140-92-94 executor 277): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 5286.1 in stage 19.0 (TID 168947) (host-10-140-92-112 executor 122): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2461.2 in stage 19.0 (TID 168960) (host-10-140-92-94 executor 278): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 5084.1 in stage 19.0 (TID 168968) (host-10-140-92-112 executor 123): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 4997.1 in stage 19.0 (TID 168969) (host-10-140-92-112 executor 124): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2785.0 in stage 19.0 (TID 163849) (host-10-140-92-91 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2784.0 in stage 19.0 (TID 163542) (host-10-140-92-91 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2780.0 in stage 19.0 (TID 162314) (host-10-140-92-91 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 910.0 in stage 19.0 (TID 162311) (host-10-140-93-25 executor 65): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 913.0 in stage 19.0 (TID 163232) (host-10-140-93-25 executor 65): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 914.0 in stage 19.0 (TID 163539) (host-10-140-93-25 executor 65): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2403.2 in stage 19.0 (TID 168971) (host-10-140-92-94 executor 277): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2787.0 in stage 19.0 (TID 164463) (host-10-140-92-91 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2788.0 in stage 19.0 (TID 164770) (host-10-140-92-91 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 918.0 in stage 19.0 (TID 164767) (host-10-140-93-25 executor 65): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2789.0 in stage 19.0 (TID 165077) (host-10-140-92-91 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 916.0 in stage 19.0 (TID 164153) (host-10-140-93-25 executor 65): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 915.0 in stage 19.0 (TID 163846) (host-10-140-93-25 executor 65): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2782.0 in stage 19.0 (TID 162928) (host-10-140-92-91 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2786.0 in stage 19.0 (TID 164156) (host-10-140-92-91 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2781.0 in stage 19.0 (TID 162621) (host-10-140-92-91 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2783.0 in stage 19.0 (TID 163235) (host-10-140-92-91 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 919.0 in stage 19.0 (TID 165074) (host-10-140-93-25 executor 65): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 911.0 in stage 19.0 (TID 162618) (host-10-140-93-25 executor 65): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 912.0 in stage 19.0 (TID 162925) (host-10-140-93-25 executor 65): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1841.1 in stage 19.0 (TID 168976) (host-10-140-92-86 executor 192): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 917.0 in stage 19.0 (TID 164460) (host-10-140-93-25 executor 65): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 684.0 in stage 19.0 (TID 163546) (host-10-140-92-180 executor 66): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 687.0 in stage 19.0 (TID 164467) (host-10-140-92-180 executor 66): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 680.0 in stage 19.0 (TID 162318) (host-10-140-92-180 executor 66): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 682.0 in stage 19.0 (TID 162932) (host-10-140-92-180 executor 66): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 685.0 in stage 19.0 (TID 163853) (host-10-140-92-180 executor 66): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 683.0 in stage 19.0 (TID 163239) (host-10-140-92-180 executor 66): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 686.0 in stage 19.0 (TID 164160) (host-10-140-92-180 executor 66): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 689.0 in stage 19.0 (TID 165081) (host-10-140-92-180 executor 66): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 681.0 in stage 19.0 (TID 162625) (host-10-140-92-180 executor 66): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 688.0 in stage 19.0 (TID 164774) (host-10-140-92-180 executor 66): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1926.2 in stage 19.0 (TID 168981) (host-10-140-92-86 executor 189): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2773.0 in stage 19.0 (TID 163272) (host-10-140-92-91 executor 207): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2774.0 in stage 19.0 (TID 163579) (host-10-140-92-91 executor 207): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2776.0 in stage 19.0 (TID 164193) (host-10-140-92-91 executor 207): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2771.0 in stage 19.0 (TID 162658) (host-10-140-92-91 executor 207): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2772.0 in stage 19.0 (TID 162965) (host-10-140-92-91 executor 207): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2777.0 in stage 19.0 (TID 164500) (host-10-140-92-91 executor 207): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2770.0 in stage 19.0 (TID 162351) (host-10-140-92-91 executor 207): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2779.0 in stage 19.0 (TID 165114) (host-10-140-92-91 executor 207): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2778.0 in stage 19.0 (TID 164807) (host-10-140-92-91 executor 207): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2775.0 in stage 19.0 (TID 163886) (host-10-140-92-91 executor 207): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2415.2 in stage 19.0 (TID 168987) (host-10-140-92-94 executor 279): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2802.0 in stage 19.0 (TID 162993) (host-10-140-92-91 executor 120): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 698.0 in stage 19.0 (TID 164859) (host-10-140-92-180 executor 70): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 696.0 in stage 19.0 (TID 164245) (host-10-140-92-180 executor 70): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 693.0 in stage 19.0 (TID 163324) (host-10-140-92-180 executor 70): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 692.0 in stage 19.0 (TID 163017) (host-10-140-92-180 executor 70): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 724.0 in stage 19.0 (TID 163618) (host-10-140-92-180 executor 67): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 729.0 in stage 19.0 (TID 165153) (host-10-140-92-180 executor 67): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 721.0 in stage 19.0 (TID 162697) (host-10-140-92-180 executor 67): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 1000.0 in stage 19.0 (TID 162402) (host-10-140-92-226 executor 142): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2806.0 in stage 19.0 (TID 164221) (host-10-140-92-91 executor 120): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2828.0 in stage 19.0 (TID 164873) (host-10-140-92-91 executor 206): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2824.0 in stage 19.0 (TID 163645) (host-10-140-92-91 executor 206): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 728.0 in stage 19.0 (TID 164846) (host-10-140-92-180 executor 67): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2823.0 in stage 19.0 (TID 163338) (host-10-140-92-91 executor 206): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 727.0 in stage 19.0 (TID 164539) (host-10-140-92-180 executor 67): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 725.0 in stage 19.0 (TID 163925) (host-10-140-92-180 executor 67): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 720.0 in stage 19.0 (TID 162390) (host-10-140-92-180 executor 67): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 695.0 in stage 19.0 (TID 163938) (host-10-140-92-180 executor 70): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 723.0 in stage 19.0 (TID 163311) (host-10-140-92-180 executor 67): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 726.0 in stage 19.0 (TID 164232) (host-10-140-92-180 executor 67): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 722.0 in stage 19.0 (TID 163004) (host-10-140-92-180 executor 67): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2808.0 in stage 19.0 (TID 164835) (host-10-140-92-91 executor 120): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2800.0 in stage 19.0 (TID 162379) (host-10-140-92-91 executor 120): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2807.0 in stage 19.0 (TID 164528) (host-10-140-92-91 executor 120): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2820.0 in stage 19.0 (TID 162417) (host-10-140-92-91 executor 206): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2825.0 in stage 19.0 (TID 163952) (host-10-140-92-91 executor 206): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 697.0 in stage 19.0 (TID 164552) (host-10-140-92-180 executor 70): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2821.0 in stage 19.0 (TID 162724) (host-10-140-92-91 executor 206): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 699.0 in stage 19.0 (TID 165166) (host-10-140-92-180 executor 70): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2809.0 in stage 19.0 (TID 165142) (host-10-140-92-91 executor 120): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2801.0 in stage 19.0 (TID 162686) (host-10-140-92-91 executor 120): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2805.0 in stage 19.0 (TID 163914) (host-10-140-92-91 executor 120): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2822.0 in stage 19.0 (TID 163031) (host-10-140-92-91 executor 206): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2826.0 in stage 19.0 (TID 164259) (host-10-140-92-91 executor 206): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2827.0 in stage 19.0 (TID 164566) (host-10-140-92-91 executor 206): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2803.0 in stage 19.0 (TID 163300) (host-10-140-92-91 executor 120): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2804.0 in stage 19.0 (TID 163607) (host-10-140-92-91 executor 120): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 691.0 in stage 19.0 (TID 162710) (host-10-140-92-180 executor 70): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2456.2 in stage 19.0 (TID 168991) (host-10-140-92-94 executor 280): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 2829.0 in stage 19.0 (TID 165180) (host-10-140-92-91 executor 206): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 694.0 in stage 19.0 (TID 163631) (host-10-140-92-180 executor 70): TaskKilled (Stage cancelled)
# 25/03/18 19:38:27 WARN TaskSetManager: Lost task 690.0 in stage 19.0 (TID 162403) (host-10-140-92-180 executor 70): TaskKilled (Stage cancelled)
# ...
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1392.1 in stage 19.0 (TID 168363) (host-10-140-92-186 executor 115): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2738.1 in stage 19.0 (TID 168365) (host-10-140-92-101 executor 241): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2714.1 in stage 19.0 (TID 168368) (host-10-140-92-101 executor 238): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 156.1 in stage 19.0 (TID 168369) (host-10-140-92-104 executor 23): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2704.1 in stage 19.0 (TID 168373) (host-10-140-92-101 executor 242): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2660.1 in stage 19.0 (TID 168372) (host-10-140-92-105 executor 259): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 202.1 in stage 19.0 (TID 168375) (host-10-140-92-104 executor 22): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2759.1 in stage 19.0 (TID 168377) (host-10-140-92-101 executor 237): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2737.1 in stage 19.0 (TID 168367) (host-10-140-92-101 executor 241): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2637.1 in stage 19.0 (TID 168374) (host-10-140-92-105 executor 261): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2641.1 in stage 19.0 (TID 168378) (host-10-140-92-105 executor 260): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2626.1 in stage 19.0 (TID 168380) (host-10-140-92-105 executor 265): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2602.1 in stage 19.0 (TID 168382) (host-10-140-92-105 executor 258): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2653.1 in stage 19.0 (TID 168383) (host-10-140-92-105 executor 262): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2002.1 in stage 19.0 (TID 168386) (host-10-140-92-186 executor 200): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 28.1 in stage 19.0 (TID 168384) (host-10-140-92-104 executor 22): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 663.1 in stage 19.0 (TID 168389) (host-10-140-92-104 executor 92): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2007.1 in stage 19.0 (TID 168387) (host-10-140-92-186 executor 200): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 5028.0 in stage 19.0 (TID 168392) (host-10-140-92-186 executor 199): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 206.1 in stage 19.0 (TID 168397) (host-10-140-92-104 executor 16): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2664.1 in stage 19.0 (TID 168394) (host-10-140-92-105 executor 259): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1375.1 in stage 19.0 (TID 168398) (host-10-140-92-186 executor 113): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 662.1 in stage 19.0 (TID 168390) (host-10-140-92-104 executor 92): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2727.1 in stage 19.0 (TID 168401) (host-10-140-92-101 executor 243): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1396.1 in stage 19.0 (TID 168402) (host-10-140-92-186 executor 115): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1904.1 in stage 19.0 (TID 168405) (host-10-140-92-186 executor 199): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2703.1 in stage 19.0 (TID 168407) (host-10-140-92-101 executor 242): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2673.1 in stage 19.0 (TID 168409) (host-10-140-92-105 executor 263): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 231.1 in stage 19.0 (TID 168411) (host-10-140-92-104 executor 22): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 74.1 in stage 19.0 (TID 168412) (host-10-140-92-104 executor 18): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1384.1 in stage 19.0 (TID 168410) (host-10-140-92-186 executor 112): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 128.1 in stage 19.0 (TID 168414) (host-10-140-92-104 executor 17): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 98.1 in stage 19.0 (TID 168416) (host-10-140-92-104 executor 23): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1897.1 in stage 19.0 (TID 168419) (host-10-140-92-186 executor 198): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1406.1 in stage 19.0 (TID 168415) (host-10-140-92-186 executor 116): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2663.1 in stage 19.0 (TID 168420) (host-10-140-92-105 executor 259): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2751.1 in stage 19.0 (TID 168422) (host-10-140-92-101 executor 237): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 65.1 in stage 19.0 (TID 168424) (host-10-140-92-104 executor 19): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1905.1 in stage 19.0 (TID 168421) (host-10-140-92-186 executor 199): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1376.1 in stage 19.0 (TID 168426) (host-10-140-92-186 executor 113): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2651.1 in stage 19.0 (TID 168423) (host-10-140-92-105 executor 262): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 57.1 in stage 19.0 (TID 168417) (host-10-140-92-104 executor 22): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 157.1 in stage 19.0 (TID 168418) (host-10-140-92-104 executor 17): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2627.1 in stage 19.0 (TID 168427) (host-10-140-92-105 executor 265): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2613.1 in stage 19.0 (TID 168433) (host-10-140-92-105 executor 264): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 99.1 in stage 19.0 (TID 168434) (host-10-140-92-104 executor 17): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1381.1 in stage 19.0 (TID 168436) (host-10-140-92-186 executor 112): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 248.1 in stage 19.0 (TID 168438) (host-10-140-92-104 executor 18): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 210.1 in stage 19.0 (TID 168441) (host-10-140-92-104 executor 19): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1408.1 in stage 19.0 (TID 168439) (host-10-140-92-186 executor 116): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 162.1 in stage 19.0 (TID 168445) (host-10-140-92-104 executor 21): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2009.1 in stage 19.0 (TID 168446) (host-10-140-92-186 executor 200): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1891.1 in stage 19.0 (TID 168447) (host-10-140-92-186 executor 198): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1413.1 in stage 19.0 (TID 168451) (host-10-140-92-186 executor 114): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2677.1 in stage 19.0 (TID 168456) (host-10-140-92-105 executor 263): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 243.1 in stage 19.0 (TID 168462) (host-10-140-92-104 executor 23): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 144.1 in stage 19.0 (TID 168464) (host-10-140-92-104 executor 22): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2643.1 in stage 19.0 (TID 168466) (host-10-140-92-105 executor 260): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 7.1 in stage 19.0 (TID 168469) (host-10-140-92-104 executor 19): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 158.1 in stage 19.0 (TID 168470) (host-10-140-92-104 executor 20): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 61.1 in stage 19.0 (TID 168473) (host-10-140-92-104 executor 16): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 661.1 in stage 19.0 (TID 168474) (host-10-140-92-104 executor 92): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 187.1 in stage 19.0 (TID 168476) (host-10-140-92-104 executor 20): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1411.1 in stage 19.0 (TID 168479) (host-10-140-92-186 executor 114): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 665.1 in stage 19.0 (TID 168481) (host-10-140-92-104 executor 92): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1407.1 in stage 19.0 (TID 168483) (host-10-140-92-186 executor 116): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1906.1 in stage 19.0 (TID 168485) (host-10-140-92-186 executor 199): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1377.1 in stage 19.0 (TID 168490) (host-10-140-92-186 executor 113): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 664.1 in stage 19.0 (TID 168487) (host-10-140-92-104 executor 92): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 148.1 in stage 19.0 (TID 168502) (host-10-140-92-104 executor 16): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 181.1 in stage 19.0 (TID 168507) (host-10-140-92-104 executor 19): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 273.1 in stage 19.0 (TID 168508) (host-10-140-92-104 executor 17): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2004.1 in stage 19.0 (TID 168511) (host-10-140-92-186 executor 200): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 239.1 in stage 19.0 (TID 168510) (host-10-140-92-104 executor 19): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2607.1 in stage 19.0 (TID 168524) (host-10-140-92-105 executor 258): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 123.1 in stage 19.0 (TID 168519) (host-10-140-92-104 executor 19): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 104.1 in stage 19.0 (TID 168529) (host-10-140-92-104 executor 21): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 669.1 in stage 19.0 (TID 168530) (host-10-140-92-104 executor 92): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 32.1 in stage 19.0 (TID 168532) (host-10-140-92-104 executor 16): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 71.1 in stage 19.0 (TID 168544) (host-10-140-92-104 executor 20): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 264.1 in stage 19.0 (TID 168537) (host-10-140-92-104 executor 16): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 100.1 in stage 19.0 (TID 168551) (host-10-140-92-104 executor 20): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1896.1 in stage 19.0 (TID 168556) (host-10-140-92-186 executor 198): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 103.1 in stage 19.0 (TID 168559) (host-10-140-92-104 executor 18): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 186.1 in stage 19.0 (TID 168568) (host-10-140-92-104 executor 17): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 75.1 in stage 19.0 (TID 168571) (host-10-140-92-104 executor 21): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 190.1 in stage 19.0 (TID 168584) (host-10-140-92-104 executor 18): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 13.1 in stage 19.0 (TID 168585) (host-10-140-92-104 executor 20): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 127.1 in stage 19.0 (TID 168586) (host-10-140-92-104 executor 23): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 86.1 in stage 19.0 (TID 168596) (host-10-140-92-104 executor 22): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1758.1 in stage 19.0 (TID 169752) (host-10-140-92-202 executor 159): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1787.1 in stage 19.0 (TID 169755) (host-10-140-92-202 executor 162): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1822.1 in stage 19.0 (TID 169762) (host-10-140-92-202 executor 163): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1782.1 in stage 19.0 (TID 169772) (host-10-140-92-202 executor 162): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2303.2 in stage 19.0 (TID 169790) (host-10-140-93-57 executor 234): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1794.1 in stage 19.0 (TID 169807) (host-10-140-92-202 executor 160): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1798.1 in stage 19.0 (TID 169813) (host-10-140-92-202 executor 160): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2885.1 in stage 19.0 (TID 169829) (host-10-140-92-202 executor 289): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2324.2 in stage 19.0 (TID 169842) (host-10-140-93-57 executor 236): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 3436.1 in stage 19.0 (TID 169771) (host-10-140-93-26 executor 193): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1749.1 in stage 19.0 (TID 169778) (host-10-140-92-202 executor 165): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2882.1 in stage 19.0 (TID 169820) (host-10-140-92-202 executor 289): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2923.1 in stage 19.0 (TID 169897) (host-10-140-92-202 executor 288): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1717.1 in stage 19.0 (TID 169869) (host-10-140-92-202 executor 164): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 1772.1 in stage 19.0 (TID 169768) (host-10-140-92-202 executor 158): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 2922.1 in stage 19.0 (TID 169893) (host-10-140-92-202 executor 288): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 219.1 in stage 19.0 (TID 168612) (host-10-140-92-104 executor 18): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 215.1 in stage 19.0 (TID 168618) (host-10-140-92-104 executor 17): TaskKilled (Stage cancelled)
# 25/03/18 19:38:31 WARN TaskSetManager: Lost task 3155.0 in stage 19.0 (TID 168641) (host-10-140-93-37 executor 7): TaskKilled (Stage cancelled)

# %%
# 验收数据
#腾讯
write_any_path(final_df, "s3://zhuanxiang-hw60p/article/tencent/v005/")
#souhu
#write_any_path(final_df, "s3://zhuanxiang-hw60p/article/souhu/final/v002/")
#sina
#write_any_path(final_df, "s3://zhuanxiang-hw60p/article/sina/v008/")
#sina——blog
#write_any_path(final_df, "s3://zhuanxiang-hw60p/article/blog_sina_com_cn/final/v001/")
# Out:
# [Stage 3:==============================================>  (17263 + 737) / 18000]

# %%
1
# Out:
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 7706.0 in stage 90.0 (TID 40632) (host-10-140-92-191 executor 290): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 14145.0 in stage 90.0 (TID 47070) (host-10-140-93-38 executor 187): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 10929.0 in stage 90.0 (TID 43855) (host-10-140-92-24 executor 176): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 13322.0 in stage 90.0 (TID 46247) (host-10-140-92-60 executor 65): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 12328.0 in stage 90.0 (TID 45253) (host-10-140-92-140 executor 146): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 12352.0 in stage 90.0 (TID 45277) (host-10-140-92-151 executor 204): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 13388.0 in stage 90.0 (TID 46313) (host-10-140-92-140 executor 148): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 17051.0 in stage 90.0 (TID 49976) (host-10-140-92-140 executor 255): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 13276.0 in stage 90.0 (TID 46201) (host-10-140-93-38 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 6032.0 in stage 90.0 (TID 38958) (host-10-140-93-37 executor 195): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 16439.0 in stage 90.0 (TID 49364) (host-10-140-92-65 executor 6): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 9644.0 in stage 90.0 (TID 42570) (host-10-140-93-57 executor 245): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 5966.0 in stage 90.0 (TID 38893) (host-10-140-92-227 executor 76): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 12715.0 in stage 90.0 (TID 45640) (host-10-140-92-140 executor 257): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 6299.0 in stage 90.0 (TID 39225) (host-10-140-92-90 executor 317): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 14658.0 in stage 90.0 (TID 47583) (host-10-140-92-140 executor 149): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 4900.0 in stage 90.0 (TID 37827) (host-10-140-92-151 executor 121): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 8405.0 in stage 90.0 (TID 41331) (host-10-140-92-227 executor 106): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 9497.0 in stage 90.0 (TID 42423) (host-10-140-92-46 executor 312): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 13669.0 in stage 90.0 (TID 46594) (host-10-140-92-184 executor 53): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 12344.0 in stage 90.0 (TID 45269) (host-10-140-93-38 executor 189): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 8970.0 in stage 90.0 (TID 41896) (host-10-140-92-37 executor 305): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 9642.0 in stage 90.0 (TID 42568) (host-10-140-93-57 executor 249): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 6808.0 in stage 90.0 (TID 39734) (host-10-140-92-115 executor 55): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 8148.0 in stage 90.0 (TID 41074) (host-10-140-92-115 executor 56): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 13219.0 in stage 90.0 (TID 46144) (host-10-140-92-140 executor 145): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 12048.0 in stage 90.0 (TID 44973) (host-10-140-92-246 executor 135): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 6373.0 in stage 90.0 (TID 39299) (host-10-140-92-115 executor 326): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 14164.0 in stage 90.0 (TID 47089) (host-10-140-92-60 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 10703.0 in stage 90.0 (TID 43629) (host-10-140-92-241 executor 217): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 14692.0 in stage 90.0 (TID 47617) (host-10-140-92-40 executor 199): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 9408.0 in stage 90.0 (TID 42334) (host-10-140-92-99 executor 282): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 15309.0 in stage 90.0 (TID 48234) (host-10-140-92-140 executor 154): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 16002.0 in stage 90.0 (TID 48927) (host-10-140-92-90 executor 318): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 12744.0 in stage 90.0 (TID 45669) (host-10-140-93-37 executor 43): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 10239.0 in stage 90.0 (TID 43165) (host-10-140-93-57 executor 243): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 4283.0 in stage 90.0 (TID 37210) (host-10-140-93-37 executor 38): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 15820.0 in stage 90.0 (TID 48745) (host-10-140-92-60 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 14324.0 in stage 90.0 (TID 47249) (host-10-140-92-151 executor 207): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 6321.0 in stage 90.0 (TID 39247) (host-10-140-92-90 executor 317): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 15231.0 in stage 90.0 (TID 48156) (host-10-140-92-60 executor 183): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 12040.0 in stage 90.0 (TID 44965) (host-10-140-92-151 executor 205): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 15408.0 in stage 90.0 (TID 48333) (host-10-140-92-140 executor 148): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 11705.0 in stage 90.0 (TID 44631) (host-10-140-92-184 executor 52): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 7695.0 in stage 90.0 (TID 40621) (host-10-140-92-90 executor 316): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 7935.0 in stage 90.0 (TID 40861) (host-10-140-92-90 executor 316): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 17567.0 in stage 90.0 (TID 50492) (host-10-140-92-60 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 11704.0 in stage 90.0 (TID 44630) (host-10-140-92-246 executor 132): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 16835.0 in stage 90.0 (TID 49760) (host-10-140-93-37 executor 43): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 15133.0 in stage 90.0 (TID 48058) (host-10-140-92-112 executor 315): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 10786.0 in stage 90.0 (TID 43712) (host-10-140-92-218 executor 279): TaskKilled (Stage cancelled)
# 25/03/18 13:33:55 WARN TaskSetManager: Lost task 15795.0 in stage 90.0 (TID 48720) (host-10-140-92-40 executor 103): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 10337.0 in stage 90.0 (TID 43263) (host-10-140-93-57 executor 251): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 11714.0 in stage 90.0 (TID 44640) (host-10-140-92-246 executor 133): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13657.0 in stage 90.0 (TID 46582) (host-10-140-93-38 executor 188): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 3163.0 in stage 90.0 (TID 36090) (host-10-140-92-196 executor 2): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16012.0 in stage 90.0 (TID 48937) (host-10-140-92-31 executor 50): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 10213.0 in stage 90.0 (TID 43139) (host-10-140-92-126 executor 266): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17129.0 in stage 90.0 (TID 50054) (host-10-140-92-40 executor 98): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13168.0 in stage 90.0 (TID 46093) (host-10-140-92-140 executor 154): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 8285.0 in stage 90.0 (TID 41211) (host-10-140-92-227 executor 108): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 9919.0 in stage 90.0 (TID 42845) (host-10-140-93-57 executor 246): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 5145.0 in stage 90.0 (TID 38072) (host-10-140-92-40 executor 99): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13135.0 in stage 90.0 (TID 46060) (host-10-140-92-60 executor 185): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7940.0 in stage 90.0 (TID 40866) (host-10-140-92-57 executor 60): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16188.0 in stage 90.0 (TID 49113) (host-10-140-92-57 executor 60): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17116.0 in stage 90.0 (TID 50041) (host-10-140-92-40 executor 103): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13465.0 in stage 90.0 (TID 46390) (host-10-140-93-38 executor 112): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7000.0 in stage 90.0 (TID 39926) (host-10-140-92-191 executor 287): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12343.0 in stage 90.0 (TID 45268) (host-10-140-92-40 executor 94): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 8496.0 in stage 90.0 (TID 41422) (host-10-140-92-227 executor 108): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17781.0 in stage 90.0 (TID 50706) (host-10-140-92-227 executor 73): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15827.0 in stage 90.0 (TID 48752) (host-10-140-93-38 executor 192): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17514.0 in stage 90.0 (TID 50439) (host-10-140-92-151 executor 205): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 11276.0 in stage 90.0 (TID 44202) (host-10-140-92-218 executor 277): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17928.0 in stage 90.0 (TID 50853) (host-10-140-92-140 executor 149): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7349.0 in stage 90.0 (TID 40275) (host-10-140-92-227 executor 108): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6280.0 in stage 90.0 (TID 39206) (host-10-140-92-115 executor 57): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 11312.0 in stage 90.0 (TID 44238) (host-10-140-92-34 executor 232): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 8079.0 in stage 90.0 (TID 41005) (host-10-140-92-191 executor 287): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 8747.0 in stage 90.0 (TID 41673) (host-10-140-92-227 executor 109): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13038.0 in stage 90.0 (TID 45963) (host-10-140-92-40 executor 198): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17518.0 in stage 90.0 (TID 50443) (host-10-140-92-140 executor 149): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13774.0 in stage 90.0 (TID 46699) (host-10-140-92-151 executor 203): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15818.0 in stage 90.0 (TID 48743) (host-10-140-92-60 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17141.0 in stage 90.0 (TID 50066) (host-10-140-93-38 executor 112): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6501.0 in stage 90.0 (TID 39427) (host-10-140-92-227 executor 107): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13416.0 in stage 90.0 (TID 46341) (host-10-140-92-60 executor 183): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6256.0 in stage 90.0 (TID 39182) (host-10-140-92-115 executor 326): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16210.0 in stage 90.0 (TID 49135) (host-10-140-93-38 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 3755.0 in stage 90.0 (TID 36682) (host-10-140-92-126 executor 260): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16496.0 in stage 90.0 (TID 49421) (host-10-140-92-246 executor 134): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 14024.0 in stage 90.0 (TID 46949) (host-10-140-93-37 executor 45): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13696.0 in stage 90.0 (TID 46621) (host-10-140-92-140 executor 254): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16339.0 in stage 90.0 (TID 49264) (host-10-140-92-65 executor 6): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6038.0 in stage 90.0 (TID 38964) (host-10-140-92-113 executor 324): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13342.0 in stage 90.0 (TID 46267) (host-10-140-92-60 executor 69): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7358.0 in stage 90.0 (TID 40284) (host-10-140-92-191 executor 289): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6293.0 in stage 90.0 (TID 39219) (host-10-140-92-227 executor 107): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6316.0 in stage 90.0 (TID 39242) (host-10-140-92-90 executor 318): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17412.0 in stage 90.0 (TID 50337) (host-10-140-93-37 executor 138): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17363.0 in stage 90.0 (TID 50288) (host-10-140-92-227 executor 82): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12648.0 in stage 90.0 (TID 45573) (host-10-140-92-60 executor 184): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 10586.0 in stage 90.0 (TID 43512) (host-10-140-92-241 executor 212): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17600.0 in stage 90.0 (TID 50525) (host-10-140-93-38 executor 119): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16040.0 in stage 90.0 (TID 48965) (host-10-140-93-37 executor 43): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13544.0 in stage 90.0 (TID 46469) (host-10-140-92-40 executor 201): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7133.0 in stage 90.0 (TID 40059) (host-10-140-92-227 executor 109): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 11119.0 in stage 90.0 (TID 44045) (host-10-140-92-155 executor 300): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15453.0 in stage 90.0 (TID 48378) (host-10-140-92-40 executor 200): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17688.0 in stage 90.0 (TID 50613) (host-10-140-93-38 executor 116): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12972.0 in stage 90.0 (TID 45897) (host-10-140-92-184 executor 51): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15710.0 in stage 90.0 (TID 48635) (host-10-140-92-115 executor 55): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12139.0 in stage 90.0 (TID 45064) (host-10-140-93-38 executor 112): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 5156.0 in stage 90.0 (TID 38083) (host-10-140-92-151 executor 128): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17235.0 in stage 90.0 (TID 50160) (host-10-140-92-113 executor 322): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6232.0 in stage 90.0 (TID 39158) (host-10-140-92-113 executor 324): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17009.0 in stage 90.0 (TID 49934) (host-10-140-92-227 executor 82): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 11345.0 in stage 90.0 (TID 44271) (host-10-140-92-24 executor 177): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 14620.0 in stage 90.0 (TID 47545) (host-10-140-92-140 executor 155): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 8761.0 in stage 90.0 (TID 41687) (host-10-140-92-227 executor 159): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13827.0 in stage 90.0 (TID 46752) (host-10-140-92-140 executor 152): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 8368.0 in stage 90.0 (TID 41294) (host-10-140-92-191 executor 286): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 5441.0 in stage 90.0 (TID 38368) (host-10-140-92-57 executor 59): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6009.0 in stage 90.0 (TID 38935) (host-10-140-92-90 executor 32): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 9496.0 in stage 90.0 (TID 42422) (host-10-140-92-46 executor 307): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15540.0 in stage 90.0 (TID 48465) (host-10-140-92-26 executor 36): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12590.0 in stage 90.0 (TID 45515) (host-10-140-92-26 executor 36): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 14546.0 in stage 90.0 (TID 47471) (host-10-140-93-37 executor 195): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15092.0 in stage 90.0 (TID 48017) (host-10-140-92-40 executor 104): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13709.0 in stage 90.0 (TID 46634) (host-10-140-93-38 executor 118): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15211.0 in stage 90.0 (TID 48136) (host-10-140-92-140 executor 252): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17578.0 in stage 90.0 (TID 50503) (host-10-140-92-140 executor 255): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 8703.0 in stage 90.0 (TID 41629) (host-10-140-92-113 executor 324): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13935.0 in stage 90.0 (TID 46860) (host-10-140-92-40 executor 103): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12145.0 in stage 90.0 (TID 45070) (host-10-140-92-26 executor 36): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 11572.0 in stage 90.0 (TID 44498) (host-10-140-92-60 executor 70): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12090.0 in stage 90.0 (TID 45015) (host-10-140-92-151 executor 203): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7955.0 in stage 90.0 (TID 40881) (host-10-140-92-90 executor 317): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16544.0 in stage 90.0 (TID 49469) (host-10-140-92-37 executor 48): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13658.0 in stage 90.0 (TID 46583) (host-10-140-92-140 executor 150): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12191.0 in stage 90.0 (TID 45116) (host-10-140-92-60 executor 69): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 14193.0 in stage 90.0 (TID 47118) (host-10-140-92-112 executor 315): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 8255.0 in stage 90.0 (TID 41181) (host-10-140-92-185 executor 1): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 992.0 in stage 90.0 (TID 33919) (host-10-140-92-246 executor 137): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 10025.0 in stage 90.0 (TID 42951) (host-10-140-93-57 executor 245): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7729.0 in stage 90.0 (TID 40655) (host-10-140-92-185 executor 1): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13422.0 in stage 90.0 (TID 46347) (host-10-140-92-140 executor 155): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16418.0 in stage 90.0 (TID 49343) (host-10-140-93-37 executor 196): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 10015.0 in stage 90.0 (TID 42941) (host-10-140-92-172 executor 168): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7469.0 in stage 90.0 (TID 40395) (host-10-140-92-191 executor 289): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 8444.0 in stage 90.0 (TID 41370) (host-10-140-92-191 executor 289): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7546.0 in stage 90.0 (TID 40472) (host-10-140-92-191 executor 286): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7147.0 in stage 90.0 (TID 40073) (host-10-140-92-191 executor 289): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13900.0 in stage 90.0 (TID 46825) (host-10-140-93-38 executor 114): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6899.0 in stage 90.0 (TID 39825) (host-10-140-92-227 executor 108): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 14742.0 in stage 90.0 (TID 47667) (host-10-140-92-140 executor 256): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6346.0 in stage 90.0 (TID 39272) (host-10-140-92-227 executor 105): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 1269.0 in stage 90.0 (TID 34196) (host-10-140-92-40 executor 95): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6518.0 in stage 90.0 (TID 39444) (host-10-140-92-227 executor 109): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17719.0 in stage 90.0 (TID 50644) (host-10-140-93-38 executor 115): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6351.0 in stage 90.0 (TID 39277) (host-10-140-92-115 executor 326): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16316.0 in stage 90.0 (TID 49241) (host-10-140-92-37 executor 37): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6399.0 in stage 90.0 (TID 39325) (host-10-140-92-227 executor 73): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 3210.0 in stage 90.0 (TID 36137) (host-10-140-92-150 executor 14): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17593.0 in stage 90.0 (TID 50518) (host-10-140-92-40 executor 199): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12620.0 in stage 90.0 (TID 45545) (host-10-140-92-40 executor 101): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 9431.0 in stage 90.0 (TID 42357) (host-10-140-92-99 executor 284): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 147.0 in stage 90.0 (TID 33074) (host-10-140-92-150 executor 18): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 3105.0 in stage 90.0 (TID 36032) (host-10-140-92-155 executor 291): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 9269.0 in stage 90.0 (TID 42195) (host-10-140-92-191 executor 287): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 11131.0 in stage 90.0 (TID 44057) (host-10-140-92-172 executor 169): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12383.0 in stage 90.0 (TID 45308) (host-10-140-92-40 executor 199): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6707.0 in stage 90.0 (TID 39633) (host-10-140-92-191 executor 290): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6671.0 in stage 90.0 (TID 39597) (host-10-140-92-227 executor 159): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 10580.0 in stage 90.0 (TID 43506) (host-10-140-92-24 executor 157): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6085.0 in stage 90.0 (TID 39011) (host-10-140-93-57 executor 248): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16546.0 in stage 90.0 (TID 49471) (host-10-140-92-57 executor 313): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12730.0 in stage 90.0 (TID 45655) (host-10-140-92-40 executor 94): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6288.0 in stage 90.0 (TID 39214) (host-10-140-92-113 executor 324): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12419.0 in stage 90.0 (TID 45344) (host-10-140-92-151 executor 128): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 10401.0 in stage 90.0 (TID 43327) (host-10-140-92-126 executor 263): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12195.0 in stage 90.0 (TID 45120) (host-10-140-92-40 executor 95): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7559.0 in stage 90.0 (TID 40485) (host-10-140-92-191 executor 290): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7832.0 in stage 90.0 (TID 40758) (host-10-140-92-185 executor 1): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 8108.0 in stage 90.0 (TID 41034) (host-10-140-92-185 executor 1): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 4938.0 in stage 90.0 (TID 37865) (host-10-140-92-140 executor 147): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15024.0 in stage 90.0 (TID 47949) (host-10-140-93-38 executor 116): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 5089.0 in stage 90.0 (TID 38016) (host-10-140-92-40 executor 102): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 4366.0 in stage 90.0 (TID 37293) (host-10-140-92-34 executor 231): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 3505.0 in stage 90.0 (TID 36432) (host-10-140-92-34 executor 234): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15563.0 in stage 90.0 (TID 48488) (host-10-140-93-38 executor 116): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7135.0 in stage 90.0 (TID 40061) (host-10-140-92-227 executor 109): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15524.0 in stage 90.0 (TID 48449) (host-10-140-93-38 executor 119): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13860.0 in stage 90.0 (TID 46785) (host-10-140-92-140 executor 252): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6623.0 in stage 90.0 (TID 39549) (host-10-140-92-196 executor 3): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 10584.0 in stage 90.0 (TID 43510) (host-10-140-93-57 executor 248): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17672.0 in stage 90.0 (TID 50597) (host-10-140-92-151 executor 130): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13921.0 in stage 90.0 (TID 46846) (host-10-140-92-191 executor 289): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6553.0 in stage 90.0 (TID 39479) (host-10-140-92-90 executor 316): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7056.0 in stage 90.0 (TID 39982) (host-10-140-92-57 executor 313): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13723.0 in stage 90.0 (TID 46648) (host-10-140-92-40 executor 200): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 10723.0 in stage 90.0 (TID 43649) (host-10-140-92-172 executor 169): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17709.0 in stage 90.0 (TID 50634) (host-10-140-92-40 executor 197): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7979.0 in stage 90.0 (TID 40905) (host-10-140-92-113 executor 322): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13348.0 in stage 90.0 (TID 46273) (host-10-140-92-40 executor 102): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6337.0 in stage 90.0 (TID 39263) (host-10-140-92-227 executor 105): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17383.0 in stage 90.0 (TID 50308) (host-10-140-92-191 executor 290): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17524.0 in stage 90.0 (TID 50449) (host-10-140-92-113 executor 323): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 9019.0 in stage 90.0 (TID 41945) (host-10-140-92-185 executor 1): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16537.0 in stage 90.0 (TID 49462) (host-10-140-92-113 executor 323): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17661.0 in stage 90.0 (TID 50586) (host-10-140-92-90 executor 319): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 9547.0 in stage 90.0 (TID 42473) (host-10-140-93-57 executor 248): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 7446.0 in stage 90.0 (TID 40372) (host-10-140-92-227 executor 160): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 12069.0 in stage 90.0 (TID 44994) (host-10-140-92-60 executor 183): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16466.0 in stage 90.0 (TID 49391) (host-10-140-92-151 executor 121): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6575.0 in stage 90.0 (TID 39501) (host-10-140-92-196 executor 2): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 10187.0 in stage 90.0 (TID 43113) (host-10-140-92-34 executor 233): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 16318.0 in stage 90.0 (TID 49243) (host-10-140-93-38 executor 114): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15599.0 in stage 90.0 (TID 48524) (host-10-140-92-40 executor 199): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 6556.0 in stage 90.0 (TID 39482) (host-10-140-92-57 executor 313): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 3526.0 in stage 90.0 (TID 36453) (host-10-140-93-57 executor 244): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 8262.0 in stage 90.0 (TID 41188) (host-10-140-92-227 executor 160): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 14173.0 in stage 90.0 (TID 47098) (host-10-140-92-140 executor 253): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 14776.0 in stage 90.0 (TID 47701) (host-10-140-92-151 executor 203): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 1013.0 in stage 90.0 (TID 33940) (host-10-140-92-151 executor 124): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 5503.0 in stage 90.0 (TID 38430) (host-10-140-93-38 executor 189): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17746.0 in stage 90.0 (TID 50671) (host-10-140-93-37 executor 193): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15523.0 in stage 90.0 (TID 48448) (host-10-140-92-140 executor 150): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 15217.0 in stage 90.0 (TID 48142) (host-10-140-92-40 executor 97): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 10719.0 in stage 90.0 (TID 43645) (host-10-140-92-34 executor 230): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 736.0 in stage 90.0 (TID 33663) (host-10-140-92-246 executor 87): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17304.0 in stage 90.0 (TID 50229) (host-10-140-92-40 executor 100): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 3342.0 in stage 90.0 (TID 36269) (host-10-140-92-30 executor 31): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 393.0 in stage 90.0 (TID 33320) (host-10-140-92-112 executor 61): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 17257.0 in stage 90.0 (TID 50182) (host-10-140-93-37 executor 141): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13910.0 in stage 90.0 (TID 46835) (host-10-140-92-151 executor 124): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 13928.0 in stage 90.0 (TID 46853) (host-10-140-92-40 executor 100): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 3644.0 in stage 90.0 (TID 36571) (host-10-140-93-57 executor 249): TaskKilled (Stage cancelled)
# 25/03/18 13:33:56 WARN TaskSetManager: Lost task 5631.0 in stage 90.0 (TID 38558) (host-10-140-92-227 executor 78): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 13459.0 in stage 90.0 (TID 46384) (host-10-140-92-140 executor 155): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 309.0 in stage 90.0 (TID 33236) (host-10-140-93-37 executor 42): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 11170.0 in stage 90.0 (TID 44096) (host-10-140-92-155 executor 297): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 17415.0 in stage 90.0 (TID 50340) (host-10-140-93-38 executor 188): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 10332.0 in stage 90.0 (TID 43258) (host-10-140-92-218 executor 271): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 8534.0 in stage 90.0 (TID 41460) (host-10-140-92-113 executor 323): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 8157.0 in stage 90.0 (TID 41083) (host-10-140-92-191 executor 288): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 7303.0 in stage 90.0 (TID 40229) (host-10-140-92-37 executor 305): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 11298.0 in stage 90.0 (TID 44224) (host-10-140-92-24 executor 173): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 6350.0 in stage 90.0 (TID 39276) (host-10-140-92-227 executor 160): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 6670.0 in stage 90.0 (TID 39596) (host-10-140-92-227 executor 158): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 7756.0 in stage 90.0 (TID 40682) (host-10-140-92-90 executor 319): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 13938.0 in stage 90.0 (TID 46863) (host-10-140-92-140 executor 150): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 11201.0 in stage 90.0 (TID 44127) (host-10-140-92-172 executor 169): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 15556.0 in stage 90.0 (TID 48481) (host-10-140-93-37 executor 138): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 9759.0 in stage 90.0 (TID 42685) (host-10-140-92-152 executor 219): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 16869.0 in stage 90.0 (TID 49794) (host-10-140-92-57 executor 59): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 8961.0 in stage 90.0 (TID 41887) (host-10-140-92-191 executor 287): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 5169.0 in stage 90.0 (TID 38096) (host-10-140-92-151 executor 204): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 9210.0 in stage 90.0 (TID 42136) (host-10-140-92-196 executor 2): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 6648.0 in stage 90.0 (TID 39574) (host-10-140-92-196 executor 2): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 13313.0 in stage 90.0 (TID 46238) (host-10-140-92-151 executor 205): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 12634.0 in stage 90.0 (TID 45559) (host-10-140-92-60 executor 186): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 14745.0 in stage 90.0 (TID 47670) (host-10-140-93-37 executor 43): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 16341.0 in stage 90.0 (TID 49266) (host-10-140-92-140 executor 154): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 4464.0 in stage 90.0 (TID 37391) (host-10-140-92-60 executor 66): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 17376.0 in stage 90.0 (TID 50301) (host-10-140-92-140 executor 145): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 4425.0 in stage 90.0 (TID 37352) (host-10-140-92-24 executor 181): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 14914.0 in stage 90.0 (TID 47839) (host-10-140-92-140 executor 256): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 14853.0 in stage 90.0 (TID 47778) (host-10-140-92-113 executor 325): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 9683.0 in stage 90.0 (TID 42609) (host-10-140-92-172 executor 171): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 12221.0 in stage 90.0 (TID 45146) (host-10-140-92-140 executor 154): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 16628.0 in stage 90.0 (TID 49553) (host-10-140-92-140 executor 149): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 10241.0 in stage 90.0 (TID 43167) (host-10-140-92-34 executor 238): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 1246.0 in stage 90.0 (TID 34173) (host-10-140-93-38 executor 113): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 16756.0 in stage 90.0 (TID 49681) (host-10-140-92-246 executor 132): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 3734.0 in stage 90.0 (TID 36661) (host-10-140-92-34 executor 233): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 14335.0 in stage 90.0 (TID 47260) (host-10-140-93-38 executor 189): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 12670.0 in stage 90.0 (TID 45595) (host-10-140-92-37 executor 49): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 2045.0 in stage 90.0 (TID 34972) (host-10-140-92-241 executor 214): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 575.0 in stage 90.0 (TID 33502) (host-10-140-92-227 executor 75): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 15618.0 in stage 90.0 (TID 48543) (host-10-140-92-140 executor 148): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 15165.0 in stage 90.0 (TID 48090) (host-10-140-92-140 executor 256): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 4494.0 in stage 90.0 (TID 37421) (host-10-140-92-155 executor 291): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 10550.0 in stage 90.0 (TID 43476) (host-10-140-92-172 executor 168): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 11886.0 in stage 90.0 (TID 44812) (host-10-140-93-38 executor 118): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 12680.0 in stage 90.0 (TID 45605) (host-10-140-93-38 executor 191): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 15942.0 in stage 90.0 (TID 48867) (host-10-140-92-151 executor 206): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 13527.0 in stage 90.0 (TID 46452) (host-10-140-92-40 executor 104): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 15437.0 in stage 90.0 (TID 48362) (host-10-140-92-90 executor 32): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 472.0 in stage 90.0 (TID 33399) (host-10-140-92-31 executor 50): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 4095.0 in stage 90.0 (TID 37022) (host-10-140-92-218 executor 273): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 8760.0 in stage 90.0 (TID 41686) (host-10-140-92-227 executor 105): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 13196.0 in stage 90.0 (TID 46121) (host-10-140-93-37 executor 41): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 17890.0 in stage 90.0 (TID 50815) (host-10-140-92-40 executor 201): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 12573.0 in stage 90.0 (TID 45498) (host-10-140-92-40 executor 97): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 29.0 in stage 90.0 (TID 32956) (host-10-140-92-196 executor 2): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 4987.0 in stage 90.0 (TID 37914) (host-10-140-92-40 executor 98): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 4060.0 in stage 90.0 (TID 36987) (host-10-140-92-241 executor 209): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 7655.0 in stage 90.0 (TID 40581) (host-10-140-92-90 executor 316): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 17388.0 in stage 90.0 (TID 50313) (host-10-140-93-38 executor 112): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 2561.0 in stage 90.0 (TID 35488) (host-10-140-92-34 executor 233): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 3827.0 in stage 90.0 (TID 36754) (host-10-140-92-152 executor 228): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 10277.0 in stage 90.0 (TID 43203) (host-10-140-92-241 executor 209): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 5385.0 in stage 90.0 (TID 38312) (host-10-140-93-38 executor 114): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 13178.0 in stage 90.0 (TID 46103) (host-10-140-92-60 executor 184): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 2395.0 in stage 90.0 (TID 35322) (host-10-140-92-218 executor 276): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 9678.0 in stage 90.0 (TID 42604) (host-10-140-93-57 executor 242): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 6952.0 in stage 90.0 (TID 39878) (host-10-140-92-90 executor 318): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 15532.0 in stage 90.0 (TID 48457) (host-10-140-92-140 executor 145): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 2210.0 in stage 90.0 (TID 35137) (host-10-140-92-172 executor 166): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 14092.0 in stage 90.0 (TID 47017) (host-10-140-93-38 executor 187): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 15313.0 in stage 90.0 (TID 48238) (host-10-140-92-40 executor 198): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 11095.0 in stage 90.0 (TID 44021) (host-10-140-92-241 executor 218): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 5568.0 in stage 90.0 (TID 38495) (host-10-140-92-40 executor 202): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 6673.0 in stage 90.0 (TID 39599) (host-10-140-92-227 executor 159): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 3895.0 in stage 90.0 (TID 36822) (host-10-140-92-34 executor 233): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 4048.0 in stage 90.0 (TID 36975) (host-10-140-92-218 executor 276): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 495.0 in stage 90.0 (TID 33422) (host-10-140-92-227 executor 80): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 15745.0 in stage 90.0 (TID 48670) (host-10-140-93-38 executor 116): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 3929.0 in stage 90.0 (TID 36856) (host-10-140-92-218 executor 270): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 5930.0 in stage 90.0 (TID 38857) (host-10-140-92-115 executor 57): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 12729.0 in stage 90.0 (TID 45654) (host-10-140-93-37 executor 38): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 14649.0 in stage 90.0 (TID 47574) (host-10-140-93-38 executor 188): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 8960.0 in stage 90.0 (TID 41886) (host-10-140-92-65 executor 6): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 12542.0 in stage 90.0 (TID 45467) (host-10-140-93-38 executor 110): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 2687.0 in stage 90.0 (TID 35614) (host-10-140-93-37 executor 194): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 7992.0 in stage 90.0 (TID 40918) (host-10-140-92-115 executor 326): TaskKilled (Stage cancelled)
# 25/03/18 13:33:57 WARN TaskSetManager: Lost task 4719.0 in stage 90.0 (TID 37646) (host-10-140-92-60 executor 68): TaskKilled (Stage cancelled)
# ...
# 25/03/18 13:33:59 WARN TaskSetManager: Lost task 12710.0 in stage 90.0 (TID 45635) (host-10-140-93-37 executor 40): TaskKilled (Stage cancelled)
# 25/03/18 13:33:59 WARN TaskSetManager: Lost task 1162.0 in stage 90.0 (TID 34089) (host-10-140-93-38 executor 118): TaskKilled (Stage cancelled)
# 25/03/18 13:33:59 WARN TaskSetManager: Lost task 13876.0 in stage 90.0 (TID 46801) (host-10-140-92-140 executor 152): TaskKilled (Stage cancelled)
# 25/03/18 13:33:59 WARN TaskSetManager: Lost task 3313.0 in stage 90.0 (TID 36240) (host-10-140-92-99 executor 283): TaskKilled (Stage cancelled)
# 25/03/18 13:33:59 WARN TaskSetManager: Lost task 450.0 in stage 90.0 (TID 33377) (host-10-140-93-15 executor 46): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 3592.0 in stage 90.0 (TID 36519) (host-10-140-93-57 executor 241): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 14928.0 in stage 90.0 (TID 47853) (host-10-140-92-40 executor 202): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 5518.0 in stage 90.0 (TID 38445) (host-10-140-92-227 executor 81): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 4280.0 in stage 90.0 (TID 37207) (host-10-140-92-155 executor 296): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 17825.0 in stage 90.0 (TID 50750) (host-10-140-93-37 executor 139): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 3063.0 in stage 90.0 (TID 35990) (host-10-140-92-155 executor 299): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 4704.0 in stage 90.0 (TID 37631) (host-10-140-92-246 executor 85): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 17680.0 in stage 90.0 (TID 50605) (host-10-140-93-38 executor 191): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 274.0 in stage 90.0 (TID 33201) (host-10-140-93-37 executor 39): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 13009.0 in stage 90.0 (TID 45934) (host-10-140-92-40 executor 197): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 13875.0 in stage 90.0 (TID 46800) (host-10-140-92-90 executor 33): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 17793.0 in stage 90.0 (TID 50718) (host-10-140-92-99 executor 282): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 16854.0 in stage 90.0 (TID 49779) (host-10-140-92-151 executor 123): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 3710.0 in stage 90.0 (TID 36637) (host-10-140-92-126 executor 262): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 15660.0 in stage 90.0 (TID 48585) (host-10-140-93-38 executor 116): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 14770.0 in stage 90.0 (TID 47695) (host-10-140-92-40 executor 198): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 16683.0 in stage 90.0 (TID 49608) (host-10-140-92-113 executor 325): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 2506.0 in stage 90.0 (TID 35433) (host-10-140-92-34 executor 232): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 13390.0 in stage 90.0 (TID 46315) (host-10-140-93-38 executor 189): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 16650.0 in stage 90.0 (TID 49575) (host-10-140-93-37 executor 142): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 16421.0 in stage 90.0 (TID 49346) (host-10-140-93-37 executor 142): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 2145.0 in stage 90.0 (TID 35072) (host-10-140-92-241 executor 209): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 2099.0 in stage 90.0 (TID 35026) (host-10-140-93-57 executor 243): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 66.0 in stage 90.0 (TID 32993) (host-10-140-92-150 executor 14): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 5656.0 in stage 90.0 (TID 38583) (host-10-140-92-140 executor 254): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 12394.0 in stage 90.0 (TID 45319) (host-10-140-92-191 executor 286): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 5883.0 in stage 90.0 (TID 38810) (host-10-140-92-90 executor 33): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 2800.0 in stage 90.0 (TID 35727) (host-10-140-92-30 executor 327): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 4980.0 in stage 90.0 (TID 37907) (host-10-140-93-38 executor 113): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 4779.0 in stage 90.0 (TID 37706) (host-10-140-92-216 executor 34): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 16219.0 in stage 90.0 (TID 49144) (host-10-140-92-140 executor 152): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 14795.0 in stage 90.0 (TID 47720) (host-10-140-92-246 executor 134): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 14015.0 in stage 90.0 (TID 46940) (host-10-140-92-40 executor 102): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 3031.0 in stage 90.0 (TID 35958) (host-10-140-92-155 executor 293): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 17186.0 in stage 90.0 (TID 50111) (host-10-140-92-40 executor 104): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 5961.0 in stage 90.0 (TID 38888) (host-10-140-92-90 executor 320): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 13506.0 in stage 90.0 (TID 46431) (host-10-140-92-140 executor 255): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 16453.0 in stage 90.0 (TID 49378) (host-10-140-92-60 executor 185): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 3961.0 in stage 90.0 (TID 36888) (host-10-140-92-172 executor 170): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 17878.0 in stage 90.0 (TID 50803) (host-10-140-92-184 executor 306): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 13091.0 in stage 90.0 (TID 46016) (host-10-140-93-38 executor 114): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 2763.0 in stage 90.0 (TID 35690) (host-10-140-92-90 executor 316): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 13659.0 in stage 90.0 (TID 46584) (host-10-140-93-37 executor 39): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 14126.0 in stage 90.0 (TID 47051) (host-10-140-92-112 executor 314): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 3898.0 in stage 90.0 (TID 36825) (host-10-140-92-152 executor 222): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 16673.0 in stage 90.0 (TID 49598) (host-10-140-93-37 executor 39): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 4887.0 in stage 90.0 (TID 37814) (host-10-140-92-184 executor 52): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 5929.0 in stage 90.0 (TID 38856) (host-10-140-92-227 executor 106): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 17359.0 in stage 90.0 (TID 50284) (host-10-140-92-60 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 1047.0 in stage 90.0 (TID 33974) (host-10-140-92-151 executor 129): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 592.0 in stage 90.0 (TID 33519) (host-10-140-92-60 executor 63): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 726.0 in stage 90.0 (TID 33653) (host-10-140-92-246 executor 90): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 4724.0 in stage 90.0 (TID 37651) (host-10-140-92-246 executor 92): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 1590.0 in stage 90.0 (TID 34517) (host-10-140-93-38 executor 192): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 12824.0 in stage 90.0 (TID 45749) (host-10-140-92-151 executor 205): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 4002.0 in stage 90.0 (TID 36929) (host-10-140-92-24 executor 181): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 623.0 in stage 90.0 (TID 33550) (host-10-140-92-60 executor 68): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 1600.0 in stage 90.0 (TID 34527) (host-10-140-92-60 executor 184): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 16280.0 in stage 90.0 (TID 49205) (host-10-140-92-140 executor 149): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 72.0 in stage 90.0 (TID 32999) (host-10-140-92-150 executor 16): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 4497.0 in stage 90.0 (TID 37424) (host-10-140-92-246 executor 85): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 14988.0 in stage 90.0 (TID 47913) (host-10-140-92-151 executor 131): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 278.0 in stage 90.0 (TID 33205) (host-10-140-93-37 executor 39): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 2956.0 in stage 90.0 (TID 35883) (host-10-140-92-112 executor 315): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 15733.0 in stage 90.0 (TID 48658) (host-10-140-92-113 executor 325): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 12397.0 in stage 90.0 (TID 45322) (host-10-140-92-40 executor 101): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 5787.0 in stage 90.0 (TID 38714) (host-10-140-92-227 executor 74): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 15303.0 in stage 90.0 (TID 48228) (host-10-140-93-38 executor 120): TaskKilled (Stage cancelled)
# 25/03/18 13:34:00 WARN TaskSetManager: Lost task 1758.0 in stage 90.0 (TID 34685) (host-10-140-92-40 executor 197): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 2217.0 in stage 90.0 (TID 35144) (host-10-140-92-241 executor 216): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 3917.0 in stage 90.0 (TID 36844) (host-10-140-92-241 executor 213): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 15522.0 in stage 90.0 (TID 48447) (host-10-140-92-40 executor 202): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 12935.0 in stage 90.0 (TID 45860) (host-10-140-92-60 executor 182): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 14347.0 in stage 90.0 (TID 47272) (host-10-140-92-140 executor 146): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 15696.0 in stage 90.0 (TID 48621) (host-10-140-92-140 executor 255): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 3721.0 in stage 90.0 (TID 36648) (host-10-140-92-152 executor 223): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 2560.0 in stage 90.0 (TID 35487) (host-10-140-93-38 executor 188): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 14118.0 in stage 90.0 (TID 47043) (host-10-140-92-140 executor 148): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 15574.0 in stage 90.0 (TID 48499) (host-10-140-92-184 executor 51): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 16564.0 in stage 90.0 (TID 49489) (host-10-140-92-40 executor 201): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 3680.0 in stage 90.0 (TID 36607) (host-10-140-92-218 executor 275): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 12107.0 in stage 90.0 (TID 45032) (host-10-140-93-37 executor 42): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 15758.0 in stage 90.0 (TID 48683) (host-10-140-92-90 executor 318): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 13646.0 in stage 90.0 (TID 46571) (host-10-140-92-184 executor 306): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 14392.0 in stage 90.0 (TID 47317) (host-10-140-92-40 executor 97): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 17859.0 in stage 90.0 (TID 50784) (host-10-140-92-90 executor 318): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 16878.0 in stage 90.0 (TID 49803) (host-10-140-92-216 executor 34): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 4026.0 in stage 90.0 (TID 36953) (host-10-140-92-172 executor 163): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 13250.0 in stage 90.0 (TID 46175) (host-10-140-92-40 executor 101): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 15629.0 in stage 90.0 (TID 48554) (host-10-140-92-196 executor 2): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 15315.0 in stage 90.0 (TID 48240) (host-10-140-92-140 executor 147): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 13364.0 in stage 90.0 (TID 46289) (host-10-140-92-60 executor 186): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 15623.0 in stage 90.0 (TID 48548) (host-10-140-92-151 executor 203): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 13979.0 in stage 90.0 (TID 46904) (host-10-140-92-60 executor 186): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 12437.0 in stage 90.0 (TID 45362) (host-10-140-93-38 executor 117): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 3622.0 in stage 90.0 (TID 36549) (host-10-140-92-126 executor 258): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 127.0 in stage 90.0 (TID 33054) (host-10-140-92-196 executor 3): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 17609.0 in stage 90.0 (TID 50534) (host-10-140-93-38 executor 190): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 15772.0 in stage 90.0 (TID 48697) (host-10-140-92-196 executor 3): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 15781.0 in stage 90.0 (TID 48706) (host-10-140-92-31 executor 50): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 5435.0 in stage 90.0 (TID 38362) (host-10-140-92-140 executor 257): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 14566.0 in stage 90.0 (TID 47491) (host-10-140-92-240 executor 4): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 13345.0 in stage 90.0 (TID 46270) (host-10-140-92-40 executor 103): TaskKilled (Stage cancelled)
# 25/03/18 13:34:01 WARN TaskSetManager: Lost task 2223.0 in stage 90.0 (TID 35150) (host-10-140-92-218 executor 271): TaskKilled (Stage cancelled)
# [Stage 90:===============================================> (17272 + 88) / 18000]
